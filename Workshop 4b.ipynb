# %%
import cobra
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from cobra.io import load_json_model

# %% [markdown]
# # In this workshop We will use an unpublished version of the <i>C. diff</i> 630 model (iCN900). Please don't distribute!

# %%
model_file = 'iCN900_09062018.json'
model = load_json_model(model_file)
model
# Out:
# <Model None at 0x11cec4a8>

# %%
# Load our genome comparison:
filename = 'CD630_vs_112C_genome_comparison.txt'
data = pd.read_csv(filename, sep='\t', skiprows=1) # change this with the name of your C. diff genome
# filter for BBH and high-identity matches
data = data[(data['comp_genome_1_hit']=='bi (<->)') & (data['comp_genome_1_percent_identity']>0.8)]
print len(data) # bbh matches
# Out:
# 3422

# %%
data[['ref_genome_locus_tag','comp_genome_1_hit','comp_genome_1_percent_identity','comp_genome_1_patric_id']].head()
# Out:
#    ref_genome_locus_tag comp_genome_1_hit  comp_genome_1_percent_identity  \
# 8                CD0001          bi (<->)                             1.0
# 9                CD0002          bi (<->)                             1.0
# 10               CD0003          bi (<->)                             1.0
# 11               CD0004          bi (<->)                             1.0
# 12               CD0005          bi (<->)                             1.0
#
#    comp_genome_1_patric_id
# 8   fig|1496.2321.peg.3133
# 9   fig|1496.2321.peg.3132
# 10  fig|1496.2321.peg.3131
# 11  fig|1496.2321.peg.3130
# 12  fig|1496.2321.peg.3129

# %%
model_genes = [g.id for g in model.genes]
print len(model_genes)
# Out:
# 900

# %%
# genome annotation has changed - need to link PATRIC old locus to new:
locus = pd.read_csv('locus_mapping.csv', index_col=0)
data = pd.merge(data, locus, left_on='ref_genome_locus_tag', right_on='old_locus')
orthologs = data[['locus','comp_genome_1_patric_id']]

# %%
orthologs.index=orthologs['locus']
orthologs = orthologs['comp_genome_1_patric_id'].to_dict()

# %%
# we will delete all genes from our model that do not have an ortholog in our genome of interest
# get missing genes:
to_delete = set(model_genes)-set(data['locus'].tolist())
print len(to_delete)
# Out:
# 34

# %%
# don't remove essential genes - note this assumption may be incorrect, e.g. in the case of auxotophy, 
# this should, however allow our draft model to solve
from cobra.flux_analysis import single_gene_deletion
sko= single_gene_deletion(model)
essential_genes = sko[sko['growth']<0.001]
essential_gene_names = [list(g)[0] for g in essential_genes.index.tolist()]

# %%
# remove the essential genes from our set of genes to delete
to_curate = list(to_delete&set(essential_gene_names)) # these genes have no ortholog but are predicted to be essential, flag for future curation
to_delete = to_delete-set(essential_gene_names)
print to_curate
print len(to_curate)
print len(to_delete)
# Out:
# [u'CD630_02440']
# 1
# 33

# %%
# check the functions of the genes missing in our strain of interest:
to_delete = list(to_delete)
for g in to_delete:
    gene = model.genes.get_by_id(g)
    print gene
    for rxn in gene.reactions:
        print '\t', rxn.id, rxn.name, rxn.reaction
# Out:
# CD630_33310
# 	GF6PTA  f6p_c + gln__L_c --> gam6p_c + glu__L_c
# CD630_038901
# 	6PHBG  cellb6p_c + h2o_c --> g6p_c + glc__D_c
# CD630_038903
# 	6PHBG  cellb6p_c + h2o_c --> g6p_c + glc__D_c
# CD630_038902
# 	6PHBG  cellb6p_c + h2o_c --> g6p_c + glc__D_c
# CD630_04300
# 	COBabc  atp_c + cobalt2_e + h2o_c --> adp_c + cobalt2_c + pi_c
# CD630_26660
# 	GLCADpts  Glc_aD_e + pep_c --> g6p_A_c + pyr_c
# CD630_23220'
# 	TKT1  r5p_c + xu5p__D_c --> g3p_c + s7p_c
# CD630_02410
# 	PSP_L  h2o_c + pser__L_c --> pi_c + ser__L_c
# 	LTHRK  atp_c + thr__L_c <=> adp_c + thrp_c
# CD630_07650
# 	SBTpts  pep_c + sbt__D_e --> pyr_c + sbt6p_c
# CD630_31360
# 	BGLA1 6-phospho-beta-glucosidase 6pgg_c + h2o_c --> g6p_c + glc__D_c
# CD630_07670
# 	SBTpts  pep_c + sbt__D_e --> pyr_c + sbt6p_c
# CD630_28720'
# 	ALTRH  altrn_c --> 2ddglcn_c + h2o_c
# CD630_2179
# 	FDH  co2_c + h_c + nadh_c --> for_c + nad_c
# CD630_26691
# 	NAt3_1  h_c + na1_e <=> h_e + na1_c
# CD630_270801
# 	SHK3Dr  3dhsk_c + h_c + nadph_c --> nadp_c + skm_c
# 	SKDH  3dhsk_c + h_c + nadh_c --> nad_c + skm_c
# CD630_08160
# 	GAMpts D-glucosamine transport via PEP:Pyr PTS gam_e + pep_c --> gam6p_c + pyr_c
# CD630_31470
# 	CYTOM Cytosine 5 methyltransferase amet_c + csn_c --> 5mcsn_c + ahcys_c + h_c
# CD630_13380
# 	MAL6PG  h2o_c + malt6p_c <=> g6p_c + glc__D_c
# CD630_04310
# 	COBabc  atp_c + cobalt2_e + h2o_c --> adp_c + cobalt2_c + pi_c
# CD07280
# 	COMCOA  co_c + coa_c + fesm_c --> accoa_c + fes_c + h_c
# CD630_07680
# 	SBTPD  nad_c + sbt6p_c --> f6p_c + h_c + nadh_c
# CD630_13360
# 	TREpts  pep_c + tre_e --> pyr_c + tre6p_c
# CD630_31370
# 	ACGApts N-Acetyl-D-glucosamine transport via PEP:Pyr PTS acgam_e + pep_c --> acgam6p_c + pyr_c
# CD630_07640
# 	SBTpts  pep_c + sbt__D_e --> pyr_c + sbt6p_c
# CD630_0769
# 	FDH  co2_c + h_c + nadh_c --> for_c + nad_c
# CD630_09270
# 	CYTOM Cytosine 5 methyltransferase amet_c + csn_c --> 5mcsn_c + ahcys_c + h_c
# CD630_07660
# 	SBTpts  pep_c + sbt__D_e --> pyr_c + sbt6p_c
# CD630_0174
# 	CMH2  co_c + h2o_c --> co2_c + h2_c
# CD630_0175
# 	CMH2  co_c + h2o_c --> co2_c + h2_c
# CD630_358802
# 	CBPS  atp_c + gln__L_c + h2o_c + h_c + hco3_c --> adp_c + cbp_c + glu__L_c + pi_c
# 	CPS  atp_c + h_c + hco3_c + nh4_c --> adp_c + cbp_c + pi_c
# CD630_358801
# 	CBPS  atp_c + gln__L_c + h2o_c + h_c + hco3_c --> adp_c + cbp_c + glu__L_c + pi_c
# 	CPS  atp_c + h_c + hco3_c + nh4_c --> adp_c + cbp_c + pi_c
# CD630_0176
# 	CMH2  co_c + h2o_c --> co2_c + h2_c
# CD630_011301
# 	BUTKr  adp_c + butpi_c --> atp_c + but_c

# %% [markdown]
# # Delete missing orthologs from our new model

# %%
from cobra.manipulation.delete import delete_model_genes
model = load_json_model(model_file)
new_model = model.copy()

# %%
delete_model_genes(new_model, to_delete)

# %%
# show the genes that were removed:
for g in new_model._trimmed_genes:
    print g
# Out:
# CD630_28720'
# CD630_04310
# CD630_07640
# CD630_038903
# CD630_038901
# CD630_07660
# CD630_038902
# CD07280
# CD630_08160
# CD630_13360
# CD630_02410
# CD630_358802
# CD630_270801
# CD630_26691
# CD630_07680
# CD630_0174
# CD630_358801
# CD630_0176
# CD630_23220'
# CD630_31370
# CD630_0175
# CD630_31360
# CD630_0769
# CD630_33310
# CD630_07650
# CD630_31470
# CD630_13380
# CD630_011301
# CD630_2179
# CD630_09270
# CD630_26660
# CD630_04300
# CD630_07670

# %%
# show the reactions that were removed:
for r in new_model._trimmed_reactions:
    print r, r.name
# Out:
# CYTOM: amet_c + csn_c --> 5mcsn_c + ahcys_c + h_c Cytosine 5 methyltransferase
# SBTPD: nad_c + sbt6p_c --> f6p_c + h_c + nadh_c
# BGLA1: 6pgg_c + h2o_c --> g6p_c + glc__D_c 6-phospho-beta-glucosidase
# TREpts: pep_c + tre_e --> pyr_c + tre6p_c
# SBTpts: pep_c + sbt__D_e --> pyr_c + sbt6p_c
# LTHRK: atp_c + thr__L_c --> adp_c + thrp_c
# ACGApts: acgam_e + pep_c --> acgam6p_c + pyr_c N-Acetyl-D-glucosamine transport via PEP:Pyr PTS
# FDH: co2_c + h_c + nadh_c --> for_c + nad_c

# %%
sol = new_model.optimize()

# %%
sol.objective_value
# Out:
# 0.2102828121195251

# %%
# Simulate essential genes in our new model.
# Extra: compare to essential genes in original model

# %%
# SOLUTION

# %% [markdown]
# ## Update the GPRs in our model

# %%
from cobra import Model
new_model = Model('C. diff 112C')
model = load_json_model(model_file)

# %%
from cobra.manipulation.delete import remove_genes

# %%
remove_genes(model,to_delete)
sol = model.optimize()
print sol
# Out:
# <Solution 0.210 at 0x1a84cfd0>

# %%
model_genes = [g for g in model.genes]
i=0

for g in model_genes:
    if g.id in orthologs.keys():
        ortholog = orthologs[g.id]
        for r in g.reactions:
            r.gene_reaction_rule = r.gene_reaction_rule.replace(g.id,ortholog)
    else:
        print g.id
# Out:
# CD630_02440

# %%
for r in model.reactions:
    rxn = r.copy()
    print rxn
    new_model.add_reaction(rxn)
new_model.reactions.BIOMASS.objective_coefficient = 1
# Out:
# TAGabc: atp_c + h2o_c + tagur_e --> adp_c + pi_c + tagur_c
# PPATabc: atp_c + h2o_c + ppat_e --> adp_c + pi_c + ppat_c
# GLUabc: atp_c + glu__L_e + h2o_c --> adp_c + glu__L_c + pi_c
# ASNabc: asn__L_e + atp_c + h2o_c --> adp_c + asn__L_c + pi_c
# GLYBabc: atp_c + glyb_e + h2o_c --> adp_c + glyb_c + pi_c
# ASPabc: asp__L_e + atp_c + h2o_c --> adp_c + asp__L_c + pi_c
# PTRCabc: atp_c + h2o_c + ptrc_e --> adp_c + pi_c + ptrc_c
# METDabc: atp_c + h2o_c + met__D_e --> adp_c + met__D_c + pi_c
# CHLabc: atp_c + chol_e + h2o_c --> adp_c + chol_c + pi_c
# NAabc: atp_c + h2o_c + na1_e --> adp_c + na1_c + pi_c
# GLNabc: atp_c + gln__L_e + h2o_c --> adp_c + gln__L_c + pi_c
# PIabc: atp_c + h2o_c + pi_e --> adp_c + 2 pi_c
# ARGabc: arg__L_e + atp_c + h2o_c --> adp_c + arg__L_c + pi_c
# HISabc: atp_c + h2o_c + his__L_e --> adp_c + his__L_c + pi_c
# TYRabc: atp_c + h2o_c + tyr__L_e --> adp_c + pi_c + tyr__L_c
# ZNabc: atp_c + h2o_c + zn2_c --> adp_c + pi_c + zn2_e
# G3Pabc: atp_c + g3p_e + h2o_c --> adp_c + pi_c + sng3p_c
# FE2abc: atp_c + fe2_e + h2o_c --> adp_c + fe2_c + pi_c
# NO3abc: atp_c + h2o_c + no3_e --> adp_c + no3_c + pi_c
# CYSabc: atp_c + cys__L_e + h2o_c --> adp_c + cys__L_c + pi_c
# CO1abc: atp_c + co1dam_e + h2o_c --> adp_c + co1dam_c + pi_c
# METabc: atp_c + h2o_c + met__L_e --> adp_c + met__L_c + pi_c
# TRPabc: atp_c + h2o_c + trp__L_e --> adp_c + pi_c + trp__L_c
# SPMDabc: atp_c + h2o_c + spmd_e --> adp_c + pi_c + spmd_c
# LYSabc: atp_c + h2o_c + lys__L_e --> adp_c + lys__L_c + pi_c
# LEUabc: atp_c + h2o_c + leu__L_e --> adp_c + leu__L_c + pi_c
# ALAabc: ala__L_e + atp_c + h2o_c --> adp_c + ala__L_c + pi_c
# PHEabc: atp_c + h2o_c + phe__L_e --> adp_c + phe__L_c + pi_c
# COBabc: atp_c + cobalt2_e + h2o_c --> adp_c + cobalt2_c + pi_c
# CA2abc: atp_c + ca2_e + h2o_c --> adp_c + ca2_c + pi_c
# VALabc: atp_c + h2o_c + val__L_e --> adp_c + pi_c + val__L_c
# PROabc: atp_c + h2o_c + pro__L_e --> adp_c + pi_c + pro__L_c
# PMG2abc: atp_c + h2o_c + mg2_e --> adp_c + mg2_c + pi_c
# THRabc: atp_c + h2o_c + thr__L_e --> adp_c + pi_c + thr__L_c
# Kabc: atp_c + h2o_c + k_e --> adp_c + k_c + pi_c
# GLYabc: atp_c + gly_e + h2o_c --> adp_c + gly_c + pi_c
# MG2abc: atp_c + h2o_c + mg2_e --> adp_c + mg2_c + pi_c
# SERabc: atp_c + h2o_c + ser__L_e --> adp_c + pi_c + ser__L_c
# ILEabc: atp_c + h2o_c + ile__L_e --> adp_c + ile__L_c + pi_c
# RIBabc: atp_c + h2o_c + rib__D_e --> adp_c + pi_c + rib__D_c
# RAFFabc: atp_c + h2o_c + raffin_e --> adp_c + pi_c + raffin_c
# GTHOr: gthox_c + h_c + nadph_c <=> gthrd_c + nadp_c
# ASNS3: asp__L_c + atp_c + gln__L_c + nh4_c --> amp_c + asn__L_c + glu__L_c + ppi_c
# GLNSCP: atp_c + gln__L_c + h2o_c + hco3_c <=> adp_c + cmylphosph_c + glu__L_c + h_c + pi_c
# GLACC: accoa_c + glu__L_c --> acglu_c + coa_c + h_c
# ASNS1: asp__L_c + atp_c + gln__L_c + h2o_c --> amp_c + asn__L_c + glu__L_c + ppi_c
# ASNS2: asp__L_c + atp_c + nh4_c --> amp_c + asn__L_c + ppi_c
# SSALx: h2o_c + nad_c + sucsal_c --> h_c + nadh_c + succ_c
# AMID_1: ad_c + h2o_c <=> ac_c + nh4_c
# GLXGLY: ala__L_c + glx_c <=> gly_c + pyr_c
# GDH1: glu__L_c + h2o_c + nad_c --> akg_c + h_c + nadh_c + nh4_c
# ABTA: 4abut_c + akg_c --> glu__L_c + sucsal_c
# SSALy: h2o_c + nadp_c + sucsal_c --> h_c + nadph_c + succ_c
# ASPTA: glu__L_c + oaa_c --> akg_c + asp__L_c
# GF6PTA: f6p_c + gln__L_c --> gam6p_c + glu__L_c
# A4PA: 4abut_c + pyr_c --> ala__L_c + sucsal_c
# GLUR: glu__L_c --> glu__D_c
# ARGSL: argsuc_c --> arg__L_c + fum_c
# ASNN: asn__L_c + h2o_c --> asp__L_c + nh4_c
# GLUSy: akg_c + gln__L_c + h_c + nadph_c --> glu__L_c + nadp_c
# GLUN: gln__L_c + h2o_c --> glu__L_c + nh4_c
# APAT2r: akg_c + ala_B_c <=> glu__L_c + msa_c
# ALATA_L: akg_c + ala__L_c --> glu__L_c + pyr_c
# A4GA: 4abut_c + glx_c --> gly_c + sucsal_c
# UAMAS: ala__L_c + atp_c + uamr_c --> adp_c + pi_c + uama_c
# GGGP: gthrd_c + h2o_c <=> cgly_c + glu__L_c
# UAMAGS: atp_c + glu__D_c + uama_c --> adp_c + pi_c + uamag_c
# GAL: atp_c + glu__L_c + nh4_c --> adp_c + gln__L_c + pi_c
# ALAR: ala__L_c <=> ala__D_c
# ALAAH: alaala_c + h2o_c --> ala__D_c
# ALAALAr: ala__D_c + atp_c --> adp_c + alaala_c + pi_c
# SPTc: pyr_c + ser__L_c --> ala__L_c + hpyr_c
# ARGSS_1: asp__L_c + atp_c + citr__L_c --> amp_c + argsuc_c + ppi_c
# GLUSx: akg_c + gln__L_c + h_c + nadh_c --> glu__L_c + nad_c
# MSADC: msa_c <=> acald_c + co2_c
# ASP4DC: asp__L_c --> ala__L_c + co2_c
# G6PDA: gam6p_c + h2o_c --> f6p_c + nh4_c
# A24T2: acgam_c + atp_c --> acgam6p_c + adp_c
# UDPACGLP: acgam1p_c + utp_c --> ppi_c + uacgam_c
# PGAMT: gam6p_c --> gam1p_c
# G1PACT: accoa_c + gam1p_c --> acgam1p_c + coa_c
# AGDC: acgam6p_c + h2o_c --> ac_c + gam6p_c
# UAG2EMA: h2o_c + uacgam_c --> acmana_c + udp_c
# UAGCVT: pep_c + uacgam_c --> pi_c + uaccg_c
# ACNML: acnam_c --> acmana_c + pyr_c
# AMANAPEr: acmanap_c <=> acgam6p_c
# AMANK: acmana_c + atp_c --> acmanap_c + adp_c
# UAPGR: h_c + nadph_c + uaccg_c --> nadp_c + uamr_c
# UAG2E: uacgam_c --> uacmam_c
# ARGDC: arg__L_c --> agm_c + co2_c
# ALPHNH: allphn_c + h2o_c --> co2_c + nh4_c
# PTRCAT1: accoa_c + ptrc_c <=> aprut_c + coa_c
# AGPR: acg5p_c + h_c + nadph_c --> acg5sa_c + nadp_c + pi_c
# AGMT: agm_c + h2o_c --> ptrc_c + urea_c
# OCBT: cbp_c + orn_c <=> citr__L_c + pi_c
# ACODA: acorn_c + h2o_c --> ac_c + orn_c
# ORNTAC: acorn_c + glu__L_c --> acglu_c + orn_c
# ABUTD: 4abutn_c + h2o_c + nad_c <=> 4abut_c + h_c + nadh_c
# ACGK: acglu_c + atp_c --> acg5p_c + adp_c
# ACGS: accoa_c + glu__L_c --> acglu_c + coa_c
# PROR: pro__L_c --> pro__D_c
# UREASE: atp_c + h_c + hco3_c + urea_c --> adp_c + allphn_c + pi_c
# PTRCTA: ptrc_c + pyr_c --> 4abutn_c + ala__L_c
# ACOTA: acg5sa_c + glu__L_c --> acorn_c + akg_c
# ARGDI: arg__L_c + h2o_c <=> citr__L_c + nh4_c
# CELLWALL: CLP_c + teichoic_c --> CELLWALL_c
# BIOMASS: CELLWALL_c + DNA_c + LIPID_c + PROTEIN_c + RNA_c + SOLPOOL_c + atp_c + h2o_c --> adp_c + biomass_c + pi_c
# RNA: atp_c + ctp_c + gtp_c + h2o_c + utp_c --> RNA_c + adp_c + pi_c + ppi_c
# DNA: atp_c + datp_c + dctp_c + dgtp_c + dttp_c + h2o_c --> DNA_c + adp_c + pi_c + ppi_c
# PEPGLYCAN: atp_c + h2o_c + uacgam_c + udpamagdapaa_c --> CLP_c + adp_c + ala__D_c + pi_c + udp_c
# PROTEIN: ala__L_c + arg__L_c + asn__L_c + asp__L_c + atp_c + cys__L_c + gln__L_c + glu__L_c + gly_c + h2o_c + his__L_c + ile__L_c + leu__L_c + lys__L_c + met__L_c + phe__L_c + pro__L_c + ser__L_c + thr__L_c + trp__L_c + tyr__L_c + val__L_c --> PROTEIN_c + adp_c + pi_c
# LIPID: dgludmygl_c + dgludpalmgl_c + mglucsyldmygl_c + mglucsyldpalmgl_c + mycdlpn_c + myrphgl_c + palmcdlpn_c + palmphgl_c + phosglcdihexdec_c + phosglcdioctdec_c + phosglcditetdec_c + strcdlpn_c + strphglc_c --> LIPID_c
# SOLPOOL: Glc_aD_c + accoa_c + ala__L_c + arg__L_c + asp__L_c + atp_c + citr__L_c + coa_c + fad_c + gln__L_c + glu__L_c + gly_c + his__L_c + ile__L_c + leu__L_c + lys__L_c + met__L_c + nad_c + nadh_c + nadp_c + nadph_c + phe__L_c + pi_c + pro__L_c + ser__L_c + thr__L_c + thym_c + val__L_c --> SOLPOOL_c
# A4HBCT: accoa_c + h4but_c --> 4hbutcoa_c + ac_c
# VACOAI: vaccoa_c <=> ctncoa_c
# BNOCA: btcoa_c + h_c + nadph_c --> btal_c + coa_c + nadp_c
# HBCO_nadp: 3hbcoa_c + nadp_c --> aacoa_c + h_c + nadph_c
# BUTCT1: ac_c + btcoa_c --> accoa_c + but_c
# SAOR: diact_c + h_c + nadh_c --> actn__S_c + nad_c
# AAAN: acald_c + accoa_c + h_c + nadh_c <=> actn__S_c + coa_c + nad_c
# 4HBCOAH: 4hbutcoa_c --> h2o_c + vaccoa_c
# ACTD: diact_c + h_c + nadh_c --> actn__R_c + nad_c
# T2ECR: b2coa_c + h_c + nadph_c --> btcoa_c + nadp_c
# SSAH: h_c + nadh_c + sucsal_c <=> h4but_c + nad_c
# BDH: bhb_c + nad_c --> acac_c + h_c + nadh_c
# BTS: btal_c + h_c + nadh_c --> 1btol_c + nad_c
# HCO3E: co2_c + h2o_c <=> h_c + hco3_c
# ARSR: actn__R_c <=> actn__S_c
# BTCOARx: btcoa_c + h_c + nadh_c --> btal_c + coa_c + nad_c
# A2DC: alac__S_c + elecacceptoxi_c --> co2_c + diact_c + elecacceptred_c
# GCCL: gccoa_c --> co2_c + ctncoa_c
# PBUTT: btcoa_c + pi_c --> butpi_c + coa_c
# BTS_nadph: btal_c + h_c + nadph_c --> 1btol_c + nadp_c
# BUTKr: adp_c + butpi_c --> atp_c + but_c
# ACLDC: alac__S_c <=> actn__R_c + co2_c
# MG2t: mg2_e --> mg2_c
# Kt3r: h_c + k_e --> h_e + k_c
# FORt: for_e <=> for_c
# NO2t: no2_e --> no2_c
# Kt1: k_e --> k_c
# ZN2t: zn2_e --> zn2_c
# ICDH: icit_c + nadp_c --> akg_c + co2_c + h_c + nadph_c
# AKGDH: akg_c + coa_c + nad_c --> co2_c + h_c + nadh_c + succoa_c
# PC: atp_c + h_c + hco3_c + pyr_c --> adp_c + oaa_c + pi_c
# CITL: cit_c <=> acon_C_c + h2o_c
# ICDHx: icit_c + nad_c --> akg_c + co2_c + h_c + nadh_c
# CS: accoa_c + h2o_c + oaa_c --> cit_c + coa_c
# SUCOAS: atp_c + coa_c + succ_c --> adp_c + pi_c + succoa_c
# ACONTb: icit_c <=> acon_C_c + h2o_c
# FUM: fum_c + h2o_c --> mal__L_c
# MDH: mal__L_c + nad_c --> h_c + nadh_c + oaa_c
# METAT: atp_c + h2o_c + met__L_c --> amet_c + pi_c + ppi_c
# HSERTA: accoa_c + hom__L_c --> achms_c + coa_c
# AHCi: ahcys_c + h2o_c --> adn_c + hcys__L_c
# SPMDAT1: accoa_c + sprm_c <=> N1aspmd_c + coa_c
# M5DPP: h2o_c + m5t23dopp_c --> d12h5mtp_c + pi_c
# METS: 5mthf_c + hcys__L_c --> met__L_c + thf_c
# TGOM: gly_c + nad_c + thf_c --> co2_c + h_c + mlthf_c + nadh_c + nh4_c
# AHSERL2: achms_c + h2s_c --> ac_c + h_c + hcys__L_c
# H23KMP: h23k5mt1pp_c + h2o_c --> d12h5mtp_c + pi_c
# DM1PE: 5mdru1p_c --> 2h3k5m_c
# SHSL1: cys__L_c + suchms_c --> cyst__L_c + succ_c
# APAPT: ametam_c + ptrc_c --> 5mta_c + h_c + spmd_c
# ADMDC: amet_c + h_c --> ametam_c + co2_c
# CYSDS: cys__L_c + h2o_c --> h2s_c + nh4_c + pyr_c
# LCYSTST: cys__L_c + h_c + unsc_c <=> ala__L_c + ssc_c
# SPMDAT2: accoa_c + spmd_c <=> coa_c + n8aspmd_c
# ASAPT: ametam_c + spmd_c <=> 5mta_c + h_c + sprm_c
# METR: met__L_c <=> met__D_c
# AHCYSNS: ahcys_c + h2o_c --> ade_c + rhcys_c
# M51PH: 5mdru1p_c --> h2o_c + m5t23dopp_c
# M523I: m5t23dopp_c --> h23k5mt1pp_c
# METGL: h2o_c + met__L_c --> 2obut_c + ch4s_c + nh4_c
# HSST: hom__L_c + succoa_c --> coa_c + suchms_c
# AHSERL: achms_c + ch4s_c <=> ac_c + met__L_c
# RHCCE: rhcys_c --> dhptd_c + hcys__L_c
# MTRK: 5mtr_c + atp_c --> 5mdr1p_c + adp_c
# MTRI: 5mdr1p_c --> 5mdru1p_c
# MTAN: 5mta_c + h2o_c --> 5mtr_c + ade_c
# CYSTL: cyst__L_c + h2o_c --> hcys__L_c + nh4_c + pyr_c
# HCYSMT: amet_c + hcys__L_c <=> ahcys_c + met__L_c
# ORNR: orn_c --> orn__D_c
# A24T: a24op_c + coa_c --> accoa_c + ala__D_c
# O45AM: orn__D_c --> dap24_c
# DOP1: dap24_c + h2o_c + nadp_c --> a24op_c + h_c + nadph_c + nh4_c
# DOP2: dap24_c + h2o_c + nad_c --> a24op_c + h_c + nadh_c + nh4_c
# DNMPPA: dhpmp_c + h2o_c --> dhnpt_c + pi_c
# DHPS2: 4abz_c + 6hmhpt_c --> dhpt_c + ppi_c
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + ppi_c
# HPPK2: 6hmhpt_c + atp_c --> 6hmhptpp_c + amp_c
# ADCS: chor_c + gln__L_c --> 4adcho_c + glu__L_c
# DHFS: atp_c + dhpt_c + glu__L_c --> adp_c + dhf_c + pi_c
# ADCL: 4adcho_c --> 4abz_c + pyr_c
# DACL: abg4_c + h2o_c + h_c <=> 4abz_c + glu__D_c
# DHPS2_1: 4abz_c + 6hmhptpp_c --> dhpt_c + ppi_c
# GTPCI_2: gtp_c + h2o_c --> ahdt_c + for_c
# DHNPA2r: dhnpt_c --> 6hmhpt_c + gcald_c
# PMANM: man6p_c --> man1p_c
# FRUK: atp_c + f1p_c --> adp_c + fdp_c
# r0191: f6p_c + utp_c --> fdp_c + udp_c
# MAN1PT2: gdp_c + man1p_c --> gdpmann_c + pi_c
# A6PAG: atp_c + gal_c --> adp_c + dgal6p_c
# AM6PT: atp_c + man_c --> adp_c + man6p_c
# FBP: fdp_c + h2o_c --> f6p_c + pi_c
# TALA: g3p_c + s7p_c --> e4p_c + f6p_c
# ABFPT: atp_c + fru_c --> adp_c + f6p_c
# FBA: dhap_c + g3p_c <=> fdp_c
# A6PAG2: atp_c + gal_bD_c --> adp_c + dgal6p_c
# FCLPA: fc1p_c <=> dhap_c + lald__L_c
# ID6P: f6p_c + itp_c --> fdp_c + idp_c
# FBA3: s17bp_c <=> dhap_c + e4p_c
# S7AP: atp_c + s7p_c --> adp_c + s17bp_c
# DGAK: Glc_aD_c --> fru_c
# MAN6PI: man6p_c <=> f6p_c
# M1PD: mnl1p_c + nad_c --> f6p_c + h_c + nadh_c
# SBTD_D2: nad_c + sbt__D_c <=> fru_c + h_c + nadh_c
# CD6P: ctp_c + f6p_c --> cdp_c + fdp_c
# UH1U: gal1p_c + utp_c --> ppi_c + udpgal_c
# FBA2: f1p_c --> dhap_c + glyald_c
# AD6P: atp_c + f6p_c --> adp_c + fdp_c
# MAN1PT: gtp_c + man1p_c --> gdpmann_c + ppi_c
# HEX7: atp_c + fru_B_c --> adp_c + f6p_c
# CT6PT: ctp_c + tag6p__D_c --> cdp_c + tagdp__D_c
# GALM2: gal_bD_c --> gal_c
# G6PI_1: g1p_c --> g1p_B_c
# AT6PT: atp_c + tag6p__D_c --> adp_c + tagdp__D_c
# GNTO: galt1p_c + nad_c <=> h_c + nadh_c + tag6p__D_c
# UGLT: gal1p_c + udpg_c --> g1p_c + udpgal_c
# UDPG4E: udpgal_c <=> udpg_c
# UT6PT: tag6p__D_c + utp_c --> tagdp__D_c + udp_c
# GALKr: atp_c + gal_c --> adp_c + gal1p_c + pi_c
# TGBPA: tagdp__D_c --> dhap_c + g3p_c
# IT6PT: itp_c + tag6p__D_c --> idp_c + tagdp__D_c
# GAL6PI: dgal6p_c --> tag6p__D_c
# GLYAT: 2aobut_c + coa_c --> accoa_c + gly_c
# SERDA: ser__L_c --> a2m2prpnte_c + h2o_c + h_c
# APDH: a2m2prpnte_c + h2o_c + h_c --> nh4_c + pyr_c
# GCCa: gly_c + lpro_c --> alpro_c + co2_c
# SERD_D: ser__D_c --> nh4_c + pyr_c
# HSDy: aspsa_c + h_c + nadph_c --> hom__L_c + nadp_c
# PSP_L: h2o_c + pser__L_c --> pi_c + ser__L_c
# ASPK: asp__L_c + atp_c --> 4pasp_c + adp_c
# THRA: thr__L_c --> acald_c + gly_c
# THRD: nad_c + thr__L_c --> 2aobut_c + h_c + nadh_c
# THRS: h2o_c + phom_c --> pi_c + thr__L_c
# BETALDHx: betald_c + h2o_c + nad_c --> glyb_c + h_c + nadh_c
# AMPTASECG: cgly_c + h2o_c --> cys__L_c + gly_c
# CHOLD2: chol_c + nadp_c --> betald_c + h_c + nadph_c
# THRD_L: thr__L_c --> 2obut_c + nh4_c
# GHMT2r: ser__L_c + thf_c <=> gly_c + h2o_c + mlthf_c
# PGCD: 3pg_c + nad_c --> 3php_c + h_c + nadh_c
# SERR: ser__L_c <=> ser__D_c
# PSERT: 3php_c + glu__L_c --> akg_c + pser__L_c
# HSDxi: aspsa_c + h_c + nadh_c --> hom__L_c + nad_c
# MANPGH: h2o_c + man6pglyc_c <=> glyc__R_c + man6p_c
# GLYCK: atp_c + glyc__R_c --> 3pg_c + adp_c
# HSK: atp_c + hom__L_c --> adp_c + phom_c
# ASAD: 4pasp_c + h_c + nadph_c --> aspsa_c + nadp_c + pi_c
# SER_AL: ser__L_c --> nh4_c + pyr_c
# ALAS: gly_c + succoa_c <=> 5aop_c + co2_c + coa_c
# CHOLD: chol_c + nad_c --> betald_c + h_c + nadh_c
# GAPDi_nadp: 13dpg_c + h_c + nadph_c --> g3p_c + nadp_c + pi_c
# ADGI: g6p_A_c --> f6p_c
# PPCK: atp_c + oaa_c --> adp_c + co2_c + pep_c
# GD3P2: g3p_c + h2o_c + nadp_c --> 3pg_c + h_c + nadph_c
# ACNO: acald_c + h2o_c + nad_c --> ac_c + h_c + nadh_c
# PGCM: g6p_A_c <=> g1p_c
# GCCc: dhlpro_c + nad_c --> h_c + lpro_c + nadh_c
# POR_syn: coa_c + fdxo_2_2_c + pyr_c --> accoa_c + co2_c + fdxrd_c + h_c
# PGM: 2pg_c <=> 3pg_c
# GLUKA: Glc_aD_c + atp_c --> adp_c + g6p_A_c
# G6PI3: f6p_c <=> g6p_c
# G6PI2: g6p_c <=> g6p_A_c
# GAPD: 13dpg_c + h_c + nadh_c --> g3p_c + nad_c + pi_c
# PGK: 3pg_c + atp_c <=> 13dpg_c + adp_c
# LDH_L: h_c + nadh_c + pyr_c --> lac__L_c + nad_c
# G1PP: g1p_c + h2o_c --> glc__D_c + pi_c
# HEX1: atp_c + glc__D_c --> adp_c + g6p_c
# GalMr: Glc_aD_c <=> glc__D_c
# XYLI2: glc__D_c --> fru_c
# TPI: g3p_c <=> dhap_c
# ENO: h2o_c + pep_c <=> 2pg_c
# ACS: ac_c + atp_c + coa_c --> accoa_c + amp_c + ppi_c
# ALCD2x: etoh_c + nad_c <=> acald_c + h_c + nadh_c
# PYK: adp_c + pep_c <=> atp_c + pyr_c
# PFK_adp: amp_c + fdp_c --> adp_c + f6p_c
# DGLACH: dgo15lac_c + h2o_c --> glcn_c
# OBFOX: 2obut_c + coa_c + fdxo_2_2_c --> co2_c + fdxrd_c + h_c + ppcoa_c
# HPYRI: 2h3oppan_c <=> hpyr_c
# SPT_syn: glx_c + ser__L_c <=> gly_c + hpyr_c
# GLYFEM: glyclt_c + h_c --> ac_c + co2_c + h2o_c + succ_c
# GCALDD: gcald_c + h2o_c + nad_c --> glyclt_c + h_c + nadh_c
# TRSARr: 2h3oppan_c + h_c + nadh_c --> glyc__R_c + nad_c
# GLYCL_2: gly_c + nad_c + thf_c --> co2_c + h_c + mlthf_c + nadh_c + nh4_c
# TRSARr2: 2h3oppan_c + h_c + nadph_c --> glyc__R_c + nadp_c
# GLYCO: h2o_c + i2ac_c --> glx_c + nh4_c
# FTHFD: 10fthf_c + h2o_c --> for_c + thf_c
# IG3PS: gln__L_c + prlp_c --> aicar_c + eig3p_c + glu__L_c
# PRAMPC: h2o_c + prbamp_c --> prfp_c
# HISTD: h2o_c + histd_c + nad_c <=> h_c + histda_c + nadh_c
# PRATPP: h2o_c + prbatp_c --> ppi_c + prbamp_c
# HISTP: h2o_c + hisp_c --> histd_c + pi_c
# ASLP: asp__L_c + co2_c + nh4_c <=> cbasp_c + h2o_c
# PRMICI: prfp_c --> prlp_c
# ATPPRT: atp_c + prpp_c --> ppi_c + prbatp_c
# HDH: h2o_c + histda_c + nad_c --> h_c + his__L_c + nadh_c
# HSTPT: glu__L_c + imacp_c --> akg_c + hisp_c
# IGPDH: eig3p_c --> h2o_c + imacp_c
# L2OA: h_c + isocaprecoa_c + nadh_c --> isocapcoa_c + nad_c
# H2CT: coa_c + h2isocap_c --> h2isocapcoa_c + h2o_c
# H2CD: h2isocapcoa_c + h_c --> h2o_c + isocaprecoa_c
# H2CPD: 4mop_c + h_c + nadh_c --> h2isocap_c + nad_c
# ICCT: h2o_c + isocapcoa_c --> coa_c + h_c + isocap_c
# DHDPS: aspsa_c + pyr_c --> 23dhdp_c + h2o_c
# HCITI: hcit_c <=> hicit_c
# PYAS: aspsa_c + pyr_c --> h2o_c + h_c + thdp_c
# SDPDS: h2o_c + sl2a6o_c --> 26dap_LL_c + succ_c
# UAAGDS: 26dap__M_c + atp_c + uamag_c --> adp_c + pi_c + ugmd_c
# DAPE: 26dap_LL_c --> 26dap__M_c
# HICITD: hicit_c + nad_c <=> 2oxoadp_c + co2_c + h_c + nadh_c
# AACT: accoa_c + akg_c + h2o_c <=> coa_c + hcit_c
# DHDPRy: 23dhdp_c + h_c + nadph_c --> h2o_c + nadp_c + thdp_c
# DHDPRx_r: 23dhdp_c + h_c + nadh_c --> nad_c + thdp_c
# SDPTA: glu__L_c + sl26da_c --> akg_c + sl2a6o_c
# THDPS: h2o_c + succoa_c + thdp_c --> coa_c + sl26da_c
# DAPDC: 26dap__M_c --> co2_c + lys__L_c
# LYSAM: lys__L_c --> 36dahx_c
# DH35O: dah35_c + h2o_c + nad_c --> a53oh_c + h_c + nadh_c + nh4_c
# A53C: a53oh_c + accoa_c --> ab3coa_c + acac_c
# AB3CL: ab3coa_c --> ctncoa_c + nh4_c
# DH36M: 36dahx_c --> dah35_c
# BUTCT2: acac_c + btcoa_c --> aacoa_c + but_c
# NP1: nicrns_c + pi_c <=> h_c + ncam_c + r1p_c
# NNDPR: h_c + prpp_c + quln_c --> co2_c + nicrnt_c + ppi_c
# NNAM: h2o_c + ncam_c --> nac_c + nh4_c
# NMNAT: atp_c + h_c + nmn_c --> nad_c + ppi_c
# NADS1: atp_c + dnad_c + nh4_c --> amp_c + nad_c + ppi_c
# NNATr: atp_c + nicrnt_c --> dnad_c + ppi_c
# NRRH: h2o_c + nicrns_c <=> h_c + ncam_c + rib__D_c
# ASPO2y: asp__L_c + nadp_c --> h_c + iasp_c + nadph_c
# NADS2: atp_c + dnad_c + gln__L_c + h2o_c --> amp_c + glu__L_c + nad_c + ppi_c
# ASPO2: asp__L_c + nad_c --> h_c + iasp_c + nadh_c
# NAPRT: atp_c + h2o_c + h_c + nac_c + prpp_c --> adp_c + nicrnt_c + pi_c + ppi_c
# NT5C: h2o_c + h_c + nmn_c --> nicrns_c + pi_c
# NADDP: h2o_c + nad_c --> amp_c + h_c + nmn_c
# NADDP2: h2o_c + nadp_c --> nad_c + pi_c
# QULNS: dhap_c + iasp_c --> h2o_c + pi_c + quln_c
# NADN: h2o_c + nad_c --> adprib_c + h_c + ncam_c
# NADK: atp_c + nad_c --> adp_c + nadp_c
# ASPO6: asp__L_c + fum_c --> iasp_c + succ_c
# NAR_syn: fdxo_2_2_c + h2o_c + no2_c <=> fdxrd_c + no3_c
# NITR: h_c + nad_c + no3_c --> h2o_c + nadh_c + no2_c
# NOR_syn: fdxo_2_2_c + h2o_c + nh4_c <=> fdxrd_c + h_c + no2_c
# NTRIRy: h_c + nadph_c + no2_c --> h2o_c + nadp_c + nh4_c
# HAMR: h2o_c + nad_c + nh4_c <=> h_c + ham_c + nadh_c
# NTRIR2x: h_c + nadh_c + no2_c --> h2o_c + nad_c + nh4_c
# FGFT: gar_c + h2o_c + methf_c --> fgam_c + h_c + thf_c
# FTCD: 5forthf_c + h_c --> methf_c + nh4_c
# THFOR2: dhf_c + h_c + nadph_c --> nadp_c + thf_c
# MRF: fdxrd_c + h_c + mlthf_c --> 5mthf_c + fdxo_2_2_c
# COMCOA: co_c + coa_c + fesm_c --> accoa_c + fes_c + h_c
# THFSP: fald_c + thf_c --> h2o_c + mlthf_c
# THFAT: h2o_c + methf_c --> 5fthf_c + h_c
# MTHFR2_1: h_c + mlthf_c + nadh_c --> 5mthf_c + nad_c
# MTHFC_1: 10fthf_c + h_c <=> h2o_c + methf_c
# MTHFD2: mlthf_c + nad_c --> methf_c + nadh_c
# MHFMT: 5mthf_c + fes_c + h_c --> fesm_c + thf_c
# FTHFCL: 5fthf_c + atp_c + h_c --> adp_c + methf_c + pi_c
# MTHFD: mlthf_c + nadp_c --> methf_c + nadph_c
# GCC2: alpro_c + thf_c --> dhlpro_c + mlthf_c + nh4_c
# FTHFLi: atp_c + for_c + thf_c --> 10fthf_c + adp_c + pi_c
# CMH2: co_c + h2o_c --> co2_c + h2_c
# SSCOARy: h_c + nadph_c + succoa_c --> coa_c + nadp_c + sucsal_c
# CO2FO: co2_c + fdxrd_c + h_c --> co_c + fdxo_2_2_c + h2o_c
# FNRR: fdxrd_c + h_c + nad_c <-- fdxo_2_2_c + nadh_c
# COAO: co_c + elecacceptoxi_c + h2o_c --> co2_c + elecacceptred_c
# FNRR2: fdxrd_c + h_c + nadp_c --> fdxo_2_2_c + nadph_c
# COR: co2_c + h_c + nadph_c --> for_c + nadp_c
# FRUpts: fru_e + pep_c --> f6p_c + pyr_c
# UACCpts: h2o_c + pep_c + uaccg_e --> pi_c + pyr_c + uaccg_c
# GALTpts: galt_e + pep_c --> galt1p_c + pyr_c
# MALTpts: malt_e + pep_c --> malt6p_c + pyr_c
# MANpts: man_e + pep_c --> man6p_c + pyr_c
# GLCADpts: Glc_aD_e + pep_c --> g6p_A_c + pyr_c
# MAN6Gpts: h2o_c + man6pglyc_e + pep_c --> man6pglyc_c + pi_c + pyr_c
# CELLBpts: cellb_e + pep_c --> cellb6p_c + pyr_c
# SUCpts: pep_c + sucr_e --> pyr_c + suc6p_c
# MNLpts: mnl_e + pep_c --> mnl1p_c + pyr_c
# DACHpts: dachi_e + pep_c --> chtbs6p_c + h_c + pyr_c
# FRUpts2: fru_e + pep_c --> f1p_c + pyr_c
# TGTpts: pep_c + tgt_e --> pyr_c + tag6p__D_c
# GLCpts: glc__D_e + pep_c --> g6p_c + pyr_c
# FUCpts: fuc_e + pep_c --> fc1p_c + pyr_c
# MOHMT: 3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c
# 2DHPFALDL: 2dhp_c <=> 3mob_c + fald_c
# PPCDC: 4ppcys_c --> co2_c + pan4p_c
# GCOADH: fad_c + gcoa_c --> fadh2_c + gccoa_c
# PBAL: ala_B_c + atp_c + pant__R_c --> amp_c + h_c + pnto__R_c + ppi_c
# PPNCL: 4ppan_c + atp_c + cys__L_c --> 4ppcys_c + amp_c + ppi_c
# PNTK: atp_c + pnto__R_c --> 4ppan_c + adp_c
# ACPPD: h2o_c + hacp_c --> aacp_c + pan4p_c
# PNCDC: ptcys_c <=> co2_c + ptth_c
# HACPS: aacp_c + coa_c --> hacp_c + pap_c
# DPCOAK: atp_c + dpcoa_c --> adp_c + coa_c
# PPNCL2: 4ppan_c + ctp_c + cys__L_c --> 4ppcys_c + cmp_c + ppi_c
# APNPT: atp_c + ptth_c --> adp_c + pan4p_c
# ACLS: pyr_c <=> alac__S_c + co2_c
# APCPT: atp_c + ptcys_c --> 4ppcys_c + adp_c
# MCOATA: h_c + hacp_c + malcoa_c --> coa_c + malacp_c
# DPR: 2dhp_c + h_c + nadph_c --> nadp_c + pant__R_c
# PTPATi: atp_c + pan4p_c --> dpcoa_c + ppi_c
# GALUi: g1p_c + utp_c --> ppi_c + udpg_c
# R5P2D: nadp_c + ribl5p_c --> h_c + nadph_c + ru5p__D_c
# R5P2D2: nad_c + ribl5p_c --> h_c + nadh_c + ru5p__D_c
# ARAI: arab__L_c --> rbl__L_c
# TAGURr: h_c + nadh_c + tagur_c --> altrn_c + nad_c
# ALTRH: altrn_c --> 2ddglcn_c + h2o_c
# XYLK: atp_c + xylu__D_c --> adp_c + xu5p__D_c
# RBK_L1: atp_c + rbl__L_c --> adp_c + ru5p__L_c
# RBP4E: ru5p__L_c <=> xu5p__D_c
# XYLI1: xyl__D_c <=> xylu__D_c
# TKT2: e4p_c + xu5p__D_c --> f6p_c + g3p_c
# RPE: ru5p__D_c --> xu5p__D_c
# GNK: atp_c + glcn_c --> 6pgc_c + adp_c
# DX5PL: pi_c + xu5p__D_c --> actp_c + g3p_c + h2o_c
# PRPPS: atp_c + r5p_c <=> amp_c + prpp_c
# RPI: ru5p__D_c --> r5p_c
# PPM: r1p_c --> r5p_c
# EDA: 2ddg6p_c --> g3p_c + pyr_c
# GND: 6pgc_c + nadp_c --> co2_c + h_c + nadph_c + ru5p__D_c
# DDGLK: 2ddglcn_c + atp_c --> 2ddg6p_c + adp_c
# SBP: h2o_c + s17bp_c --> pi_c + s7p_c
# GLYCK2: atp_c + glyc__R_c --> 2pg_c + adp_c
# EDD: 6pgc_c --> 2ddg6p_c + h2o_c
# DRBK: atp_c + drib_c <=> 2dr5p_c + adp_c
# PGL: 6pgl_c + h2o_c --> 6pgc_c
# RBK: atp_c + rib__D_c --> adp_c + r5p_c
# TKT1: r5p_c + xu5p__D_c --> g3p_c + s7p_c
# PPM2: d2rib1p_c --> 2dr5p_c
# PTAr: accoa_c + pi_c <=> actp_c + coa_c
# DGUO: glc__D_c + q8h2_c --> dgo15lac_c + q8_c
# DRPA: 2dr5p_c --> acald_c + g3p_c
# SHKK: atp_c + skm_c --> adp_c + skm5p_c
# 4HALDD: 4hoxpacd_c + h2o_c + nad_c <=> 4hphac_c + h_c + nadh_c
# PPND: nad_c + pphn_c --> 34hpp_c + co2_c + h_c + nadh_c
# PPNDH: pphn_c --> co2_c + h2o_c + phpyr_c
# AROAT: glu__L_c + pphn_c --> Largn_c + akg_c
# SHK3Dr: 3dhsk_c + h_c + nadph_c --> nadp_c + skm_c
# CHORS: 3psme_c --> chor_c + pi_c
# DHQS: 2dda7p_c --> 3dhq_c + pi_c
# SKDH: 3dhsk_c + h_c + nadh_c --> nad_c + skm_c
# AROH: Largn_c <=> co2_c + h2o_c + phe__L_c
# ARNO: Largn_c + nad_c --> co2_c + h_c + nadh_c + tyr__L_c
# PSCVT: pep_c + skm5p_c --> 3psme_c + pi_c
# CHORM: chor_c --> pphn_c
# DHQTi: 3dhq_c --> 3dhsk_c + h2o_c
# C4HP: 34hpp_c <=> 4hoxpacd_c + co2_c
# PHETA1: akg_c + phe__L_c <=> glu__L_c + phpyr_c
# DDPA: e4p_c + h2o_c + pep_c --> 2dda7p_c + pi_c
# O2XOADOX: 2oxoadp_c + coa_c + nad_c <=> co2_c + gcoa_c + h_c + nadh_c
# HPH4CL: 4hphac_c --> co2_c + m4po_c
# P3PCL: p3pyr_c <=> Pald_c + co2_c
# AEPPYRTA: 2ameph_c + pyr_c --> Pald_c + ala__L_c
# PALDH: Pald_c + h2o_c --> acald_c + pi_c
# PPPM: pep_c <=> p3pyr_c
# ACALD: acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c
# PHHL: h2o_c + ppac_c <=> ac_c + pi_c
# PHNO: h2o_c + nad_c + ppat_c <=> h_c + nadh_c + pi_c
# PPA: h2o_c + ppi_c <=> pi_c
# PHHL2: Pald_c + h2o_c + nad_c --> h_c + nadh_c + ppac_c
# PPA2: h2o_c + pppi_c <=> pi_c + ppi_c
# UI45AH: h2o_c + u45imzc_c --> a45imzc_c + co2_c + nh4_c
# ANTDR: atp_c + fmnh2_c --> datp_c + fmn_c + h2o_c
# NTD10: h2o_c + xmp_c --> pi_c + xtsn_c
# XTSNH: h2o_c + xtsn_c --> rib__D_c + xan_c
# DADNK: atp_c + dad_2_c --> adp_c + damp_c
# GLYR: gly_c + pi_c + selprotein_c + trdrd_c --> actp_c + h2o_c + nh4_c + trdox_c
# PUNP7E: din_c + pi_c <=> 2dr1p_c + hxan_c
# NTD7: amp_c + h2o_c --> adn_c + pi_c
# HXAND: h2o_c + hxan_c + nad_c --> h_c + nadh_c + xan_c
# HXIMP: hxan_c + prpp_c --> imp_c + ppi_c
# NDPK5: atp_c + dgdp_c --> adp_c + dgtp_c
# ADPRDP: amp_c + r5p_c <=> adprib_c + h2o_c
# AI4AH: a4imz_c + h2o_c --> i4mzo_c + nh4_c
# DGK1: atp_c + dgmp_c --> adp_c + dgdp_c
# UI45DC: a45imzc_c --> a4imz_c + co2_c
# XPPT: prpp_c + xan_c --> ppi_c + xmp_c
# ADK1: amp_c + atp_c --> adp_c
# DGNSK: atp_c + dgsn_c --> adp_c + dgmp_c
# GLUPRT: gln__L_c + h2o_c + prpp_c --> glu__L_c + ppi_c + pram_c
# GNNUC: gsn_c + h2o_c --> gua_c + rib__D_c
# GDPDPK: atp_c + gdp_c --> amp_c + ppgpp_c
# FTHFGFT: fgly_c + thf_c --> 5forthf_c + gly_c
# GDPTPDP: h2o_c + ppgpp_c --> gdp_c + ppi_c
# GPAR: gua_c + prpp_c --> gmp_c + ppi_c
# PRFGCL: atp_c + fpram_c --> adp_c + air_c + pi_c
# PUNP5: ins_c + pi_c --> hxan_c + r1p_c
# NTD9: gmp_c + h2o_c --> gsn_c + pi_c
# XAH: h2o_c + xan_c --> u45imzc_c
# INSH: h2o_c + ins_c --> hxan_c + rib__D_c
# PUNP2: dad_2_c + pi_c --> 2dr1p_c + ade_c
# DADK: atp_c + damp_c --> adp_c + dadp_c
# GDTPR: h2o_c + pppgpp_c --> pi_c + ppgpp_c
# DADA: dad_2_c + h2o_c --> din_c + nh4_c
# NTD6: damp_c + h2o_c --> dad_2_c + pi_c
# GK1: atp_c + gmp_c --> adp_c + gdp_c
# GART: atp_c + for_c + gar_c --> adp_c + fgam_c + pi_c
# ADSL2r: 25aics_c --> aicar_c + fum_c
# AP3S: adp_c + atp_c --> p1p3b5adtp_c + ppi_c
# PRFGS: atp_c + fgam_c + gln__L_c + h2o_c --> adp_c + fpram_c + glu__L_c + pi_c
# HXPRT: hxan_c + prpp_c --> imp_c + ppi_c
# PUNP4: dgsn_c + pi_c <=> 2dr1p_c + gua_c
# ADA: adn_c + h2o_c --> ins_c + nh4_c
# IMPC: fprica_c --> h2o_c + imp_c
# GARFT: 10fthf_c + gar_c --> fgam_c + thf_c
# NDPK8: atp_c + dadp_c --> adp_c + datp_c
# R1PI: 2dr1p_c <=> d2rib1p_c
# ADSL1r: dcamp_c --> amp_c + fum_c
# GMPS2: atp_c + gln__L_c + h2o_c + xmp_c --> amp_c + glu__L_c + gmp_c + ppi_c
# GUAD: gua_c + h2o_c --> nh4_c + xan_c
# RNDR1: adp_c + trdrd_c <=> dadp_c + h2o_c + trdox_c
# AICART: 10fthf_c + aicar_c --> fprica_c + thf_c
# PRASCSi: 5aizc_c + asp__L_c + atp_c --> 25aics_c + adp_c + pi_c
# TPHAP: h2o_c + p1p3b5adtp_c --> adp_c + amp_c
# ADSS: asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + pi_c
# ADPT: ade_c + prpp_c --> amp_c + ppi_c
# IM4A: h2o_c + i4mzo_c --> fgly_c
# RNTR2: fmnh2_c + gtp_c --> dgtp_c + fmn_c + h2o_c
# NDPK1: atp_c + gdp_c --> adp_c + gtp_c
# PUNP7: pi_c + xtsn_c --> r1p_c + xan_c
# PUNP1: adn_c + pi_c --> ade_c + r1p_c
# PPRGL: atp_c + gly_c + pram_c --> adp_c + gar_c + pi_c
# NTD8: dgmp_c + h2o_c --> dgsn_c + pi_c
# PUNP3: gsn_c + pi_c --> gua_c + r1p_c
# AIRCr: air_c + co2_c <=> 5aizc_c
# NTP1: atp_c + h2o_c --> adp_c + pi_c
# X5PAL: atp_c + nh4_c + xmp_c --> amp_c + gmp_c + ppi_c
# RNDR2: gdp_c + trdrd_c --> dgdp_c + h2o_c + trdox_c
# CBMKr: adp_c + cbp_c --> atp_c + co2_c + nh4_c
# IMPD: h2o_c + imp_c + nad_c --> h_c + nadh_c + xmp_c
# THIELEC: elecacceptoxi_c + trdrd_c --> elecacceptred_c + trdox_c
# THIH: trdrd_c --> h_c + trdox_c
# GDPDPKE: atp_c + gtp_c --> amp_c + pppgpp_c
# PPGPPDPE: h2o_c + pppgpp_c --> gtp_c + ppi_c
# ADNUC: adn_c + h2o_c --> ade_c + rib__D_c
# ASPCMY: asp__L_c + cmylphosph_c --> h_c + ncmylasp_c + pi_c
# DHNCM: dhor__S_c + h2o_c <=> h_c + ncmylasp_c
# DCTCP: cytd_c + dctp_c --> cmp_c + dcdp_c
# URIDK2r: atp_c + dump_c --> adp_c + dudp_c
# RNTR4: fmnh2_c + utp_c --> dutp_c + fmn_c + h2o_c
# U3IBA: 3uib_c + h2o_c --> 3aib__D_c + co2_c + nh4_c
# RNDR4: trdrd_c + udp_c --> dudp_c + h2o_c + trdox_c
# PYK5: idp_c + pep_c --> itp_c + pyr_c
# CYTK1: atp_c + cmp_c --> adp_c + cdp_c
# UTUP: uri_c + utp_c --> udp_c + ump_c
# DATCY: cytd_c + datp_c --> cmp_c + dadp_c
# ORPT: orot_c + prpp_c --> orot5p_c + ppi_c
# PYK4: cdp_c + pep_c --> ctp_c + pyr_c
# RNDR3: cdp_c + trdrd_c --> dcdp_c + h2o_c + trdox_c
# DCTUP: dctp_c + uri_c --> dcdp_c + ump_c
# DGTCY: cytd_c + dgtp_c --> cmp_c + dgdp_c
# CYTDK1: atp_c + cytd_c --> adp_c + cmp_c
# DHPM1: 56dura_c + h2o_c --> cala_c
# DCTPD: dctp_c + h2o_c --> dutp_c + nh4_c
# UMPK: atp_c + ump_c --> adp_c + udp_c
# ASPCT: asp__L_c + cbp_c --> cbasp_c + pi_c
# TMDPP: pi_c + thymd_c <=> 2dr1p_c + thym_c
# NTP5: ctp_c + h2o_c --> cdp_c + pi_c
# PYNP2r: pi_c + uri_c --> r1p_c + ura_c
# DURAD: h_c + nadph_c + ura_c --> 56dura_c + nadp_c
# CSND: csn_c + h2o_c --> nh4_c + ura_c
# CTPS2: atp_c + gln__L_c + h2o_c + utp_c --> adp_c + ctp_c + glu__L_c + pi_c
# SDQO: dhor__S_c + q8h2_c --> orot_c + q8_c
# URIK1: atp_c + uri_c --> adp_c + ump_c
# CBPS: atp_c + gln__L_c + h2o_c + h_c + hco3_c --> adp_c + cbp_c + glu__L_c + pi_c
# TMDK1: atp_c + thymd_c --> adp_c + dtmp_c
# DHPM2: 56dthm_c + h2o_c --> 3uib_c
# NDPK4: atp_c + dtdp_c --> adp_c + dttp_c
# CYTDK2: cytd_c + gtp_c --> cmp_c + gdp_c
# NDPK7: atp_c + dcdp_c --> adp_c + dctp_c
# TMDS3: dump_c + h_c + mlthf_c + nadph_c --> dtmp_c + nadp_c + thf_c
# URIK2: gtp_c + uri_c --> gdp_c + ump_c
# PYNP1: cytd_c + pi_c <=> csn_c + r1p_c
# NDPK3: atp_c + cdp_c --> adp_c + ctp_c
# DURIPP: duri_c + pi_c --> 2dr1p_c + ura_c
# DHORTS: cbasp_c --> dhor__S_c + h2o_c
# NTPP4: ctp_c + h2o_c --> cmp_c + pi_c
# DTTUP: dttp_c + uri_c --> dtdp_c + ump_c
# DCYTD: dcyt_c + h2o_c --> duri_c + nh4_c
# ITCY: cytd_c + itp_c --> cmp_c + idp_c
# NDP7: h2o_c + udp_c --> pi_c + ump_c
# NDPK2: atp_c + udp_c --> adp_c + utp_c
# NTD3: dcmp_c + h2o_c <=> dcyt_c + pi_c
# DUTPDP: dutp_c + h2o_c --> dump_c + ppi_c
# UPPN: cala_c + h2o_c --> ala_B_c + co2_c + nh4_c
# CPS: atp_c + h_c + hco3_c + nh4_c --> adp_c + cbp_c + pi_c
# DTMPK: atp_c + dtmp_c --> adp_c + dtdp_c
# CDPPH: cdp_c + h2o_c --> cmp_c + pi_c
# URIK3: itp_c + uri_c --> idp_c + ump_c
# UTCY: cytd_c + utp_c --> cmp_c + udp_c
# PYK2: pep_c + udp_c --> pyr_c + utp_c
# DUTUP: dutp_c + uri_c --> dudp_c + ump_c
# RNTR3: ctp_c + fmnh2_c --> dctp_c + fmn_c + h2o_c
# UPPRT: prpp_c + ura_c --> ppi_c + ump_c
# TMDS: dump_c + mlthf_c --> dhf_c + dtmp_c
# OMPDC: orot5p_c --> co2_c + ump_c
# DURAD2: h_c + nadph_c + thym_c --> 56dthm_c + nadp_c
# DUTCP: cytd_c + dutp_c --> cmp_c + dudp_c
# DATUP: datp_c + uri_c --> dadp_c + ump_c
# CYTK2: atp_c + dcmp_c --> adp_c + dcdp_c
# NTP7: h2o_c + utp_c --> pi_c + udp_c
# DCMPDA: dcmp_c + h2o_c --> dump_c + nh4_c
# TRDR: h_c + nadph_c + trdox_c --> nadp_c + trdrd_c
# PURGL: h2o_c + psuri5p_c --> r5p_c + ura_c
# CYTD: cytd_c + h2o_c --> nh4_c + uri_c
# URIH: h2o_c + uri_c --> rib__D_c + ura_c
# NDPK6: atp_c + dudp_c --> adp_c + dutp_c
# NTD5: dtmp_c + h2o_c --> pi_c + thymd_c
# DGTUP: dgtp_c + uri_c --> dgdp_c + ump_c
# DTTGY: cytd_c + dttp_c --> cmp_c + dtdp_c
# ACCOAC: accoa_c + atp_c + h_c + hco3_c --> adp_c + malcoa_c + pi_c
# VNAATPS: adp_c + na1_e + pi_c --> atp_c + h2o_c + na1_c
# OAADC: oaa_c --> co2_c + pyr_c
# PDH: coa_c + nad_c + pyr_c --> accoa_c + co2_c + h_c + nadh_c
# LCADi: h2o_c + lald__L_c + nad_c <=> h_c + lac__L_c + nadh_c
# ATPS4r: adp_c + h_e + pi_c --> atp_c + h2o_c + h_c
# LQ8P: lac__D_c + q8h2_c --> pyr_c + q8_c
# LacR: lac__L_c <=> lac__D_c
# ACKr: actp_c + adp_c <=> ac_c + atp_c
# PPDK: atp_c + pi_c + pyr_c --> amp_c + pep_c + ppi_c
# PPS: atp_c + h2o_c + pyr_c --> amp_c + pep_c + pi_c
# D3AIBT: 3aib__D_c + pyr_c <=> 2mop_c + ala__L_c
# LDH_D: h_c + nadh_c + pyr_c --> lac__D_c + nad_c
# MLG: gthrd_c + mthgxl_c --> lacgth_c
# PANO: h2o_c + mthgxl_c + nad_c --> h_c + nadh_c + pyr_c
# SUCOAACTr: accoa_c + succ_c --> ac_c + succoa_c
# SLGH: h2o_c + lacgth_c --> gthrd_c + lac__D_c
# ADCi: acac_c --> acetone_c + co2_c
# FRD2: fum_c + mql8_c --> mqn8_c + succ_c
# ME1: mal__L_c + nad_c --> co2_c + h_c + nadh_c + pyr_c
# MGSA: dhap_c --> mthgxl_c + pi_c
# PFL: coa_c + pyr_c --> accoa_c + for_c
# HAAOR: elecacceptoxi_c + lac__D_c --> elecacceptred_c + pyr_c
# MCPST: cyan_c + mercppyr_c --> pyr_c + tcynt_c
# L_LACD3: lac__D_c + mqn8_c --> mql8_c + pyr_c
# FMNAT: atp_c + fmn_c --> fad_c + ppi_c
# RBFK: atp_c + ribflv_c --> adp_c + fmn_c
# DB4PS: ru5p__D_c --> db4p_c + for_c
# PMDPHT: 5aprbu_c + h2o_c --> 4r5au_c + pi_c
# GTPCII2: gtp_c + h2o_c --> 25drapp_c + for_c + ppi_c
# RBFSa: 4r5au_c + db4p_c --> dmlz_c + h2o_c + pi_c
# DHPPDA2: 25drapp_c + h2o_c --> 5apru_c + nh4_c
# APRAUR: 5apru_c + h_c + nadph_c --> 5aprbu_c + nadp_c
# RBFSb: dmlz_c --> 4r5au_c + ribflv_c
# ADPGLC: adpglc_c + h2o_c --> amp_c + g1p_c
# FFSD: h2o_c + suc6p_c --> fru_B_c + g6p_c
# CLBH: cellb_c + h2o_c <=> glc__D_c
# GLGC: atp_c + g1p_c --> adpglc_c + ppi_c
# AGA: h2o_c + sucr_c --> fru_c + glc__D_c
# DC6PH: chtbs6p_c + h2o_c + h_c --> acgam6p_c + acgam_c
# 6PHBG: cellb6p_c + h2o_c --> g6p_c + glc__D_c
# ESCHL: escul_c + h2o_c <=> escut_c + glc__D_c
# MAL6PG: h2o_c + malt6p_c <=> g6p_c + glc__D_c
# G6PBDH: g6p_c + nadp_c --> 6pgl_c + h_c + nadph_c
# RAFGH: h2o_c + raffin_c --> gal_c + sucr_c
# PGMT: g1p_B_c --> g6p_c
# TRE6PH: h2o_c + tre6p_c --> g6p_c + glc__D_c
# MPL: malt_c + pi_c --> g1p_B_c + glc__D_c
# SR1: h_c + nadh_c + pro__D_c + selprotein_c --> a5pn_c + nad_c + pmf_c
# SR2: accoa_c + co2_c + nad_c + nadph_c + pmf_c --> coa_c + mal__L_c + nadh_c + nadp_c
# SR3: adp_c + isobutp_c --> atp_c + isobuta_c
# OAKGB: adp_c + m2butp_c --> atp_c + m2but_c
# GLP5H: akg_c + orn_c --> glu__L_c + glusemald_c
# P5CN: glusemald_c <=> h2o_c + pyr5carb_c
# ICN: nadph_c + pyr5carb_c <=> nadp_c + pro__L_c
# SR4: 2mbald_c + coa_c + nad_c <=> h_c + ibcoa_c + nadh_c
# SR5: glyb_c + pi_c + trdrd_c --> actp_c + h2o_c + tmam_c + trdox_c
# PTA2E: ivcoa_c + pi_c --> coa_c + ppap_c
# ALATA_D: akg_c + ala__D_c --> glu__D_c + pyr_c
# PIBT: ibcoa_c + pi_c --> coa_c + isobutp_c
# OIVD2E: 3mop_c + coa_c + nad_c --> co2_c + h_c + m2bcoa_c + nadh_c
# IPPT: adp_c + ppap_c <=> atp_c + ival_c
# ILETAR: 3mop_c + glu__L_c --> akg_c + ile__L_c
# M2BCT: m2bcoa_c + pi_c --> coa_c + m2butp_c
# OIVD1r: 4mop_c + coa_c + nad_c --> co2_c + h_c + ivcoa_c + nadh_c
# VOR2bE: 3mob_c + coa_c + fdxo_2_2_c --> co2_c + fdxrd_c + ibcoa_c
# SULRR: h_c + nadh_c + so3_c --> h2o_c + h2s_c + nad_c
# SULR_syn: fdxo_2_2_c + h2o_c + h2s_c --> fdxrd_c + h_c + so3_c
# r0595E: mercppyr_c + so3_c <=> h_c + pyr_c + tsul_c
# SFRR: h_c + so3_c --> h2o_c + h2s_c
# CYANST: cyan_c + h_c + tsul_c --> so3_c + tcynt_c
# SULRR2: h_c + nadph_c + so3_c --> h2o_c + h2s_c + nadp_c
# BPNT: h2o_c + pap_c --> amp_c + pi_c
# HEXTT: hexdp_c + ipdp_c --> hepdp_c + ppi_c
# LPTAB1: ala__D_c + gpgl_c + phosglcdihexdec_c --> lpteichoic_c
# LPTAB2: ala__D_c + gpgl_c + phosglcditetdec_c --> lpteichoic_c
# LPTAB3: ala__D_c + gpgl_c + phosglcdioctdec_c --> lpteichoic_c
# UAGPT3: uacmam_c + unaga_c --> abdmagdpu_c + udp_c
# ACGAMT: uacgam_c + udcpp_c --> ump_c + unaga_c
# LYST1: lys__L_c + phosglcdihexdec_c <=> h2o_c + palmphgl_c
# LYST2: lys__L_c + phosglcditetdec_c <=> h2o_c + myrphgl_c
# LYST3: lys__L_c + phosglcdioctdec_c <=> h2o_c + strphglc_c
# CDPGH: abdmagdpu_c + cdpg_c --> cmp_c + teichoic_c
# GRTT: grdp_c + ipdp_c <=> frdp_c + ppi_c
# IPDPS2: h2mb4p_c + h_c + nadph_c --> h2o_c + ipdp_c + nadp_c
# DMPPS_syn: h2mb4p_c + h_c + nadph_c --> dmpp_c + h2o_c + nadp_c
# MVNOR: coa_c + mevR_c + nad_c --> h_c + hmgcoa_c + nadh_c
# CDPMEK: 4c2me_c + atp_c <=> 2p4c2me_c + adp_c
# MEPCT: 2me4p_c + ctp_c <=> 4c2me_c + ppi_c
# MECDPDH4E: 2mecdp_c + fdxrd_c + h_c <=> fdxo_2_2_c + h2mb4p_c + h2o_c
# DXPRIi: dxyl5p_c + h_c + nadph_c <=> 2me4p_c + nadp_c
# FDIPDC: frdp_c + ipdp_c --> ppi_c + udcpdp_c
# FRTT: frdp_c + ipdp_c --> ggdp_c + ppi_c
# DMATT: dmpp_c + ipdp_c --> grdp_c + ppi_c
# UDCPDP: h2o_c + udcpdp_c <=> pi_c + udcpp_c
# GGTT: ggdp_c + ipdp_c --> pendp_c + ppi_c
# HMGL: hmgcoa_c --> acac_c + accoa_c
# IPDDI: dmpp_c <=> ipdp_c
# IPDPS: h2mb4p_c + h_c + nadh_c --> h2o_c + ipdp_c + nad_c
# MECDPS: 2p4c2me_c --> 2mecdp_c + cmp_c
# DMPPS: h2mb4p_c + h_c + nadh_c --> dmpp_c + h2o_c + nad_c
# PPTT: ipdp_c + pendp_c --> hexdp_c + ppi_c
# TYRL: amet_c + elecacceptred_c + tyr__L_c --> dad_5_c + elecacceptoxi_c + i2ac_c + m4po_c + met__L_c
# X5TDG: thmpp_c + xu5p__D_c --> dhettp_c + g3p_c + h_c
# HETZK: 4mhetz_c + atp_c --> 4mpetz_c + adp_c
# TMPPP: 4ampm_c + 4mpetz_c + h_c --> ppi_c + thmmp_c
# PPS2: air_c + amet_c --> 2mahmp_c + co_c + dad_2_c + for_c + met__L_c
# PPS5: air_c + amet_c --> 2mahmp_c + co_c + dad_5_c + for_c + met__L_c
# MX15PSL: 2h3k5m_c + h_c --> ch4s_c + dxyl5p_c
# PMPK: 2mahmp_c + atp_c --> 4ampm_c + adp_c
# S7PTDG: s7p_c + thmpp_c --> dhettp_c + h_c + r5p_c
# DAPAL: 23dappa_c + h2o_c --> nh4_c + pyr_c
# DXPS: g3p_c + pyr_c --> co2_c + dxyl5p_c
# TMK: atp_c + thm_c --> adp_c + thmmp_c
# M45TB: cys__L_c + g3p_c + gly_c + pyr_c --> 4mhetz_c + ala__L_c + co2_c + h2o_c + pi_c
# TMDPK: atp_c + thm_c --> amp_c + thmpp_c
# TMPK: atp_c + thmmp_c --> adp_c + thmpp_c
# AKGt: akg_e <=> akg_c
# MEVRt: mevR_e <=> mevR_c
# XYLt: xyl__D_e --> xyl__D_c
# IBUTt: isobuta_c --> isobuta_e
# FE2t: fe2_e --> fe2_c
# IVALt: ival_c --> ival_e
# DHPt: dhptd_c --> dhptd_e
# Ht: h_e --> h_c
# DH23t: 23dhb_c --> d23hb_e
# HAMt: ham_e --> ham_c
# GTHOXt: gthox_e <=> gthox_c
# GTHRDtr: gthrd_e <=> gthrd_c
# FUMtr: fum_e <=> fum_c
# ESCULt: escul_e --> escul_c
# D23APt: 23dappa_e --> 23dappa_c
# PYDXNtr: pydxn_e <=> pydxn_c
# ESCUTt: escut_c --> escut_e
# AM2Et: 2ameph_e --> 2ameph_c
# BTNt: btn_e --> btn_c
# PNTRt: pnto__R_e <=> pnto__R_c
# CDPGt: cdpg_e --> cdpg_c
# IBTOLt: ibtol_c --> ibtol_e
# COBYt: cobalt2_e --> cobalt2_c
# GLYCt: glyc_e <=> glyc_c
# M2Bt: m2but_c --> m2but_e
# ADtr: ad_c --> ad_e
# NACt: nac_e --> nac_c
# ETHAt: etha_e --> etha_c
# A5PNt: a5pn_c --> a5pn_e
# DTBTt: dtbt_e --> dtbt_c
# THMt: thm_e <=> thm_c
# ABZ4t: 4abz_e --> 4abz_c
# M4POt: m4po_c --> m4po_e
# PIt: pi_e <=> pi_c
# ICAPt: isocap_c --> isocap_e
# NH4t: nh4_e <=> nh4_c
# NCAMt: ncam_e --> ncam_c
# TMAMt: tmam_e <=> tmam_c
# SUCCt: succ_e <=> succ_c
# NPHS: sbzcoa_c <=> coa_c + dhna_c
# NADPHQR3: h_c + mqn8_c + nadh_c --> mql8_c + nad_c
# SEPHCHCS: akg_c + ichor_c <=> 2shchc_c + co2_c + pyr_c
# TYAKGA: akg_c + tyr__L_c <=> 34hpp_c + glu__L_c
# DHNAOT4: dhna_c + octdp_c --> 2dmmql8_c + co2_c + ppi_c
# AMMQLT8: 2dmmql8_c + amet_c --> ahcys_c + mqn8_c
# OCTDPS: hepdp_c + ipdp_c --> octdp_c + ppi_c
# SUCBZS: 2shchc_c <=> h2o_c + sucbz_c
# ICHORS: chor_c --> ichor_c
# SUCBZL: atp_c + coa_c + sucbz_c --> amp_c + ppi_c + sbzcoa_c
# IPPS: 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c
# ECOAH9ir: 2mb2coa_c + h2o_c --> 3hmbcoa_c
# IPMD: 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c
# HACD9: 3hmbcoa_c + nad_c --> 2maacoa_c + h_c + nadh_c
# 3MOPDC: 3mob_c + h_c --> 2mbald_c + co2_c
# IPPMIa: 3c3hmp_c --> 2ippm_c + h2o_c
# VALTA: akg_c + val__L_c --> 3mob_c + glu__L_c
# IPPMIb: 2ippm_c + h2o_c --> 3c2hmp_c
# DHAD2: 23dhmp_c --> 3mop_c + h2o_c
# VPAMTr: pyr_c + val__L_c --> 3mob_c + ala__L_c
# MB2CFO: fad_c + m2bcoa_c --> 2mb2coa_c + fadh2_c
# ACHBS: 2obut_c + pyr_c --> 2ahbut_c + co2_c
# KARA2: 2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c
# MACCOAT: 2maacoa_c + coa_c --> accoa_c + ppcoa_c
# OMCDC: 3c4mop_c --> 4mop_c + co2_c
# IBHH: 2mbald_c + h_c + nadh_c <=> ibtol_c + nad_c
# MMSAD1: 2mop_c + coa_c + nad_c <=> co2_c + h_c + nadh_c + ppcoa_c
# PCFPT: 2obut_c + coa_c <=> for_c + ppcoa_c
# CNOR: copre6_c + h_c + nadh_c --> codhpre6_c + nad_c
# SHCHD2: dscl_c + nad_c --> h_c + nadh_c + scl_c
# CYRDAAT: atp_c + co1dam_c --> adcobdam_c + pppi_c
# ALMPC: amet_c + pc1_c --> ahcys_c + dscl_c
# ACBIPGT: acap_c + gtp_c --> agdpcbi_c + ppi_c
# NNDMBRT: dmbzid_c + nicrnt_c --> 5prdmbz_c + h_c + nac_c
# CPPPGO2: amet_c + cpppg3_c --> co2_c + dad_5_c + met__L_c + pppg9_c
# BTS4E: amet_c + dtbt_c + ssc_c --> btn_c + dad_5_c + met__L_c + unsc_c
# UPP3S: hmbil_c <=> h2o_c + uppg3_c
# THRPDC: thrp_c <=> applp_c + co2_c
# ADOCBIK: adocbi_c + atp_c --> adocbip_c + adp_c
# UPP3MT: amet_c + uppg3_c --> ahcys_c + dscl_c
# ABCK: adocbi_c + gtp_c <=> adocbip_c + gdp_c
# CPC2MTE: amet_c + cbshclin_c --> ahcys_c + cbflll_c
# UPPDC1: uppg3_c <=> co2_c + cpppg3_c
# BACCL: atp_c + btn_c --> btamp_c + ppi_c
# CODSCL5BMT: amet_c + codscl5b_c + h_c --> ahcys_c + copre6_c
# DHBD: 23ddhb_c + nad_c --> 23dhb_c + h2o_c + h_c + nadh_c
# CP3S: cbflll_c + elecacceptred_c <=> copre3_c + elecacceptoxi_c
# ADOCBLS1: agdpcbi_c + rdmbzi_c --> adcobdam_c + gmp_c + h_c
# ICHORT: h2o_c + ichor_c --> 23ddhb_c + pyr_c
# CP7MT: amet_c + codhpre6_c --> ahcys_c + cbpcr7_c + co2_c
# CBIATE: atp_c + c1yda_c + h_c --> acbda_c + pppi_c
# CYRDAR2: co2dam_c + fmnh2_c --> c1yda_c + fmn_c + h_c
# P9DH: mqn8_c + pppg9_c --> mql8_c + ppp9_c
# ADCPS1E: acb_c + applp_c + atp_c --> acap_c + adp_c + pi_c
# AP7MT: amet_c + cbpcr7_c --> ahcys_c + cbpcr8x_c
# PGAL: h2o_c + pbng_c <=> hmbil_c + nh4_c
# AH5L: 5aop_c <=> h2o_c + pbng_c
# ADCYRSE: acbda_c + atp_c + gln__L_c + h2o_c --> acb_c + adp_c + glu__L_c + pi_c
# CPC8MM: cbpcr8x_c --> cobya_c
# CODSCL4MT: amet_c + copre4_c --> ahcys_c + codscl5a_c
# FCLT: fe2_c + ppp9_c --> h_c + pheme_c
# CPC6R: copre6_c + h_c + nadph_c --> codhpre6_c + nadp_c
# RZ5PP: 5prdmbz_c + h2o_c --> pi_c + rdmbzi_c
# SAMU3: amet_c + uppg3_c --> ahcys_c + pc1_c
# CPC3MT: amet_c + copre3_c --> ahcys_c + copre4_c
# CLGAL: atp_c + cobya_c + gln__L_c + h2o_c --> adp_c + co2dam_c + glu__L_c + pi_c
# ADOCBLS2: 5prdmbz_c + agdpcbi_c --> adocbl_c + gmp_c + h_c
# SCL: cobalt2_c + scl_c <=> cbshclin_c + h_c
# CODSCL5DA: codscl5a_c + h2o_c --> acald_c + codscl5b_c
# ACARP: adocbl_c + h2o_c <=> adcobdam_c + pi_c
# PPATTT: pydam_c + pyr_c --> ala__L_c + pydx_c
# PYDXK: atp_c + pydam_c --> adp_c + pyam5p_c
# P5P2AK: pyam5p_c + pyr_c --> ala__D_c + pydx5p_c
# PYDXOR: h_c + nadph_c + pydx_c --> nadp_c + pydxn_c
# PYOA: oaa_c + pydam_c --> asp__L_c + pydx_c
# PYDXNK: atp_c + pydx_c --> adp_c + pydx5p_c
# P52O: akg_c + pyam5p_c --> glu__D_c + pydx5p_c
# CO2t: co2_e <=> co2_c
# H2Ot: h2o_e <=> h2o_c
# ETOHt: etoh_e <=> etoh_c
# HCO3t: hco3_e <=> hco3_c
# ACEt: acetone_c --> acetone_e
# H2t: h2_e <=> h2_c
# MANt2: h_e + man_e --> h_c + man_c
# GLCAt2: Glc_aD_e + h_e --> Glc_aD_c + h_c
# URIt2: h_e + uri_e --> h_c + uri_c
# URAt2: h_e + ura_e --> h_c + ura_c
# NAt3_1: h_c + na1_e <=> h_e + na1_c
# NAt4: ca2_e + na1_c --> ca2_c + na1_e
# XYLt2: h_e + xyl__D_e --> h_c + xyl__D_c
# ACt2: ac_c + h_c <=> ac_e + h_e
# GLCNt2: glcn_e + h_e --> glcn_c + h_c
# NAt5: na1_e + pi_e --> na1_c + pi_c
# DADNt2: dad_2_e + h_e --> dad_2_c + h_c
# DCYTt2: dcyt_e + h_e --> dcyt_c + h_c
# CELBt2: cellb_e + h_e --> cellb_c + h_c
# THMDt2: h_e + thymd_e --> h_c + thymd_c
# LACLt2: h_e + lac__L_e --> h_c + lac__L_c
# MALt2: h_c + mal__L_e --> h_e + mal__L_c
# RIBFLVt2: h_e + ribflv_e <=> h_c + ribflv_c
# HXANt2r: h_e + hxan_e --> h_c + hxan_c
# DD2Gt2: 2ddglcn_e + h_e --> 2ddglcn_c + h_c
# NAt6: h_e + na1_e --> h_c + na1_c
# SBTt2: h_e + sbt__D_e --> h_c + sbt__D_c
# MALTt2: h_e + malt_e --> h_c + malt_c
# Kt2r: h_e + k_e --> h_c + k_c
# CSNt2: csn_e + h_e --> csn_c + h_c
# SUCRt2: h_e + sucr_e --> h_c + sucr_c
# INSt2: h_e + ins_e --> h_c + ins_c
# ABG4t2: abg4_e + h_e --> abg4_c + h_c
# ARBt2r: arab__L_e + h_e --> arab__L_c + h_c
# ACNAMt2: acnam_e + h_e --> acnam_c + h_c
# XANt2: h_e + xan_e --> h_c + xan_c
# GALt2_2: gal_bD_e + h_e --> gal_bD_c + h_c
# SO3t: na1_e + so3_e --> na1_c + so3_c
# XANt3: ura_e + xan_e --> ura_c + xan_c
# ALAt4: ala__L_e + na1_e --> ala__L_c + na1_c
# ADNt2: adn_e + h_e --> adn_c + h_c
# GLCt2: glc__D_e + h_e --> glc__D_c + h_c
# GLUt4: glu__L_e + na1_e --> glu__L_c + na1_c
# CHORt2: chor_e + h_e <=> chor_c + h_c
# ASPt2: asp__L_e + na1_e --> asp__L_c + na1_c
# ACAPS: accoa_c + hacp_c <=> acacp_c + coa_c
# MAACAPS: acacp_c + malacp_c --> acacacp_c + co2_c + hacp_c
# ACNP: acacacp_c + nadph_c <=> h3bacp_c + nadp_c
# H3BT: h3bacp_c <=> b2eacp_c + h2o_c
# B2BO: b2eacp_c + h_c + nadph_c --> butacp_c + nadp_c
# B2BO2: b2eacp_c + h_c + nadph_c --> butacp_c + nadp_c
# BMOC: butacp_c + h_c + malacp_c --> co2_c + hacp_c + o3hacp_c
# OHO1: h_c + nadph_c + o3hacp_c --> h3hacp_c + nadp_c
# OHO2: h_c + nadh_c + o3hacp_c --> h3hacp_c + nad_c
# HT2H: h3hacp_c <=> h2o_c + t2eacp_c
# T2ORX: h_c + nadph_c + t2eacp_c --> hexacp_c + nadp_c
# HMCO: h_c + hexacp_c + malacp_c --> co2_c + hacp_c + ox3xooctacp_c
# O3H3R1: h_c + nadph_c + ox3xooctacp_c --> h3octacp_c + nadp_c
# O3H3R2: h_c + nadh_c + ox3xooctacp_c --> h3octacp_c + nad_c
# H3T2E: h3octacp_c <=> h2o_c + toct2enacp_c
# T2ORO: h_c + nadph_c + toct2enacp_c --> nadp_c + octacp_c
# OM3O: h_c + malacp_c + octacp_c --> co2_c + hacp_c + o3xodecacp_c
# ODEC1: h_c + nadph_c + o3xodecacp_c --> h3decacp_c + nadp_c
# ODEC2: h_c + nadh_c + o3xodecacp_c --> h3decacp_c + nad_c
# HD22: h3decacp_c <=> dec22enacp_c + h2o_c
# DEDACP1: dec22enacp_c + h_c + nadph_c --> decacp_c + nadp_c
# DE3OX: decacp_c + h_c + malacp_c --> co2_c + hacp_c + o3xododecacp_c
# O3D1: h_c + nadph_c + o3xododecacp_c --> d3odecacp_c + nadp_c
# O3D2: h_c + nadh_c + o3xododecacp_c --> d3odecacp_c + nad_c
# O3DODEC: d3odecacp_c <=> dodec2enacp_c + h2o_c
# DODEC1: dodec2enacp_c + h_c + nadph_c --> dodecacp_c + nadp_c
# DODEC2: dodecacp_c + h_c + malacp_c --> co2_c + hacp_c + oxo3myristacp_c
# OMR1: h_c + nadph_c + oxo3myristacp_c --> m3yristacp_c + nadp_c
# OMR2: h_c + nadh_c + oxo3myristacp_c --> m3yristacp_c + nad_c
# M3TT: m3yristacp_c <=> h2o_c + ttetdec2enoylacp_c
# TTMR1: h_c + nadph_c + ttetdec2enoylacp_c --> myrstacp_c + nadp_c
# MMHO: h_c + malacp_c + myrstacp_c <=> co2_c + hacp_c + o3xopalmacp_c
# OPALM1: h_c + nadph_c + o3xopalmacp_c --> nadp_c + p3almacp_c
# OPALM2: h_c + nadh_c + o3xopalmacp_c --> nad_c + p3almacp_c
# PTDH: p3almacp_c <=> h2o_c + thexdecenoylacp_c
# TDPR: h_c + nadph_c + thexdecenoylacp_c --> nadp_c + palmacp_c
# PCA1: atp_c + coa_c + palmacd_c <=> amp_c + palmcoa_c + ppi_c
# PCA2: atp_c + coa_c + palmacd_c <=> amp_c + palmacp_c + ppi_c
# PTHEX: nad_c + palmcoa_c --> h_c + nadh_c + thexdecenoylcoa_c
# THP: h2o_c + thexdecenoylcoa_c <=> p3almcoa_c
# P3OR: nad_c + p3almcoa_c <=> h_c + nadh_c + o3xopalmcoa_c
# OCAM: coa_c + o3xopalmcoa_c <=> accoa_c + myrstcoa_c
# MYTR: myrstcoa_c + nad_c --> h_c + nadh_c + ttetdec2enoylcoa_c
# TTH: h2o_c + ttetdec2enoylcoa_c <=> m3yristcoa_c
# M3R: m3yristcoa_c + nad_c <=> h_c + nadh_c + oxo3myristcoa_c
# O3CCO: coa_c + oxo3myristcoa_c <=> accoa_c + dodeccoa_c
# DDDR: dodeccoa_c + nad_c --> dodec22encoa_c + h_c + nadh_c
# DDH: dodec22encoa_c + h2o_c <=> d3odeccoa_c
# D3OR: d3odeccoa_c + nad_c <=> h_c + nadh_c + oxo3dodeccoa_c
# ODCOA: coa_c + oxo3dodeccoa_c <=> accoa_c + deccoa_c
# DECCR: deccoa_c + nad_c --> dec22encoa_c + h_c + nadh_c
# DEC22H: dec22encoa_c + h2o_c <=> d3eccoa_c
# D3CCR: d3eccoa_c + nad_c <=> h_c + nadh_c + oxo3deccoa_c
# OX3COA: coa_c + oxo3deccoa_c <=> accoa_c + octcoa_c
# OCTR: nad_c + octcoa_c --> h_c + nadh_c + toct2encoa_c
# TOCTH: h2o_c + toct2encoa_c <=> o3ctcoa_c
# O3CTR: nad_c + o3ctcoa_c <=> h_c + nadh_c + o3xooctcoa_c
# THEXCOA: coa_c + o3xooctcoa_c <=> accoa_c + hexcoa_c
# HEXR: hexcoa_c + nad_c --> h_c + nadh_c + thex2encoa_c
# THEXH: h2o_c + thex2encoa_c <=> h3excoa_c
# H3EXR: h3excoa_c + nad_c <=> h_c + nadh_c + oxo3hexcoa_c
# OX3HECOA: coa_c + oxo3hexcoa_c <=> accoa_c + btcoa_c
# BTCR: btcoa_c + nad_c --> but2encoa_c + h_c + nadh_c
# BUTH: but2encoa_c + h2o_c <=> 3hbcoa_c
# HB3R: 3hbcoa_c + nad_c --> aacoa_c + h_c + nadh_c
# B2CR: b2coa_c + fadh2_c <=> btcoa_c + fad_c
# HBCH: 3hbcoa_c --> ctncoa_c + h2o_c
# ACCOAS: aacoa_c + coa_c <=> accoa_c
# HBRCH: 3hbcoa__R_c + h2o_c --> bhb_c + coa_c + h_c
# HB3I: 3hbcoa_c <=> 3hbcoa__R_c
# ACACP: acac_c + atp_c + coa_c + h_c --> aacoa_c + amp_c + ppi_c
# MCOAH: coa_c + myrstacp_c --> hacp_c + myrstcoa_c
# PCOAH: coa_c + palmacp_c <=> hacp_c + palmcoa_c
# SRCOAH: coa_c + sracp_c <=> hacp_c + srcoa_c
# GLYCR: glyc_c + nad_c --> glyald_c + h_c + nadh_c
# GLYCR2: glyc_c + nadp_c --> glyald_c + h_c + nadph_c
# GLYAR: glyald_c + h2o_c + nad_c <=> glyc__R_c + h_c + nadh_c
# GLYP: atp_c + glyc_c --> adp_c + sng3p_c
# PCHD: hex1decg3p_c + palmcoa_c --> coa_c + dhex12decg3p_c
# MCHD: myrstcoa_c + tet1decg3p_c --> coa_c + dtet12radecg3p_c
# SRCHD: oct1decg3p_c + srcoa_c --> coa_c + di12octdecg3p_c
# DHPH: adp_c + dhex12decg3p_c <=> atp_c + dgdi12hexdec_c
# DTPH: adp_c + dtet12radecg3p_c <=> atp_c + dgdi12tetdec_c
# DOPH: adp_c + di12octdecg3p_c <=> atp_c + dgdi12octdec_c
# UDGMS: dgdi12hexdec_c + udpg_c <=> mglucsyldpalmgl_c + udp_c
# UDSDM: dgdi12tetdec_c + udpg_c <=> mglucsyldmygl_c + udp_c
# UDMGS: dgdi12octdec_c + udpg_c <=> mglucsyldstgl_c + udp_c
# UDMDP: mglucsyldpalmgl_c + udpg_c <=> dgludpalmgl_c + udp_c
# UMGDS: mglucsyldmygl_c + udpg_c <=> dgludmygl_c + udp_c
# UMGSDS: mglucsyldstgl_c + udpg_c <=> digludstgl_c + udp_c
# ALAALAP: alaala_c + atp_c + ugmd_c --> adp_c + pi_c + udpamagdapaa_c
# PGHDGM: dgludpalmgl_c + phosglcdihexdec_c <=> gpgl_c + mglucsyldpalmgl_c
# PGMHDGM: dgludmygl_c + phosglcditetdec_c <=> gpgl_c + mglucsyldmygl_c
# PGOHDGM: digludstgl_c + phosglcdioctdec_c <=> gpgl_c + mglucsyldstgl_c
# CG3P: ctp_c + sng3p_c --> cdpg_c + ppi_c
# DHRG: dhap_c + h_c + nadh_c --> nad_c + sng3p_c
# DHRG2: dhap_c + h_c + nadph_c --> nadp_c + sng3p_c
# ETHAAL: etha_c --> acald_c + nh4_c
# CDHG: ctp_c + dhex12decg3p_c <=> cdpdhexdecglc_c + ppi_c
# CTHG: ctp_c + dtet12radecg3p_c <=> cdpdtetdecglc_c + ppi_c
# COHG: ctp_c + dgdi12octdec_c <=> cdpoctdecglc_c + ppi_c
# CHLD: cdpdhexdecglc_c + h2o_c --> cmp_c + dhex12decg3p_c
# CTLD: cdpdtetdecglc_c + h2o_c --> cmp_c + dtet12radecg3p_c
# COLD: cdpoctdecglc_c + h2o_c --> cmp_c + dgdi12octdec_c
# CHPHD: cdpdhexdecglc_c + sng3p_c --> cmp_c + pgpdihexdec_c
# CTPTHD: cdpdtetdecglc_c + sng3p_c --> cmp_c + pgpditetdec_c
# CDCPO: cdpoctdecglc_c + sng3p_c --> cmp_c + pgpdioctdec_c
# PGHHPD: h2o_c + pgpdihexdec_c --> h_c + phosglcdihexdec_c + pi_c
# PTDGT: h2o_c + pgpditetdec_c --> h_c + phosglcditetdec_c + pi_c
# PGOGO: h2o_c + pgpdioctdec_c --> h_c + phosglcdioctdec_c + pi_c
# PGHGP: phosglcdihexdec_c --> glyc_c + palmcdlpn_c
# PGTGM: phosglcditetdec_c --> glyc_c + mycdlpn_c
# PGOSC: phosglcdioctdec_c --> glyc_c + strcdlpn_c
# PGHD: palmcoa_c + sng3p_c --> coa_c + hex1decg3p_c
# MGTD: myrstcoa_c + sng3p_c --> coa_c + tet1decg3p_c
# SRGO: sng3p_c + srcoa_c --> coa_c + oct1decg3p_c
# SELP: sectrna_c --> selprotein_c
# SELPTRN: sectrnasec_c + selnp_c --> h_c + pi_c + sectrna_c
# SLGTH: gthrd_c + h_c + slnt_c --> dgslnt_c + gthox_c + h2o_c
# DGSLR: dgslnt_c + h_c + nadph_c --> gslnt_c + gthrd_c + nadp_c
# GSLR: gslnt_c + nadph_c --> gthrd_c + nadp_c + seln_c
# SELNP: atp_c + h2o_c + seln_c --> amp_c + pi_c + selnp_c
# SELMR: mql8_c + sel_c --> h2o_c + mqn8_c + slnt_c
# SELt: sel_e <=> sel_c
# SERLTRN: atp_c + ser__L_c + trnasecys_c --> amp_c + ppi_c + sectrnasec_c
# SLNTt: slnt_e --> slnt_c
# SELCYH: h2o_c + selencysthne_c --> nh4_c + pyr_c + selenlhcys_c
# SELCDH: selencysthne_c <=> a2m2prpnte_c + h_c + selenlhcys_c
# BIOMASSDRAIN: biomass_c -->
# EX_tre_e: tre_e -->
# EX_co1dam_e: co1dam_e -->
# EX_phe__L_e: phe__L_e <=>
# EX_thm_e: thm_e <=>
# EX_leu__L_e: leu__L_e <=>
# EX_dachi_e: dachi_e -->
# EX_k_e: k_e <=>
# EX_pydxn_e: pydxn_e <=>
# EX_ac_e: ac_e -->
# EX_cdpg_e: cdpg_e -->
# EX_etoh_e: etoh_e -->
# EX_malt_e: malt_e -->
# EX_galt_e: galt_e -->
# EX_Glc_aD_e: Glc_aD_e -->
# EX_glyc_e: glyc_e -->
# EX_mnl_e: mnl_e -->
# EX_d23hb_e: d23hb_e -->
# EX_gly_e: gly_e <=>
# EX_gln__L_e: gln__L_e <=>
# EX_isobuta_e: isobuta_e -->
# EX_fe2_e: fe2_e <=>
# EX_m4po_e: m4po_e -->
# EX_tmam_e: tmam_e -->
# EX_lys__L_e: lys__L_e <=>
# EX_ad_e: ad_e -->
# EX_tagur_e: tagur_e -->
# EX_cobalt2_e: cobalt2_e <=>
# EX_chol_e: chol_e -->
# EX_ala__L_e: ala__L_e <=>
# EX_ca2_e: ca2_e <=>
# EX_acetone_e: acetone_e -->
# EX_m2but_e: m2but_e -->
# EX_uri_e: uri_e <=>
# EX_xan_e: xan_e -->
# EX_2ddglcn_e: 2ddglcn_e -->
# EX_dad_2_e: dad_2_e <=>
# EX_escut_e: escut_e -->
# EX_ins_e: ins_e <=>
# EX_ribflv_e: ribflv_e <=>
# EX_escul_e: escul_e -->
# EX_fru_e: fru_e -->
# EX_nac_e: nac_e -->
# EX_glc__D_e: glc__D_e <=>
# EX_arg__L_e: arg__L_e <=>
# EX_gthrd_e: gthrd_e -->
# EX_ile__L_e: ile__L_e <=>
# EX_mg2_e: mg2_e <=>
# EX_dcyt_e: dcyt_e <=>
# EX_mevR_e: mevR_e -->
# EX_csn_e: csn_e -->
# EX_fuc_e: fuc_e -->
# EX_pro__L_e: pro__L_e <=>
# EX_xyl__D_e: xyl__D_e -->
# EX_pi_e: pi_e <=>
# EX_tyr__L_e: tyr__L_e <=>
# EX_dhptd_e: dhptd_e -->
# EX_acnam_e: acnam_e -->
# EX_trp__L_e: trp__L_e <=>
# EX_sbt__D_e: sbt__D_e -->
# EX_raffin_e: raffin_e -->
# EX_so3_e: so3_e -->
# EX_arab__L_e: arab__L_e -->
# EX_cellb_e: cellb_e -->
# EX_ncam_e: ncam_e <=>
# EX_chor_e: chor_e <=>
# EX_ptrc_e: ptrc_e -->
# EX_met__L_e: met__L_e <=>
# EX_abg4_e: abg4_e -->
# EX_asp__L_e: asp__L_e <=>
# EX_ibtol_e: ibtol_e -->
# EX_cys__L_e: cys__L_e <=>
# EX_gal_bD_e: gal_bD_e -->
# EX_thr__L_e: thr__L_e <=>
# EX_ppat_e: ppat_e -->
# EX_succ_e: succ_e -->
# EX_isocap_e: isocap_e -->
# EX_for_e: for_e -->
# EX_dtbt_e: dtbt_e -->
# EX_glcn_e: glcn_e -->
# EX_no2_e: no2_e -->
# EX_23dappa_e: 23dappa_e -->
# EX_man_e: man_e -->
# EX_his__L_e: his__L_e <=>
# EX_btn_e: btn_e <=>
# EX_a5pn_e: a5pn_e -->
# EX_thymd_e: thymd_e <=>
# EX_ser__L_e: ser__L_e <=>
# EX_g3p_e: g3p_e <=>
# EX_h2_e: h2_e -->
# EX_hxan_e: hxan_e <=>
# EX_2ameph_e: 2ameph_e -->
# EX_man6pglyc_e: man6pglyc_e -->
# EX_ival_e: ival_e -->
# EX_acgam_e: acgam_e -->
# EX_pnto__R_e: pnto__R_e <=>
# EX_na1_e: na1_e <=>
# EX_mal__L_e: mal__L_e -->
# EX_tgt_e: tgt_e -->
# EX_zn2_e: zn2_e <=>
# EX_ura_e: ura_e <=>
# EX_adn_e: adn_e <=>
# EX_nh4_e: nh4_e -->
# EX_h_e: h_e <=>
# EX_rib__D_e: rib__D_e -->
# EX_asn__L_e: asn__L_e <=>
# EX_sucr_e: sucr_e -->
# EX_co2_e: co2_e <=>
# EX_uaccg_e: uaccg_e -->
# EX_glyb_e: glyb_e -->
# EX_spmd_e: spmd_e -->
# EX_ham_e: ham_e -->
# EX_val__L_e: val__L_e <=>
# EX_met__D_e: met__D_e -->
# EX_h2o_e: h2o_e <=>
# EX_glu__L_e: glu__L_e <=>
# EX_hco3_e: hco3_e -->
# EX_4abz_e: 4abz_e <=>
# EX_etha_e: etha_e -->
# EX_no3_e: no3_e -->
# EX_akg_e: akg_e -->
# EX_sel_e: sel_e <=>
# EX_slnt_e: slnt_e <=>
# EX_gthox_e: gthox_e -->
# EX_lac__L_e: lac__L_e -->
# EX_fum_e: fum_e -->
# NADH6: 4.5 h_c + nadh_c + q8_c --> 3.5 h_e + nad_c + q8h2_c
# SERTRS2: atp_c + ser__L_c + trnasecys_c --> amp_c + ppi_c + sertrna_sec_c
# PROTRS: atp_c + pro__L_c + trnapro_c --> amp_c + ppi_c + protrna_c
# GLNTRS: atp_c + gln__L_c + trnagln_c --> amp_c + glntrna_c + ppi_c
# CYSTRS: atp_c + cys__L_c + trnacys_c --> amp_c + cystrna_c + ppi_c
# THRTRS: atp_c + thr__L_c + trnathr_c --> amp_c + ppi_c + thrtrna_c
# ALATRS: ala__L_c + atp_c + trnaala_c --> alatrna_c + amp_c + ppi_c
# TYRTRS: atp_c + trnatyr_c + tyr__L_c --> amp_c + ppi_c + tyrtrna_c
# ASNTRS: asn__L_c + atp_c + trnaasn_c --> amp_c + asntrna_c + ppi_c
# GLYTRS: atp_c + gly_c + trnagly_c --> amp_c + glytrna_c + ppi_c
# LEUTRS: atp_c + leu__L_c + trnaleu_c --> amp_c + leutrna_c + ppi_c
# FMETTRS: 10fthf_c + mettrna_c --> fmettrna_c + h_c + thf_c
# TRPTRS: atp_c + trnatrp_c + trp__L_c --> amp_c + ppi_c + trptrna_c
# ASPTRS: asp__L_c + atp_c + trnaasp_c --> amp_c + asptrna_c + ppi_c
# VALTRS: atp_c + trnaval_c + val__L_c --> amp_c + ppi_c + valtrna_c
# METTRS: atp_c + met__L_c + trnamet_c --> amp_c + mettrna_c + ppi_c
# SERTRS: atp_c + ser__L_c + trnaser_c --> amp_c + ppi_c + sertrna_c
# PHETRS: atp_c + phe__L_c + trnaphe_c --> amp_c + phetrna_c + ppi_c
# GLCS1: adpglc_c --> adp_c + glycogen_c + h_c
# GLCP: glycogen_c + pi_c --> g1p_c
# P5CR: 1pyr5c_c + 2.0 h_c + nadph_c --> nadp_c + pro__L_c
# SERAT: accoa_c + ser__L_c --> acser_c + coa_c
# SPODM: 2.0 h_c + 2.0 o2s_c --> h2o2_c + o2_c
# ADD: ade_c + h2o_c + h_c --> hxan_c + nh4_c
# Cuabc: atp_c + cu2_e + h2o_c --> adp_c + cu2_c + h_c + pi_c
# GLBRAN2: glycogen_c --> bglycogen_c
# PAPPT3: udcpp_c + ugmda_c --> uagmda_c + ump_c
# UDPGD: h2o_c + 2.0 nad_c + udpg_c --> 3.0 h_c + 2.0 nadh_c + udpglcur_c
# ACM6PH: acmum6p_c + h2o_c --> acgam6p_c + lac__D_c
# FE3abc: atp_c + fe3_e + h2o_c --> adp_c + fe3_c + h_c + pi_c
# METSR_S1: metox_c + trdrd_c --> h2o_c + met__L_c + trdox_c
# MALTATr: accoa_c + malt_c --> acmalt_c + coa_c
# CELBpts: cellb_e + pep_c --> 6pgg_c + pyr_c
# CODH_ACS: co2_c + coa_c + fdxr_42_c + h_c + mecfsp_c --> accoa_c + cfesp_c + fdxo_42_c + h2o_c
# CYSS: acser_c + h2s_c --> ac_c + cys__L_c + h_c
# MOBDabc: atp_c + h2o_c + mobd_e --> adp_c + h_c + mobd_c + pi_c
# MTHFR5: fdxo_42_c + h_c + mlthf_c + 2.0 nadh_c --> 5mthf_c + fdxr_42_c + 2.0 nad_c
# 26DPAi: 23dhdp_c + nad_c --> DPA_c + h_c + nadh_c
# ACTNabc: actn__R_e + atp_c + h2o_c --> actn__R_c + adp_c + h_c + pi_c
# ASPR: asp__D_c --> asp__L_c
# ANHMK: anhm_c + atp_c + h2o_c --> acmum6p_c + adp_c + h_c
# MOGDS: gtp_c + h_c + moco_c --> mocogdp_c + ppi_c
# MNabc: atp_c + h2o_c + mn2_e --> adp_c + h_c + mn2_c + pi_c
# CHTBSH: chtbs_c + h2o_c --> ac_c + acgam_c
# ILETAR1: akg_c + leu__L_c --> 4mop_c + glu__L_c
# HBCHLR2: b2coa_c + h2o_c --> 3hbcoa__R_c
# FNRR3: fdxo_2_2_c + h2_c --> fdxrd_c + 2 h_c
# ACACCT: acac_c + accoa_c --> aacoa_c + ac_c
# FMNRx: fmn_c + h_c + nadh_c --> fmnh2_c + nad_c
# FMNRx2: fmn_c + h_c + nadph_c --> fmnh2_c + nadp_c
# AGPOP: dgdp_c + h_c + pep_c --> dgtp_c + pyr_c
# PYK3: gdp_c + h_c + pep_c --> gtp_c + pyr_c
# DAPOP: dadp_c + h_c + pep_c --> datp_c + pyr_c
# PPC: co2_c + h2o_c + pep_c --> h_c + oaa_c + pi_c
# UAGHD: h_c + nadh_c + uaccg_c --> nad_c + uamr_c
# GAMpts: gam_e + pep_c --> gam6p_c + pyr_c

# %%
print new_model.reactions.BIOMASS.objective_coefficient

sol = new_model.optimize()
print sol
print len(new_model.reactions)
ex_rxns = [r for r in model.reactions if r.id.startswith('EX') and r.lower_bound<0]
print ex_rxns
# Out:
# 1.0
# <Solution 0.210 at 0x1974d6a0>
# 1208
# [<Reaction EX_phe__L_e at 0x1bd03fd0>, <Reaction EX_thm_e at 0x1bd18080>, <Reaction EX_leu__L_e at 0x1bd180f0>, <Reaction EX_k_e at 0x1bd181d0>, <Reaction EX_pydxn_e at 0x1bd18240>, <Reaction EX_gly_e at 0x1bd186a0>, <Reaction EX_gln__L_e at 0x1bd18710>, <Reaction EX_fe2_e at 0x1bd187f0>, <Reaction EX_lys__L_e at 0x1bd18940>, <Reaction EX_cobalt2_e at 0x1bd18a90>, <Reaction EX_ala__L_e at 0x1bd18b70>, <Reaction EX_ca2_e at 0x1bd18be0>, <Reaction EX_uri_e at 0x1bd18d30>, <Reaction EX_dad_2_e at 0x1bd18e80>, <Reaction EX_ins_e at 0x1bd18f60>, <Reaction EX_ribflv_e at 0x1bd18fd0>, <Reaction EX_glc__D_e at 0x1bd731d0>, <Reaction EX_arg__L_e at 0x1bd73240>, <Reaction EX_ile__L_e at 0x1bd73320>, <Reaction EX_mg2_e at 0x1bd73390>, <Reaction EX_dcyt_e at 0x1bd73400>, <Reaction EX_pro__L_e at 0x1bd735c0>, <Reaction EX_pi_e at 0x1bd736a0>, <Reaction EX_tyr__L_e at 0x1bd73710>, <Reaction EX_trp__L_e at 0x1bd73860>, <Reaction EX_ncam_e at 0x1bd73b00>, <Reaction EX_chor_e at 0x1bd73b70>, <Reaction EX_met__L_e at 0x1bd73c50>, <Reaction EX_asp__L_e at 0x1bd73d30>, <Reaction EX_cys__L_e at 0x1bd73e10>, <Reaction EX_thr__L_e at 0x1bd73ef0>, <Reaction EX_his__L_e at 0x1bd8a390>, <Reaction EX_btn_e at 0x1bd8a400>, <Reaction EX_thymd_e at 0x1bd8a4e0>, <Reaction EX_ser__L_e at 0x1bd8a550>, <Reaction EX_g3p_e at 0x1bd8a5c0>, <Reaction EX_hxan_e at 0x1bd8a6a0>, <Reaction EX_pnto__R_e at 0x1bd8a8d0>, <Reaction EX_na1_e at 0x1bd8a940>, <Reaction EX_zn2_e at 0x1bd8aa90>, <Reaction EX_ura_e at 0x1bd8ab00>, <Reaction EX_adn_e at 0x1bd8ab70>, <Reaction EX_h_e at 0x1bd8ac50>, <Reaction EX_asn__L_e at 0x1bd8ad30>, <Reaction EX_co2_e at 0x1bd8ae10>, <Reaction EX_val__L_e at 0x1bda1080>, <Reaction EX_h2o_e at 0x1bda1160>, <Reaction EX_glu__L_e at 0x1bda11d0>, <Reaction EX_4abz_e at 0x1bda12b0>, <Reaction EX_sel_e at 0x1bda1470>, <Reaction EX_slnt_e at 0x1bda14e0>]

# %%
# save our new model:
cobra.io.save_json_model(new_model,'iCdiff112c_draft.json')

# %%
# work with our new model as the model from now on:
model = load_json_model('iCdiff112c_draft.json')
sol = model.optimize()
print sol
# Out:
# <Solution 0.210 at 0x18d20358>

# %%
# define a minimal media for C. diff to grow on
def set_min_media(model):
    # set all exchange reactions to lower bound of 0: e.g. nothing can enter the cell
    ex_rxns = [r for r in model.reactions if r.id.startswith('EX')]
    for r in ex_rxns:
        r.lower_bound = 0
        
    #define our minimal media exchanges:
    min_media = {
        'EX_glc__D_e':-10,
        'EX_leu__L_e':-1,
        'EX_k_e': -1000,
        'EX_pydxn_e': -1,
        'EX_fe2_e': -1000,
        'EX_cobalt2_e': -1000,
        'EX_ca2_e': -1000,
        'EX_ile__L_e': -1,
        'EX_mg2_e': -1000,
        'EX_pro__L_e': -1,
        'EX_pi_e': -1000,
        'EX_trp__L_e': -1,
        'EX_met__L_e': -1,
        'EX_cys__L_e': -1,
        'EX_btn_e': -1,
        'EX_pnto__R_e': -1,
        'EX_na1_e': -1000,
        'EX_zn2_e': -1000,
        'EX_h_e': -1000,
        'EX_co2_e': -1000,
        'EX_val__L_e': -1,
        'EX_h2o_e': -1000,
        'EX_sel_e': -1000,
        'EX_slnt_e': -1000
    }
    for r in min_media.keys():
        rxn = model.reactions.get_by_id(r)
        rxn.lower_bound = min_media[r]
    return model

# %%
# change to minimal media and ensure that the model can still grow
new_model = set_min_media(new_model)
sol = new_model.optimize()
print sol
# Out:
# <Solution 0.015 at 0x1672f128>

# %%
# Check growth capabilities of our model by switching out glucose for all other possible carbon sources
new_model.reactions.get_by_id('EX_glc__D_e').lower_bound = 0
# SOLUTION
# Out:
# <Solution -0.000 at 0x1a63d0b8>
# EX_tre_e: tre_e -->
# <Solution -0.000 at 0x16f9bcc0>
# EX_co1dam_e: co1dam_e -->
# <Solution -0.000 at 0x1a63d208>
# EX_phe__L_e: phe__L_e -->
# <Solution -0.000 at 0x16f9bf60>
# EX_thm_e: thm_e -->
# <Solution -0.000 at 0x1a63d588>
# EX_leu__L_e: leu__L_e <=>
# <Solution 0.000 at 0x16f9b908>
# EX_dachi_e: dachi_e -->
# <Solution 0.023 at 0x1a63d7f0>
# EX_k_e: k_e <=>
# <Solution 0.000 at 0x16f9bcc0>
# EX_pydxn_e: pydxn_e <=>
# <Solution 0.000 at 0x1a63d240>
# EX_ac_e: ac_e -->
# <Solution 0.004 at 0x12a1c0f0>
# EX_cdpg_e: cdpg_e -->
# <Solution 0.000 at 0x11c65978>
# EX_etoh_e: etoh_e -->
# <Solution 0.015 at 0x18c36518>
# EX_malt_e: malt_e -->
# <Solution 0.015 at 0x1b175b70>
# EX_galt_e: galt_e -->
# <Solution 0.015 at 0x1a84ca20>
# EX_Glc_aD_e: Glc_aD_e -->
# <Solution 0.015 at 0x155fe048>
# EX_glyc_e: glyc_e -->
# <Solution 0.015 at 0x11599390>
# EX_mnl_e: mnl_e -->
# <Solution 0.015 at 0x1c8e8080>
# EX_d23hb_e: d23hb_e -->
# <Solution 0.000 at 0x1974dac8>
# EX_gly_e: gly_e -->
# <Solution 0.019 at 0x11c65978>
# EX_gln__L_e: gln__L_e -->
# <Solution 0.029 at 0x18c36518>
# EX_isobuta_e: isobuta_e -->
# <Solution 0.000 at 0x1855fcf8>
# EX_fe2_e: fe2_e <=>
# <Solution 0.000 at 0x12a1c0f0>
# EX_m4po_e: m4po_e -->
# <Solution 0.000 at 0x155fe048>
# EX_tmam_e: tmam_e -->
# <Solution 0.000 at 0x11599390>
# EX_lys__L_e: lys__L_e -->
# <Solution 0.000 at 0x1b175b70>
# EX_ad_e: ad_e -->
# <Solution 0.000 at 0x1a7bf208>
# EX_tagur_e: tagur_e -->
# <Solution 0.015 at 0x11c65978>
# EX_cobalt2_e: cobalt2_e <=>
# <Solution 0.000 at 0x18c36518>
# EX_chol_e: chol_e -->
# <Solution 0.013 at 0x1855fcf8>
# EX_ala__L_e: ala__L_e -->
# <Solution 0.035 at 0x12a1c0f0>
# EX_ca2_e: ca2_e <=>
# <Solution 0.000 at 0x155fe048>
# EX_acetone_e: acetone_e -->
# <Solution 0.000 at 0x11599390>
# EX_m2but_e: m2but_e -->
# <Solution 0.000 at 0x1c8e8080>
# EX_uri_e: uri_e -->
# <Solution 0.065 at 0x1a7bf208>
# EX_xan_e: xan_e -->
# <Solution 0.019 at 0x1b175b70>
# EX_2ddglcn_e: 2ddglcn_e -->
# <Solution 0.015 at 0x1855f2e8>
# EX_dad_2_e: dad_2_e -->
# <Solution 0.080 at 0x155fe048>
# EX_escut_e: escut_e -->
# <Solution 0.000 at 0x12a1c0f0>
# EX_ins_e: ins_e -->
# <Solution 0.064 at 0x11c65978>
# EX_ribflv_e: ribflv_e -->
# <Solution -0.000 at 0x11599390>
# EX_escul_e: escul_e -->
# <Solution 0.015 at 0x1c8e8080>
# EX_fru_e: fru_e -->
# <Solution 0.015 at 0x18c36518>
# EX_nac_e: nac_e -->
# <Solution -0.000 at 0x17228588>
# EX_glc__D_e: glc__D_e -->
# <Solution 0.015 at 0x1a7bf208>
# EX_arg__L_e: arg__L_e -->
# <Solution 0.052 at 0xc6520b8>
# EX_gthrd_e: gthrd_e -->
# <Solution -0.000 at 0x1a84ca20>
# EX_ile__L_e: ile__L_e <=>
# <Solution -0.000 at 0x11c65978>
# EX_mg2_e: mg2_e <=>
# <Solution -0.000 at 0x1855f2e8>
# EX_dcyt_e: dcyt_e -->
# <Solution 0.067 at 0x1c8e8080>
# EX_mevR_e: mevR_e -->
# <Solution 0.015 at 0x167258d0>
# EX_csn_e: csn_e -->
# <Solution 0.014 at 0x155fe048>
# EX_fuc_e: fuc_e -->
# <Solution 0.015 at 0x11599390>
# EX_pro__L_e: pro__L_e <=>
# <Solution 0.000 at 0x17228588>
# EX_xyl__D_e: xyl__D_e -->
# <Solution 0.015 at 0x1a7bf208>
# EX_pi_e: pi_e <=>
# <Solution 0.000 at 0x11c65978>
# EX_tyr__L_e: tyr__L_e -->
# <Solution 0.000 at 0x18c36518>
# EX_dhptd_e: dhptd_e -->
# <Solution 0.000 at 0x1855fcf8>
# EX_acnam_e: acnam_e -->
# <Solution 0.023 at 0x1855f358>
# EX_trp__L_e: trp__L_e <=>
# <Solution 0.000 at 0x1c8e8080>
# EX_sbt__D_e: sbt__D_e -->
# <Solution 0.015 at 0x11599390>
# EX_raffin_e: raffin_e -->
# <Solution 0.015 at 0x17228588>
# EX_so3_e: so3_e -->
# <Solution -0.000 at 0x18560dd8>
# EX_arab__L_e: arab__L_e -->
# <Solution 0.015 at 0x1b175b70>
# EX_cellb_e: cellb_e -->
# <Solution 0.015 at 0x10900470>
# EX_ncam_e: ncam_e -->
# <Solution 0.000 at 0x1855fcf8>
# EX_chor_e: chor_e -->
# <Solution 0.015 at 0x167258d0>
# EX_ptrc_e: ptrc_e -->
# <Solution 0.000 at 0xc6520b8>
# EX_met__L_e: met__L_e <=>
# <Solution 0.000 at 0x1a7bf208>
# EX_abg4_e: abg4_e -->
# <Solution 0.000 at 0x17228588>
# EX_asp__L_e: asp__L_e -->
# <Solution 0.035 at 0x18c36518>
# EX_ibtol_e: ibtol_e -->
# <Solution -0.000 at 0x1b175b70>
# EX_cys__L_e: cys__L_e <=>
# <Solution -0.000 at 0x10900470>
# EX_gal_bD_e: gal_bD_e -->
# <Solution 0.015 at 0x1855fcf8>
# EX_thr__L_e: thr__L_e -->
# <Solution 0.033 at 0x1855f358>
# EX_ppat_e: ppat_e -->
# <Solution 0.000 at 0x1c8e8080>
# EX_succ_e: succ_e -->
# <Solution 0.000 at 0x18560dd8>
# EX_isocap_e: isocap_e -->
# <Solution 0.000 at 0x17228588>
# EX_for_e: for_e -->
# <Solution 0.000 at 0x11599390>
# EX_dtbt_e: dtbt_e -->
# <Solution 0.000 at 0x155fe048>
# EX_glcn_e: glcn_e -->
# <Solution 0.015 at 0x10900470>
# EX_no2_e: no2_e -->
# <Solution -0.000 at 0x1855fcf8>
# EX_23dappa_e: 23dappa_e -->
# <Solution 0.023 at 0x1855f358>
# EX_man_e: man_e -->
# <Solution 0.015 at 0x1b175b70>
# EX_his__L_e: his__L_e -->
# <Solution 0.000 at 0x18560dd8>
# EX_btn_e: btn_e <=>
# <Solution 0.000 at 0x11c65978>
# EX_a5pn_e: a5pn_e -->
# <Solution 0.000 at 0x11599390>
# EX_thymd_e: thymd_e -->
# <Solution 0.020 at 0x155fe048>
# EX_ser__L_e: ser__L_e -->
# <Solution 0.030 at 0x10900470>
# EX_g3p_e: g3p_e -->
# <Solution -0.000 at 0xc6520b8>
# EX_h2_e: h2_e -->
# <Solution -0.000 at 0x18c36518>
# EX_hxan_e: hxan_e -->
# <Solution 0.019 at 0x17228588>
# EX_2ameph_e: 2ameph_e -->
# <Solution 0.038 at 0x18560dd8>
# EX_man6pglyc_e: man6pglyc_e -->
# <Solution 0.015 at 0x1b175b70>
# EX_ival_e: ival_e -->
# <Solution -0.000 at 0x167258d0>
# EX_acgam_e: acgam_e -->
# <Solution -0.000 at 0x155fe048>
# EX_pnto__R_e: pnto__R_e <=>
# <Solution -0.000 at 0x10900470>
# EX_na1_e: na1_e <=>
# <Solution -0.000 at 0x1855fcf8>
# EX_mal__L_e: mal__L_e -->
# <Solution 0.015 at 0x18c36518>
# EX_tgt_e: tgt_e -->
# <Solution 0.015 at 0x17228588>
# EX_zn2_e: zn2_e <=>
# <Solution -0.000 at 0x18560dd8>
# EX_ura_e: ura_e -->
# <Solution 0.014 at 0x1b175b70>
# EX_adn_e: adn_e -->
# <Solution 0.064 at 0x167258d0>
# EX_nh4_e: nh4_e -->
# <Solution 0.000 at 0x155fe048>
# EX_h_e: h_e <=>
# <Solution 0.000 at 0x139cc9b0>
# EX_rib__D_e: rib__D_e -->
# <Solution 0.015 at 0x11c65978>
# EX_asn__L_e: asn__L_e -->
# <Solution 0.035 at 0x18c36518>
# EX_sucr_e: sucr_e -->
# <Solution 0.015 at 0x17228588>
# EX_co2_e: co2_e <=>
# <Solution -0.000 at 0x18560dd8>
# EX_uaccg_e: uaccg_e -->
# <Solution -0.000 at 0x1b175b70>
# EX_glyb_e: glyb_e -->
# <Solution 0.003 at 0x167258d0>
# EX_spmd_e: spmd_e -->
# <Solution 0.000 at 0x1855fcf8>
# EX_ham_e: ham_e -->
# <Solution 0.000 at 0x1855f048>
# EX_val__L_e: val__L_e <=>
# <Solution 0.000 at 0x11c65978>
# EX_met__D_e: met__D_e -->
# <Solution 0.000 at 0x10900470>
# EX_h2o_e: h2o_e <=>
# <Solution 0.000 at 0x17228588>
# EX_glu__L_e: glu__L_e -->
# <Solution 0.029 at 0x18560dd8>
# EX_hco3_e: hco3_e -->
# <Solution 0.000 at 0x1c8e8080>
# EX_4abz_e: 4abz_e -->
# <Solution 0.000 at 0x167258d0>
# EX_etha_e: etha_e -->
# <Solution 0.016 at 0x1b175b70>
# EX_no3_e: no3_e -->
# <Solution 0.000 at 0x1855f048>
# EX_akg_e: akg_e -->
# <Solution 0.008 at 0x11c65978>
# EX_sel_e: sel_e <=>
# <Solution 0.000 at 0x10900470>
# EX_slnt_e: slnt_e <=>
# <Solution 0.000 at 0x155fe048>
# EX_gthox_e: gthox_e -->
# <Solution 0.000 at 0x18560dd8>
# EX_lac__L_e: lac__L_e -->
# <Solution 0.015 at 0x1c8e8080>
# EX_fum_e: fum_e -->
# <Solution 0.015 at 0x1a84ca20>
