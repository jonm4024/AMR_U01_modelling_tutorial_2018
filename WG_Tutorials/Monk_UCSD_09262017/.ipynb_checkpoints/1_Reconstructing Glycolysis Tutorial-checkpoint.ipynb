# %% [markdown]
# In this tutorial we will learn how to:
#
# 1) Run Flux balance analysis
# 2) Change the flux constraints of a reaction
# 3) Simulate a gene knockout
# 4) Simulate growth of a strain on different nutrient conditions

# %% [markdown]
# ## Reconstructing Pathways

# %% [markdown]
# ![Selection_084.png](attachment:Selection_084.png)

# %%
import cobra
from cobra import Model, Reaction, Metabolite

# %% [markdown]
# ## Metabolites are Network Nodes

# %%
#Glucose 
glc__D_c = Metabolite('glc__D_c',
    name='D-glucose',
    formula='C6H12O6',
    compartment='c',
    charge=0
)

#Glucose-6-Phosphate
g6p_c=Metabolite('g6p_c',
    name='D-glucose 6-phosphate',
    formula='C6H11O9P',
    compartment='c',
    charge=-2
)

#ATP
atp_c=Metabolite('atp_c',
    name='ATP',
    formula='C10H12N5O13P3',
    compartment='c',
    charge=-4
)

#ADP
adp_c=Metabolite('adp_c',
    name='ADP',
    formula='C10H12N5O10P2',
    compartment='c',
    charge=-3
)

#H ion
h_c=Metabolite('h_c',
    name='H+',
    formula='H',
    compartment='c',
    charge=1
)

# %% [markdown]
# ## Reactions are Network Links

# %%
#First Reaction of Glycolysis Pathway, Hexokinase
HEX1 = Reaction('HEX1')

#Define the bounds to define the reversibility of the reaction
HEX1.lower_bound = 0.
HEX1.upper_bound = 1000.

#Add metabolites with the appropriate stoichiometry
HEX1.add_metabolites({
    atp_c: -1.0,
    glc__D_c: -1.0,
    g6p_c: 1.0,
    adp_c: 1.0,
    h_c: 1.0
    })

# %%
HEX1.reaction
# Out:
# 'atp_c + glc__D_c --> adp_c + g6p_c + h_c'

# %% [markdown]
# ### A full model consists of reactions and metabolites as we defined above. Here we load a finished model of E. coli str. K-12

# %%
model = cobra.io.load_json_model('iAF1260.json')

# %%
print ('Reactions')
print ('---------')
for reaction in model.reactions:
    print('%s : %s' % (reaction.id, reaction.reaction))
# Out:
# Reactions
# ---------
# 12DGR120tipp : 12dgr120_p --> 12dgr120_c
# 12DGR140tipp : 12dgr140_p --> 12dgr140_c
# 12DGR141tipp : 12dgr141_p --> 12dgr141_c
# 12DGR160tipp : 12dgr160_p --> 12dgr160_c
# 12DGR161tipp : 12dgr161_p --> 12dgr161_c
# 12DGR180tipp : 12dgr180_p --> 12dgr180_c
# 12DGR181tipp : 12dgr181_p --> 12dgr181_c
# 12PPDRtex : 12ppd__R_e <=> 12ppd__R_p
# 12PPDRtpp : 12ppd__R_p <=> 12ppd__R_c
# 12PPDStex : 12ppd__S_e <=> 12ppd__S_p
# 12PPDStpp : 12ppd__S_p <=> 12ppd__S_c
# 14GLUCANabcpp : 14glucan_p + atp_c + h2o_c --> 14glucan_c + adp_c + h_c + pi_c
# 14GLUCANtexi : 14glucan_e --> 14glucan_p
# 23CAMPtex : 23camp_e <=> 23camp_p
# 23CCMPtex : 23ccmp_e <=> 23ccmp_p
# 23CGMPtex : 23cgmp_e <=> 23cgmp_p
# 23CUMPtex : 23cump_e <=> 23cump_p
# 23DAPPAt2pp : 23dappa_p + h_p --> 23dappa_c + h_c
# 23DAPPAtex : 23dappa_e <=> 23dappa_p
# 23PDE2pp : 23cump_p + h2o_p --> 3ump_p + h_p
# 23PDE4pp : 23ccmp_p + h2o_p --> 3cmp_p + h_p
# 23PDE7pp : 23camp_p + h2o_p --> 3amp_p + h_p
# 23PDE9pp : 23cgmp_p + h2o_p --> 3gmp_p + h_p
# 26DAHtex : 26dap__M_e <=> 26dap__M_p
# 2AGPA120tipp : 2ddecg3p_p --> 2ddecg3p_c
# 2AGPA140tipp : 2tdecg3p_p --> 2tdecg3p_c
# 2AGPA141tipp : 2tdec7eg3p_p --> 2tdec7eg3p_c
# 2AGPA160tipp : 2hdecg3p_p --> 2hdecg3p_c
# 2AGPA161tipp : 2hdec9eg3p_p --> 2hdec9eg3p_c
# 2AGPA180tipp : 2odecg3p_p --> 2odecg3p_c
# 2AGPA181tipp : 2odec11eg3p_p --> 2odec11eg3p_c
# 2AGPE120tipp : 2agpe120_p --> 2agpe120_c
# 2AGPE140tipp : 2agpe140_p --> 2agpe140_c
# 2AGPE141tipp : 2agpe141_p --> 2agpe141_c
# 2AGPE160tipp : 2agpe160_p --> 2agpe160_c
# 2AGPE161tipp : 2agpe161_p --> 2agpe161_c
# 2AGPE180tipp : 2agpe180_p --> 2agpe180_c
# 2AGPE181tipp : 2agpe181_p --> 2agpe181_c
# 2AGPEAT120 : 2agpe120_c + atp_c + ddca_c --> amp_c + pe120_c + ppi_c
# 2AGPEAT140 : 2agpe140_c + atp_c + ttdca_c --> amp_c + pe140_c + ppi_c
# 2AGPEAT141 : 2agpe141_c + atp_c + ttdcea_c --> amp_c + pe141_c + ppi_c
# 2AGPEAT160 : 2agpe160_c + atp_c + hdca_c --> amp_c + pe160_c + ppi_c
# 2AGPEAT161 : 2agpe161_c + atp_c + hdcea_c --> amp_c + pe161_c + ppi_c
# 2AGPEAT180 : 2agpe180_c + atp_c + ocdca_c --> amp_c + pe180_c + ppi_c
# 2AGPEAT181 : 2agpe181_c + atp_c + ocdcea_c --> amp_c + pe181_c + ppi_c
# 2AGPG120tipp : 2agpg120_p --> 2agpg120_c
# 2AGPG140tipp : 2agpg140_p --> 2agpg140_c
# 2AGPG141tipp : 2agpg141_p --> 2agpg141_c
# 2AGPG160tipp : 2agpg160_p --> 2agpg160_c
# 2AGPG161tipp : 2agpg161_p --> 2agpg161_c
# 2AGPG180tipp : 2agpg180_p --> 2agpg180_c
# 2AGPG181tipp : 2agpg181_p --> 2agpg181_c
# 2AGPGAT120 : 2agpg120_c + atp_c + ddca_c --> amp_c + pg120_c + ppi_c
# 2AGPGAT140 : 2agpg140_c + atp_c + ttdca_c --> amp_c + pg140_c + ppi_c
# 2AGPGAT141 : 2agpg141_c + atp_c + ttdcea_c --> amp_c + pg141_c + ppi_c
# 2AGPGAT160 : 2agpg160_c + atp_c + hdca_c --> amp_c + pg160_c + ppi_c
# 2AGPGAT161 : 2agpg161_c + atp_c + hdcea_c --> amp_c + pg161_c + ppi_c
# 2AGPGAT180 : 2agpg180_c + atp_c + ocdca_c --> amp_c + pg180_c + ppi_c
# 2AGPGAT181 : 2agpg181_c + atp_c + ocdcea_c --> amp_c + pg181_c + ppi_c
# 2DGLCNRx : 2dhglcn_c + h_c + nadh_c --> glcn_c + nad_c
# 2DGLCNRy : 2dhglcn_c + h_c + nadph_c --> glcn_c + nadp_c
# 2DGULRx : 2dhguln_c + h_c + nadh_c --> idon__L_c + nad_c
# 2DGULRy : 2dhguln_c + h_c + nadph_c --> idon__L_c + nadp_c
# 2MAHMP : 2mahmp_c + h2o_c --> 4ampm_c + h_c + pi_c
# 34dhpactex : 34dhpac_e <=> 34dhpac_p
# 3AMPtex : 3amp_e <=> 3amp_p
# 3CMPtex : 3cmp_e <=> 3cmp_p
# 3GMPtex : 3gmp_e <=> 3gmp_p
# 3HAD100 : 3hdecACP_c --> h2o_c + tdec2eACP_c
# 3HAD120 : 3hddecACP_c --> h2o_c + tddec2eACP_c
# 3HAD121 : 3hcddec5eACP_c --> h2o_c + t3c5ddeceACP_c
# 3HAD140 : 3hmrsACP_c --> h2o_c + tmrs2eACP_c
# 3HAD141 : 3hcmrs7eACP_c --> h2o_c + t3c7mrseACP_c
# 3HAD160 : 3hpalmACP_c --> h2o_c + tpalm2eACP_c
# 3HAD161 : 3hcpalm9eACP_c --> h2o_c + t3c9palmeACP_c
# 3HAD180 : 3hoctaACP_c --> h2o_c + toctd2eACP_c
# 3HAD181 : 3hcvac11eACP_c --> h2o_c + t3c11vaceACP_c
# 3HAD40 : 3haACP_c --> but2eACP_c + h2o_c
# 3HAD60 : 3hhexACP_c --> h2o_c + thex2eACP_c
# 3HAD80 : 3hoctACP_c --> h2o_c + toct2eACP_c
# 3HCINNMH : 3hcinnm_c + h_c + nadh_c + o2_c --> dhcinnm_c + h2o_c + nad_c
# 3HPPPNH : 3hpppn_c + h_c + nadh_c + o2_c --> dhpppn_c + h2o_c + nad_c
# 3KGK : 3dhguln_c + atp_c --> 3dhgulnp_c + adp_c + h_c
# 3NTD2pp : 3ump_p + h2o_p --> pi_p + uri_p
# 3NTD4pp : 3cmp_p + h2o_p --> cytd_p + pi_p
# 3NTD7pp : 3amp_p + h2o_p --> adn_p + pi_p
# 3NTD9pp : 3gmp_p + h2o_p --> gsn_p + pi_p
# 3OAR100 : 3odecACP_c + h_c + nadph_c <=> 3hdecACP_c + nadp_c
# 3OAR120 : 3oddecACP_c + h_c + nadph_c <=> 3hddecACP_c + nadp_c
# 3OAR121 : 3ocddec5eACP_c + h_c + nadph_c --> 3hcddec5eACP_c + nadp_c
# 3OAR140 : 3omrsACP_c + h_c + nadph_c <=> 3hmrsACP_c + nadp_c
# 3OAR141 : 3ocmrs7eACP_c + h_c + nadph_c --> 3hcmrs7eACP_c + nadp_c
# 3OAR160 : 3opalmACP_c + h_c + nadph_c <=> 3hpalmACP_c + nadp_c
# 3OAR161 : 3ocpalm9eACP_c + h_c + nadph_c --> 3hcpalm9eACP_c + nadp_c
# 3OAR180 : 3ooctdACP_c + h_c + nadph_c <=> 3hoctaACP_c + nadp_c
# 3OAR181 : 3ocvac11eACP_c + h_c + nadph_c --> 3hcvac11eACP_c + nadp_c
# 3OAR40 : actACP_c + h_c + nadph_c <=> 3haACP_c + nadp_c
# 3OAR60 : 3ohexACP_c + h_c + nadph_c <=> 3hhexACP_c + nadp_c
# 3OAR80 : 3ooctACP_c + h_c + nadph_c <=> 3hoctACP_c + nadp_c
# 3OAS100 : h_c + malACP_c + ocACP_c --> 3odecACP_c + ACP_c + co2_c
# 3OAS120 : dcaACP_c + h_c + malACP_c --> 3oddecACP_c + ACP_c + co2_c
# 3OAS121 : cdec3eACP_c + h_c + malACP_c --> 3ocddec5eACP_c + ACP_c + co2_c
# 3OAS140 : ddcaACP_c + h_c + malACP_c --> 3omrsACP_c + ACP_c + co2_c
# 3OAS141 : cddec5eACP_c + h_c + malACP_c --> 3ocmrs7eACP_c + ACP_c + co2_c
# 3OAS160 : h_c + malACP_c + myrsACP_c --> 3opalmACP_c + ACP_c + co2_c
# 3OAS161 : h_c + malACP_c + tdeACP_c --> 3ocpalm9eACP_c + ACP_c + co2_c
# 3OAS180 : h_c + malACP_c + palmACP_c --> 3ooctdACP_c + ACP_c + co2_c
# 3OAS181 : h_c + hdeACP_c + malACP_c --> 3ocvac11eACP_c + ACP_c + co2_c
# 3OAS60 : butACP_c + h_c + malACP_c --> 3ohexACP_c + ACP_c + co2_c
# 3OAS80 : h_c + hexACP_c + malACP_c --> 3ooctACP_c + ACP_c + co2_c
# 3PEPTabcpp : LalaDgluMdap_p + atp_c + h2o_c --> LalaDgluMdap_c + adp_c + h_c + pi_c
# 3PEPTtex : LalaDgluMdap_e <=> LalaDgluMdap_p
# 3UMPtex : 3ump_e <=> 3ump_p
# 42A12BOOXpp : dopa_p + h2o_p + o2_p --> 34dhpac_p + h2o2_p + nh4_p
# 4HOXPACDtex : 4hoxpacd_e <=> 4hoxpacd_p
# 4HTHRS : h2o_c + phthr_c --> 4hthr_c + pi_c
# 4PCP : LalaDgluMdapDala_c + h2o_c --> LalaDgluMdap_c + ala__D_c
# 4PCPpp : LalaDgluMdapDala_p + h2o_p --> LalaDgluMdap_p + ala__D_p
# 4PEPTabcpp : LalaDgluMdapDala_p + atp_c + h2o_c --> LalaDgluMdapDala_c + adp_c + h_c + pi_c
# 4PEPTtex : LalaDgluMdapDala_e <=> LalaDgluMdapDala_p
# 5DGLCNR : 5dglcn_c + h_c + nadph_c <=> glcn_c + nadp_c
# 5DGLCNt2rpp : 5dglcn_p + h_p <=> 5dglcn_c + h_c
# 5DGLCNtex : 5dglcn_e <=> 5dglcn_p
# 5DOAN : dad_5_c + h2o_c --> 5drib_c + ade_c
# A5PISO : ru5p__D_c <=> ara5p_c
# AACPS1 : ACP_c + atp_c + ttdca_c --> amp_c + myrsACP_c + ppi_c
# AACPS2 : ACP_c + atp_c + ttdcea_c --> amp_c + ppi_c + tdeACP_c
# AACPS3 : ACP_c + atp_c + hdca_c --> amp_c + palmACP_c + ppi_c
# AACPS4 : ACP_c + atp_c + hdcea_c --> amp_c + hdeACP_c + ppi_c
# AACPS5 : ACP_c + atp_c + ocdcea_c --> amp_c + octeACP_c + ppi_c
# AACPS6 : ACP_c + atp_c + ocdca_c --> amp_c + ocdcaACP_c + ppi_c
# AACPS7 : ACP_c + atp_c + ddca_c --> amp_c + ddcaACP_c + ppi_c
# AACPS8 : ACP_c + atp_c + dca_c --> amp_c + dcaACP_c + ppi_c
# AACPS9 : ACP_c + atp_c + octa_c --> amp_c + ocACP_c + ppi_c
# AACTOOR : aact_c + h2o_c + o2_c --> h2o2_c + mthgxl_c + nh4_c
# AADDGT : dtdp4aaddg_c + unagamu_c --> dtdp_c + h_c + unagamuf_c
# AAMYL : 14glucan_c --> malthx_c
# AAMYLpp : 14glucan_p --> malthx_p
# AB6PGH : arbt6p_c + h2o_c --> g6p_c + hqn_c
# ABTA : 4abut_c + akg_c --> glu__L_c + sucsal_c
# ABUTD : 4abutn_c + h2o_c + nad_c --> 4abut_c + 2.0 h_c + nadh_c
# ABUTt2pp : 4abut_p + h_p --> 4abut_c + h_c
# ABUTtex : 4abut_e <=> 4abut_p
# ACACCT : acac_c + accoa_c --> aacoa_c + ac_c
# ACACT1r : 2.0 accoa_c <=> aacoa_c + coa_c
# ACACt2pp : acac_p + h_p <=> acac_c + h_c
# ACACtex : acac_e <=> acac_p
# ACALD : acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c
# ACALDtex : acald_e <=> acald_p
# ACALDtpp : acald_p <=> acald_c
# ACANTHAT : accoa_c + anth_c --> acanth_c + coa_c
# ACBIPGT : adocbip_c + gtp_c + h_c --> agdpcbi_c + ppi_c
# ACCOAC : accoa_c + atp_c + hco3_c --> adp_c + h_c + malcoa_c + pi_c
# ACCOAL : atp_c + coa_c + ppa_c --> adp_c + pi_c + ppcoa_c
# ACGAL1PPpp : acgal1p_p + h2o_p --> acgal_p + pi_p
# ACGAL1Ptex : acgal1p_e <=> acgal1p_p
# ACGALtex : acgal_e <=> acgal_p
# ACGAM1PPpp : acgam1p_p + h2o_p --> acgam_p + pi_p
# ACGAM1Ptex : acgam1p_e <=> acgam1p_p
# ACGAMK : acgam_c + atp_c --> acgam6p_c + adp_c + h_c
# ACGAMT : uacgam_c + udcpp_c --> ump_c + unaga_c
# ACGAptspp : acgam_p + pep_c --> acgam6p_c + pyr_c
# ACGAtex : acgam_e <=> acgam_p
# ACGK : acglu_c + atp_c --> acg5p_c + adp_c
# ACGS : accoa_c + glu__L_c --> acglu_c + coa_c + h_c
# ACHBS : 2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c
# ACKr : ac_c + atp_c <=> actp_c + adp_c
# ACLS : h_c + 2.0 pyr_c --> alac__S_c + co2_c
# ACM6PH : acmum6p_c + h2o_c --> acgam6p_c + lac__D_c
# ACMAMUT : uacmamu_c + unaga_c --> h_c + udp_c + unagamu_c
# ACMANAptspp : acmana_p + pep_c --> acmanap_c + pyr_c
# ACMANAtex : acmana_e <=> acmana_p
# ACMUMptspp : acmum_p + pep_c --> acmum6p_c + pyr_c
# ACMUMtex : acmum_e --> acmum_p
# ACNAMt2pp : acnam_p + h_p --> acnam_c + h_c
# ACNAMtex : acnam_e <=> acnam_p
# ACNML : acnam_c --> acmana_c + pyr_c
# ACOAD1f : btcoa_c + fad_c <=> b2coa_c + fadh2_c
# ACOAD2f : fad_c + hxcoa_c <=> fadh2_c + hx2coa_c
# ACOAD3f : fad_c + occoa_c <=> fadh2_c + oc2coa_c
# ACOAD4f : dcacoa_c + fad_c <=> dc2coa_c + fadh2_c
# ACOAD5f : ddcacoa_c + fad_c <=> dd2coa_c + fadh2_c
# ACOAD6f : fad_c + tdcoa_c <=> fadh2_c + td2coa_c
# ACOAD7f : fad_c + pmtcoa_c <=> fadh2_c + hdd2coa_c
# ACOAD8f : fad_c + stcoa_c <=> fadh2_c + od2coa_c
# ACOATA : ACP_c + accoa_c <=> acACP_c + coa_c
# ACODA : acorn_c + h2o_c --> ac_c + orn_c
# ACOLIPAtex : acolipa_p --> acolipa_e
# ACONIs : acon_T_c <=> acon_C_c
# ACONMT : acon_T_c + amet_c --> aconm_c + ahcys_c
# ACONTa : cit_c <=> acon_C_c + h2o_c
# ACONTb : acon_C_c + h2o_c <=> icit_c
# ACOTA : acorn_c + akg_c <=> acg5sa_c + glu__L_c
# ACPS1 : apoACP_c + coa_c --> ACP_c + h_c + pap_c
# ACS : ac_c + atp_c + coa_c --> accoa_c + amp_c + ppi_c
# ACSERtex : acser_e <=> acser_p
# ACSERtpp : acser_c --> acser_p
# ACt2rpp : ac_p + h_p <=> ac_c + h_c
# ACt4pp : ac_p + na1_p --> ac_c + na1_c
# ACtex : ac_e <=> ac_p
# ADA : adn_c + h2o_c + h_c --> ins_c + nh4_c
# ADCL : 4adcho_c --> 4abz_c + h_c + pyr_c
# ADCS : chor_c + gln__L_c --> 4adcho_c + glu__L_c
# ADD : ade_c + h2o_c + h_c --> hxan_c + nh4_c
# ADEt2rpp : ade_p + h_p <=> ade_c + h_c
# ADEtex : ade_e <=> ade_p
# ADK1 : amp_c + atp_c <=> 2.0 adp_c
# ADK3 : amp_c + gtp_c <=> adp_c + gdp_c
# ADK4 : amp_c + itp_c <=> adp_c + idp_c
# ADMDC : amet_c + h_c --> ametam_c + co2_c
# ADNCYC : atp_c --> camp_c + ppi_c
# ADNK1 : adn_c + atp_c --> adp_c + amp_c + h_c
# ADNUC : adn_c + h2o_c --> ade_c + rib__D_c
# ADNt2pp_copy1 : adn_p + h_p --> adn_c + h_c
# ADNt2pp_copy2 : adn_p + h_p <=> adn_c + h_c
# ADNtex : adn_e <=> adn_p
# ADOCBIK : adocbi_c + atp_c --> adocbip_c + adp_c + h_c
# ADOCBLS : agdpcbi_c + rdmbzi_c --> adocbl_c + gmp_c + h_c
# ADOCBLabcpp : adocbl_p + atp_c + h2o_c --> adocbl_c + adp_c + h_c + pi_c
# ADOCBLtonex : adocbl_e + h_p --> adocbl_p + h_c
# ADPRDP : adprib_c + h2o_c --> amp_c + 2.0 h_c + r5p_c
# ADPT : ade_c + prpp_c --> amp_c + ppi_c
# ADSK : aps_c + atp_c --> adp_c + h_c + paps_c
# ADSL1r : dcamp_c <=> amp_c + fum_c
# ADSL2r : 25aics_c <=> aicar_c + fum_c
# ADSS : asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + 2.0 h_c + pi_c
# AGDC : acgam6p_c + h2o_c --> ac_c + gam6p_c
# AGM3PA : anhgm3p_c + h2o_c --> LalaDgluMdap_c + anhgm_c
# AGM3PApp : anhgm3p_p + h2o_p --> LalaDgluMdap_p + anhgm_p
# AGM3PH : anhgm3p_c + h2o_c --> acgam_c + anhm3p_c
# AGM3Pt2pp : anhgm3p_p + h_p --> anhgm3p_c + h_c
# AGM4PA : anhgm4p_c + h2o_c --> LalaDgluMdapDala_c + anhgm_c
# AGM4PApp : anhgm4p_p + h2o_p --> LalaDgluMdapDala_p + anhgm_p
# AGM4PCP : anhgm4p_c + h2o_c --> ala__D_c + anhgm3p_c
# AGM4PCPpp : anhgm4p_p + h2o_p --> ala__D_p + anhgm3p_p
# AGM4PH : anhgm4p_c + h2o_c --> acgam_c + anhm4p_c
# AGM4Pt2pp : anhgm4p_p + h_p --> anhgm4p_c + h_c
# AGMH : anhgm_c + h2o_c --> acgam_c + anhm_c
# AGMHE : adphep_DD_c --> adphep_LD_c
# AGMT : agm_c + h2o_c --> ptrc_c + urea_c
# AGMt2pp : anhgm_p + h_p --> anhgm_c + h_c
# AGMtex : agm_e <=> agm_p
# AGPAT120 : 1ddecg3p_c + ddcaACP_c --> ACP_c + pa120_c
# AGPAT140 : 1tdecg3p_c + myrsACP_c --> ACP_c + pa140_c
# AGPAT141 : 1tdec7eg3p_c + tdeACP_c --> ACP_c + pa141_c
# AGPAT160 : 1hdecg3p_c + palmACP_c --> ACP_c + pa160_c
# AGPAT161 : 1hdec9eg3p_c + hdeACP_c --> ACP_c + pa161_c
# AGPAT180 : 1odecg3p_c + ocdcaACP_c --> ACP_c + pa180_c
# AGPAT181 : 1odec11eg3p_c + octeACP_c --> ACP_c + pa181_c
# AGPR : acg5sa_c + nadp_c + pi_c <=> acg5p_c + h_c + nadph_c
# AGt3 : ag_c + h_e --> ag_e + h_c
# AHCYSNS : ahcys_c + h2o_c --> ade_c + rhcys_c
# AICART : 10fthf_c + aicar_c <=> fprica_c + thf_c
# AIRC2 : air_c + atp_c + hco3_c --> 5caiz_c + adp_c + h_c + pi_c
# AIRC3 : 5aizc_c <=> 5caiz_c
# AKGDH : akg_c + coa_c + nad_c --> co2_c + nadh_c + succoa_c
# AKGt2rpp : akg_p + h_p <=> akg_c + h_c
# AKGtex : akg_e <=> akg_p
# ALAALAD : alaala_c + h2o_c --> 2.0 ala__D_c
# ALAALAabcpp : alaala_p + atp_c + h2o_c --> adp_c + alaala_c + h_c + pi_c
# ALAALAr : 2.0 ala__D_c + atp_c <=> adp_c + alaala_c + h_c + pi_c
# ALAALAtex : alaala_e <=> alaala_p
# ALAGLUE : LalaDglu_c <=> LalaLglu_c
# ALAR : ala__L_c <=> ala__D_c
# ALATA_D2 : ala__D_c + pydx5p_c --> pyam5p_c + pyr_c
# ALATA_L : akg_c + ala__L_c <=> glu__L_c + pyr_c
# ALATA_L2 : ala__L_c + pydx5p_c --> pyam5p_c + pyr_c
# ALATRS : ala__L_c + atp_c + trnaala_c --> alatrna_c + amp_c + ppi_c
# ALAabcpp : ala__L_p + atp_c + h2o_c --> adp_c + ala__L_c + h_c + pi_c
# ALAt2pp : ala__L_p + h_p --> ala__L_c + h_c
# ALAt4pp : ala__L_p + na1_p --> ala__L_c + na1_c
# ALAtex : ala__L_e <=> ala__L_p
# ALCD19 : glyald_c + h_c + nadh_c <=> glyc_c + nad_c
# ALCD2x : etoh_c + nad_c <=> acald_c + h_c + nadh_c
# ALDD19xr : h2o_c + nad_c + pacald_c --> 2.0 h_c + nadh_c + pac_c
# ALDD2x : acald_c + h2o_c + nad_c --> ac_c + 2.0 h_c + nadh_c
# ALDD2y : acald_c + h2o_c + nadp_c --> ac_c + 2.0 h_c + nadph_c
# ALDD3y : h2o_c + nadp_c + ppal_c --> 2.0 h_c + nadph_c + ppa_c
# ALDD4 : btal_c + h2o_c + nad_c --> but_c + 2.0 h_c + nadh_c
# ALLK : all__D_c + atp_c --> adp_c + all6p_c + h_c
# ALLPI : all6p_c <=> allul6p_c
# ALLTAMH : alltt_c + 2.0 h2o_c + 2.0 h_c --> co2_c + 2.0 nh4_c + urdglyc_c
# ALLTN : alltn_c + h2o_c --> alltt_c + h_c
# ALLTNt2rpp : alltn_p + h_p <=> alltn_c + h_c
# ALLTNtex : alltn_e <=> alltn_p
# ALLULPE : allul6p_c <=> f6p_c
# ALLabcpp : all__D_p + atp_c + h2o_c --> adp_c + all__D_c + h_c + pi_c
# ALLtex : all__D_e <=> all__D_p
# ALPATE160pp : alpp_p + pe160_p --> 2agpe160_p + lpp_p
# ALPATG160pp : alpp_p + pg160_p --> 2agpg160_p + lpp_p
# ALR2 : h_c + mthgxl_c + nadph_c --> acetol_c + nadp_c
# ALR4x : acetol_c + h_c + nadh_c --> 12ppd__R_c + nad_c
# ALTRH : altrn_c --> 2ddglcn_c + h2o_c
# AM3PA : anhm3p_c + h2o_c --> LalaDgluMdap_c + anhm_c
# AM4PA : anhm4p_c + h2o_c --> LalaDgluMdapDala_c + anhm_c
# AM4PCP : anhm4p_c + h2o_c --> ala__D_c + anhm3p_c
# AMALT1 : malt_c + malttr_c --> glc__D_c + maltttr_c
# AMALT2 : malt_c + maltttr_c --> glc__D_c + maltpt_c
# AMALT3 : malt_c + maltpt_c --> glc__D_c + malthx_c
# AMALT4 : malt_c + malthx_c --> glc__D_c + malthp_c
# AMANAPEr : acmanap_c <=> acgam6p_c
# AMANK : acmana_c + atp_c --> acmanap_c + adp_c + h_c
# AMAOTr : 8aonn_c + amet_c <=> amob_c + dann_c
# AMMQLT8 : 2dmmql8_c + amet_c --> ahcys_c + h_c + mql8_c
# AMPMS2 : air_c + h2o_c + nad_c --> 4ampm_c + 2.0 for_c + 3.0 h_c + nadh_c
# AMPN : amp_c + h2o_c --> ade_c + r5p_c
# AMPTASECG : cgly_c + h2o_c --> cys__L_c + gly_c
# AMPTASEPG : h2o_c + progly_c --> gly_c + pro__L_c
# AMPtex : amp_e <=> amp_p
# ANHGMtex : anhgm_e <=> anhgm_p
# ANHMK : anhm_c + atp_c + h2o_c --> acmum6p_c + adp_c + h_c
# ANPRT : anth_c + prpp_c --> ppi_c + pran_c
# ANS : chor_c + gln__L_c --> anth_c + glu__L_c + h_c + pyr_c
# AOBUTDs : 2aobut_c + h_c --> aact_c + co2_c
# AOXSr : ala__L_c + h_c + pmcoa_c <=> 8aonn_c + co2_c + coa_c
# AP4AH : ap4a_c + h2o_c --> 2.0 adp_c + 2.0 h_c
# AP5AH : ap5a_c + h2o_c --> adp_c + atp_c + 2.0 h_c
# APRAUR : 5apru_c + h_c + nadph_c --> 5aprbu_c + nadp_c
# ARAI : arab__L_c <=> rbl__L_c
# ARBTNR1 : 2.0 arbtn_fe3_c + fadh2_c --> 2.0 arbtn_c + fad_c + 2.0 fe2_c + 2.0 h_c
# ARBTNR2 : 2.0 arbtn_fe3_c + fmnh2_c --> 2.0 arbtn_c + 2.0 fe2_c + fmn_c + 2.0 h_c
# ARBTNR3 : 2.0 arbtn_fe3_c + rbflvrd_c --> 2.0 arbtn_c + 2.0 fe2_c + 2.0 h_c + ribflv_c
# ARBTNabcpp : arbtn_fe3_p + atp_c + h2o_c --> adp_c + arbtn_fe3_c + h_c + pi_c
# ARBTNexs : arbtn_e + fe3_e --> arbtn_fe3_e
# ARBTNtex : arbtn_p + h_p --> arbtn_e + h_c
# ARBTNtonex : arbtn_fe3_e + h_p --> arbtn_fe3_p + h_c
# ARBTNtpp : arbtn_c + h_p --> arbtn_p + h_c
# ARBabcpp : arab__L_p + atp_c + h2o_c --> adp_c + arab__L_c + h_c + pi_c
# ARBt2rpp : arab__L_p + h_p <=> arab__L_c + h_c
# ARBt3ipp : arab__L_c + h_p --> arab__L_p + h_c
# ARBtex : arab__L_e <=> arab__L_p
# ARGAGMt7pp : agm_c + arg__L_p <=> agm_p + arg__L_c
# ARGDC : arg__L_c + h_c --> agm_c + co2_c
# ARGDCpp : arg__L_p + h_p --> agm_p + co2_p
# ARGORNt7pp : arg__L_p + orn_c <=> arg__L_c + orn_p
# ARGSL : argsuc_c <=> arg__L_c + fum_c
# ARGSS : asp__L_c + atp_c + citr__L_c --> amp_c + argsuc_c + h_c + ppi_c
# ARGTRS : arg__L_c + atp_c + trnaarg_c --> amp_c + argtrna_c + ppi_c
# ARGabcpp : arg__L_p + atp_c + h2o_c --> adp_c + arg__L_c + h_c + pi_c
# ARGt3pp : arg__L_c + h_p --> arg__L_p + h_c
# ARGtex : arg__L_e <=> arg__L_p
# ASAD : aspsa_c + nadp_c + pi_c <=> 4pasp_c + h_c + nadph_c
# ASCBPL : ascb6p_c + h2o_c --> 3dhgulnp_c + h_c
# ASCBptspp : ascb__L_p + pep_c --> ascb6p_c + pyr_c
# ASCBtex : ascb__L_e <=> ascb__L_p
# ASNN : asn__L_c + h2o_c --> asp__L_c + nh4_c
# ASNNpp : asn__L_p + h2o_p --> asp__L_p + nh4_p
# ASNS1 : asp__L_c + atp_c + gln__L_c + h2o_c --> amp_c + asn__L_c + glu__L_c + h_c + ppi_c
# ASNS2 : asp__L_c + atp_c + nh4_c --> amp_c + asn__L_c + h_c + ppi_c
# ASNTRS : asn__L_c + atp_c + trnaasn_c --> amp_c + asntrna_c + ppi_c
# ASNabcpp : asn__L_p + atp_c + h2o_c --> adp_c + asn__L_c + h_c + pi_c
# ASNt2rpp : asn__L_p + h_p <=> asn__L_c + h_c
# ASNtex : asn__L_e <=> asn__L_p
# ASO3t8pp : aso3_c + atp_c + h2o_c --> adp_c + aso3_p + h_c + pi_c
# ASO3tex : aso3_e <=> aso3_p
# ASP1DC : asp__L_c + h_c --> ala_B_c + co2_c
# ASPCT : asp__L_c + cbp_c --> cbasp_c + h_c + pi_c
# ASPK : asp__L_c + atp_c <=> 4pasp_c + adp_c
# ASPO3 : asp__L_c + q8_c --> h_c + iasp_c + q8h2_c
# ASPO4 : asp__L_c + mqn8_c --> h_c + iasp_c + mql8_c
# ASPO5 : asp__L_c + fum_c --> h_c + iasp_c + succ_c
# ASPO6 : asp__L_c + o2_c --> h2o2_c + h_c + iasp_c
# ASPT : asp__L_c --> fum_c + nh4_c
# ASPTA : akg_c + asp__L_c <=> glu__L_c + oaa_c
# ASPTRS : asp__L_c + atp_c + trnaasp_c --> amp_c + asptrna_c + ppi_c
# ASPabcpp : asp__L_p + atp_c + h2o_c --> adp_c + asp__L_c + h_c + pi_c
# ASPt2_2pp : asp__L_p + 2.0 h_p --> asp__L_c + 2.0 h_c
# ASPt2_3pp : asp__L_p + 3.0 h_p --> asp__L_c + 3.0 h_c
# ASPt2pp : asp__L_p + h_p --> asp__L_c + h_c
# ASPtex : asp__L_e <=> asp__L_p
# ASR : aso4_c + 2.0 gthrd_c --> aso3_c + gthox_c + h2o_c
# AST : arg__L_c + succoa_c --> coa_c + h_c + sucarg_c
# ATHRDHr : athr__L_c + nadp_c <=> 2aobut_c + h_c + nadph_c
# ATPHs : atp_c + h2o_c + h_c --> itp_c + nh4_c
# ATPM : atp_c + h2o_c --> adp_c + h_c + pi_c
# ATPPRT : atp_c + prpp_c --> ppi_c + prbatp_c
# ATPS4rpp : adp_c + 4.0 h_p + pi_c <=> atp_c + h2o_c + 3.0 h_c
# BALAt2pp : ala_B_p + h_p --> ala_B_c + h_c
# BALAtex : ala_B_e <=> ala_B_p
# BETALDHx : betald_c + h2o_c + nad_c --> glyb_c + 2.0 h_c + nadh_c
# BETALDHy : betald_c + h2o_c + nadp_c --> glyb_c + 2.0 h_c + nadph_c
# BPNT : h2o_c + pap_c --> amp_c + pi_c
# BSORx : btnso_c + h_c + nadh_c --> btn_c + h2o_c + nad_c
# BSORy : btnso_c + h_c + nadph_c --> btn_c + h2o_c + nadp_c
# BTS4 : amet_c + dtbt_c + s_c --> btn_c + dad_5_c + h_c + met__L_c
# BUTCT : accoa_c + but_c --> ac_c + btcoa_c
# BUTSO3abcpp : atp_c + butso3_p + h2o_c --> adp_c + butso3_c + h_c + pi_c
# BUTSO3tex : butso3_e <=> butso3_p
# BUTt2rpp : but_p + h_p <=> but_c + h_c
# BUTtex : but_e <=> but_p
# CA2t3pp : ca2_c + h_p --> ca2_p + h_c
# CA2tex : ca2_e <=> ca2_p
# CADVtpp : 15dap_c + h_p + lys__L_p --> 15dap_p + h_c + lys__L_c
# CAT : 2.0 h2o2_c --> 2.0 h2o_c + o2_c
# CAt6pp : ca2_c + na1_p <=> ca2_p + na1_c
# CBIAT : atp_c + cbi_c + h_c <=> adocbi_c + pppi_c
# CBItonex : cbi_e + h_p --> cbi_p + h_c
# CBIuabcpp : atp_c + cbi_p + h2o_c --> adp_c + cbi_c + h_c + pi_c
# CBL1abcpp : atp_c + cbl1_p + h2o_c --> adp_c + cbl1_c + h_c + pi_c
# CBL1tonex : cbl1_e + h_p --> cbl1_p + h_c
# CBLAT : atp_c + cbl1_c + h_c <=> adocbl_c + pppi_c
# CBMKr : atp_c + co2_c + nh4_c <=> adp_c + cbp_c + 2.0 h_c
# CBPS : 2.0 atp_c + gln__L_c + h2o_c + hco3_c --> 2.0 adp_c + cbp_c + glu__L_c + 2.0 h_c + pi_c
# CD2abcpp : atp_c + cd2_c + h2o_c --> adp_c + cd2_p + h_c + pi_c
# CD2t3pp : cd2_c + h_p --> cd2_p + h_c
# CD2tex : cd2_e <=> cd2_p
# CD2tpp : cd2_p --> cd2_c
# CDAPPA120 : cdpdddecg_c + h2o_c --> cmp_c + 2.0 h_c + pa120_c
# CDAPPA140 : cdpdtdecg_c + h2o_c --> cmp_c + 2.0 h_c + pa140_c
# CDAPPA141 : cdpdtdec7eg_c + h2o_c --> cmp_c + 2.0 h_c + pa141_c
# CDAPPA160 : cdpdhdecg_c + h2o_c --> cmp_c + 2.0 h_c + pa160_c
# CDAPPA161 : cdpdhdec9eg_c + h2o_c --> cmp_c + 2.0 h_c + pa161_c
# CDAPPA180 : cdpdodecg_c + h2o_c --> cmp_c + 2.0 h_c + pa180_c
# CDAPPA181 : cdpdodec11eg_c + h2o_c --> cmp_c + 2.0 h_c + pa181_c
# CDPMEK : 4c2me_c + atp_c --> 2p4c2me_c + adp_c + h_c
# CFAS160E : 2.0 amet_c + pe161_c --> 2.0 ahcys_c + cpe160_c + 2.0 h_c
# CFAS160G : 2.0 amet_c + pg161_c --> 2.0 ahcys_c + cpg160_c + 2.0 h_c
# CFAS180E : 2.0 amet_c + pe181_c --> 2.0 ahcys_c + cpe180_c + 2.0 h_c
# CFAS180G : 2.0 amet_c + pg181_c --> 2.0 ahcys_c + cpg180_c + 2.0 h_c
# CGLYabcpp : atp_c + cgly_p + h2o_c --> adp_c + cgly_c + h_c + pi_c
# CGLYtex : cgly_e <=> cgly_p
# CHLabcpp : atp_c + chol_p + h2o_c --> adp_c + chol_c + h_c + pi_c
# CHLt2pp : chol_p + h_p --> chol_c + h_c
# CHLtex : chol_e <=> chol_p
# CHORM : chor_c --> pphn_c
# CHORS : 3psme_c --> chor_c + pi_c
# CHRPL : chor_c --> 4hbz_c + pyr_c
# CINNDO : cinnm_c + h_c + nadh_c + o2_c --> cenchddd_c + nad_c
# CITL : cit_c --> ac_c + oaa_c
# CITt7pp : cit_p + succ_c --> cit_c + succ_p
# CITtex : cit_e <=> cit_p
# CLIPAtex : lipa_cold_p --> lipa_cold_e
# CLPNH120pp : clpn120_p + h2o_p --> h_p + pa120_p + pg120_p
# CLPNH140pp : clpn140_p + h2o_p --> h_p + pa140_p + pg140_p
# CLPNH141pp : clpn141_p + h2o_p --> h_p + pa141_p + pg141_p
# CLPNH160pp : clpn160_p + h2o_p --> h_p + pa160_p + pg160_p
# CLPNH161pp : clpn161_p + h2o_p --> h_p + pa161_p + pg161_p
# CLPNH180pp : clpn180_p + h2o_p --> h_p + pa180_p + pg180_p
# CLPNH181pp : clpn181_p + h2o_p --> h_p + pa181_p + pg181_p
# CLPNS120pp : 2.0 pg120_p <=> clpn120_p + glyc_p
# CLPNS140pp : 2.0 pg140_p <=> clpn140_p + glyc_p
# CLPNS141pp : 2.0 pg141_p <=> clpn141_p + glyc_p
# CLPNS160pp : 2.0 pg160_p <=> clpn160_p + glyc_p
# CLPNS161pp : 2.0 pg161_p <=> clpn161_p + glyc_p
# CLPNS180pp : 2.0 pg180_p <=> clpn180_p + glyc_p
# CLPNS181pp : 2.0 pg181_p <=> clpn181_p + glyc_p
# CLt3_2pp : 2.0 cl_p + h_c --> 2.0 cl_c + h_p
# CLtex : cl_e <=> cl_p
# CMPN : cmp_c + h2o_c --> csn_c + r5p_c
# CMPtex : cmp_e <=> cmp_p
# CO2tex : co2_e <=> co2_p
# CO2tpp : co2_p <=> co2_c
# COBALT2abcpp : atp_c + cobalt2_c + h2o_c --> adp_c + cobalt2_p + h_c + pi_c
# COBALT2t3pp : cobalt2_c + h_p --> cobalt2_p + h_c
# COBALT2tex : cobalt2_e <=> cobalt2_p
# COBALT2tpp : cobalt2_p --> cobalt2_c
# COLIPAabcpp : atp_c + colipa_c + h2o_c --> adp_c + colipa_p + h_c + pi_c
# COLIPAtex : colipa_p --> colipa_e
# CPGNR1 : 2.0 cpgn_c + fadh2_c --> 2.0 cpgn_un_c + fad_c + 2.0 fe2_c + 2.0 h_c
# CPGNR2 : 2.0 cpgn_c + fmnh2_c --> 2.0 cpgn_un_c + 2.0 fe2_c + fmn_c + 2.0 h_c
# CPGNR3 : 2.0 cpgn_c + rbflvrd_c --> 2.0 cpgn_un_c + 2.0 fe2_c + 2.0 h_c + ribflv_c
# CPGNUtex : cpgn_un_p + h_p --> cpgn_un_e + h_c
# CPGNUtpp : cpgn_un_c + h_p --> cpgn_un_p + h_c
# CPGNabcpp : atp_c + cpgn_p + h2o_c --> adp_c + cpgn_c + h_c + pi_c
# CPGNexs : cpgn_un_e + fe3_e --> cpgn_e
# CPGNtonex : cpgn_e + h_p --> cpgn_p + h_c
# CPPPGO : cpppg3_c + 2.0 h_c + o2_c --> 2.0 co2_c + 2.0 h2o_c + pppg9_c
# CPPPGO2 : 2.0 amet_c + cpppg3_c --> 2.0 co2_c + 2.0 dad_5_c + 2.0 met__L_c + pppg9_c
# CRNBTCT : bbtcoa_c + crn_c <=> crncoa_c + gbbtn_c
# CRNCAL2 : atp_c + coa_c + crn_c --> adp_c + crncoa_c + pi_c
# CRNCAR : crncoa_c <=> crnDcoa_c
# CRNCBCT : crn_c + ctbtcoa_c <=> crncoa_c + ctbt_c
# CRNCDH : crncoa_c <=> ctbtcoa_c + h2o_c
# CRNDCAL2 : atp_c + coa_c + crn__D_c --> adp_c + crnDcoa_c + pi_c
# CRNDabcpp : atp_c + crn__D_p + h2o_c --> adp_c + crn__D_c + h_c + pi_c
# CRNDt2rpp : crn__D_p + h_p <=> crn__D_c + h_c
# CRNabcpp : atp_c + crn_p + h2o_c --> adp_c + crn_c + h_c + pi_c
# CRNt2rpp : crn_p + h_p <=> crn_c + h_c
# CRNt7pp : crn_p + gbbtn_c --> crn_c + gbbtn_p
# CRNt8pp : crn__D_c + crn_p --> crn__D_p + crn_c
# CRNtex : crn_e <=> crn_p
# CS : accoa_c + h2o_c + oaa_c --> cit_c + coa_c + h_c
# CSND : csn_c + h2o_c + h_c --> nh4_c + ura_c
# CSNt2pp : csn_p + h_p --> csn_c + h_c
# CSNtex : csn_e <=> csn_p
# CTBTCAL2 : atp_c + coa_c + ctbt_c --> adp_c + ctbtcoa_c + pi_c
# CTBTabcpp : atp_c + ctbt_p + h2o_c --> adp_c + ctbt_c + h_c + pi_c
# CTBTt2rpp : ctbt_p + h_p <=> ctbt_c + h_c
# CTPS2 : atp_c + gln__L_c + h2o_c + utp_c --> adp_c + ctp_c + glu__L_c + 2.0 h_c + pi_c
# CU1Opp : 4.0 cu_p + 4.0 h_p + o2_p --> 4.0 cu2_p + 2.0 h2o_p
# CU1abcpp : atp_c + cu_c + h2o_c --> adp_c + cu_p + h_c + pi_c
# CU2abcpp : atp_c + cu2_c + h2o_c --> adp_c + cu2_p + h_c + pi_c
# CU2tex : cu2_e <=> cu2_p
# CU2tpp : cu2_p --> cu2_c
# CUt3 : cu_c + h_e --> cu_e + h_c
# CUtex : cu_e <=> cu_p
# CYANST : cyan_c + tsul_c --> h_c + so3_c + tcynt_c
# CYANSTpp : cyan_p + tsul_p --> h_p + so3_p + tcynt_p
# CYANtex : cyan_e <=> cyan_p
# CYNTAH : cynt_c + 3.0 h_c + hco3_c --> 2.0 co2_c + nh4_c
# CYNTt2pp : cynt_p + h_p --> cynt_c + h_c
# CYNTtex : cynt_e <=> cynt_p
# CYSDDS : cys__D_c + h2o_c --> h2s_c + nh4_c + pyr_c
# CYSDS : cys__L_c + h2o_c --> h2s_c + nh4_c + pyr_c
# CYSDabcpp : atp_c + cys__D_p + h2o_c --> adp_c + cys__D_c + h_c + pi_c
# CYSDtex : cys__D_e <=> cys__D_p
# CYSS : acser_c + h2s_c --> ac_c + cys__L_c + h_c
# CYSSADS : 3sala_c + 2.0 h_c --> ala__L_c + so2_c
# CYSTL : cyst__L_c + h2o_c --> hcys__L_c + nh4_c + pyr_c
# CYSTRS : atp_c + cys__L_c + trnacys_c --> amp_c + cystrna_c + ppi_c
# CYSabc2pp : atp_c + cys__L_c + h2o_c --> adp_c + cys__L_p + h_c + pi_c
# CYSabcpp : atp_c + cys__L_p + h2o_c --> adp_c + cys__L_c + h_c + pi_c
# CYStex : cys__L_e <=> cys__L_p
# CYStpp : cys__L_c --> cys__L_p
# CYTBD2pp : 2.0 h_c + mql8_c + 0.5 o2_c --> h2o_c + 2.0 h_p + mqn8_c
# CYTBDpp : 2.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 2.0 h_p + q8_c
# CYTBO3_4pp : 4.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 4.0 h_p + q8_c
# CYTD : cytd_c + h2o_c + h_c --> nh4_c + uri_c
# CYTDH : cytd_c + h2o_c --> csn_c + rib__D_c
# CYTDK2 : cytd_c + gtp_c --> cmp_c + gdp_c + h_c
# CYTDt2pp_copy1 : cytd_p + h_p --> cytd_c + h_c
# CYTDt2pp_copy2 : cytd_p + h_p <=> cytd_c + h_c
# CYTDtex : cytd_e <=> cytd_p
# CYTK1 : atp_c + cmp_c <=> adp_c + cdp_c
# CYTK2 : atp_c + dcmp_c <=> adp_c + dcdp_c
# DAAD : ala__D_c + fad_c + h2o_c --> fadh2_c + nh4_c + pyr_c
# DADA : dad_2_c + h2o_c + h_c --> din_c + nh4_c
# DADK : atp_c + damp_c <=> adp_c + dadp_c
# DADNt2pp : dad_2_p + h_p --> dad_2_c + h_c
# DADNtex : dad_2_e <=> dad_2_p
# DAGK120 : 12dgr120_c + atp_c --> adp_c + h_c + pa120_c
# DAGK140 : 12dgr140_c + atp_c --> adp_c + h_c + pa140_c
# DAGK141 : 12dgr141_c + atp_c --> adp_c + h_c + pa141_c
# DAGK160 : 12dgr160_c + atp_c --> adp_c + h_c + pa160_c
# DAGK161 : 12dgr161_c + atp_c --> adp_c + h_c + pa161_c
# DAGK180 : 12dgr180_c + atp_c --> adp_c + h_c + pa180_c
# DAGK181 : 12dgr181_c + atp_c --> adp_c + h_c + pa181_c
# DALAt2pp : ala__D_p + h_p --> ala__D_c + h_c
# DALAtex : ala__D_e <=> ala__D_p
# DAMPtex : damp_e <=> damp_p
# DAPAL : 23dappa_c + h2o_c --> 2.0 nh4_c + pyr_c
# DAPDC : 26dap__M_c + h_c --> co2_c + lys__L_c
# DAPE : 26dap_LL_c <=> 26dap__M_c
# DAPabcpp : 26dap__M_p + atp_c + h2o_c --> 26dap__M_c + adp_c + h_c + pi_c
# DAPtex : 15dap_e <=> 15dap_p
# DASYN120 : ctp_c + h_c + pa120_c --> cdpdddecg_c + ppi_c
# DASYN140 : ctp_c + h_c + pa140_c --> cdpdtdecg_c + ppi_c
# DASYN141 : ctp_c + h_c + pa141_c --> cdpdtdec7eg_c + ppi_c
# DASYN160 : ctp_c + h_c + pa160_c --> cdpdhdecg_c + ppi_c
# DASYN161 : ctp_c + h_c + pa161_c --> cdpdhdec9eg_c + ppi_c
# DASYN180 : ctp_c + h_c + pa180_c --> cdpdodecg_c + ppi_c
# DASYN181 : ctp_c + h_c + pa181_c --> cdpdodec11eg_c + ppi_c
# DATPHs : datp_c + h2o_c + h_c --> ditp_c + nh4_c
# DB4PS : ru5p__D_c --> db4p_c + for_c + h_c
# DBTS : atp_c + co2_c + dann_c --> adp_c + dtbt_c + 3.0 h_c + pi_c
# DCAtex : dca_e <=> dca_p
# DCMPtex : dcmp_e <=> dcmp_p
# DCTPD : dctp_c + h2o_c + h_c --> dutp_c + nh4_c
# DCYTD : dcyt_c + h2o_c + h_c --> duri_c + nh4_c
# DCYTt2pp : dcyt_p + h_p --> dcyt_c + h_c
# DCYTtex : dcyt_e <=> dcyt_p
# DDCAtexi : ddca_e --> ddca_p
# DDGALK : 2dh3dgal_c + atp_c --> 2dh3dgal6p_c + adp_c + h_c
# DDGLCNt2rpp : 2ddglcn_p + h_p <=> 2ddglcn_c + h_c
# DDGLCNtex : 2ddglcn_e <=> 2ddglcn_p
# DDGLK : 2ddglcn_c + atp_c --> 2ddg6p_c + adp_c + h_c
# DDPA : e4p_c + h2o_c + pep_c --> 2dda7p_c + pi_c
# DDPGALA : 2dh3dgal6p_c <=> g3p_c + pyr_c
# DGK1 : atp_c + dgmp_c <=> adp_c + dgdp_c
# DGMPtex : dgmp_e <=> dgmp_p
# DGSNt2pp : dgsn_p + h_p --> dgsn_c + h_c
# DGSNtex : dgsn_e <=> dgsn_p
# DHAD1 : 23dhmb_c --> 3mob_c + h2o_c
# DHAD2 : 23dhmp_c --> 3mop_c + h2o_c
# DHAPT : dha_c + pep_c --> dhap_c + pyr_c
# DHAtex : dha_e <=> dha_p
# DHAtpp : dha_p <=> dha_c
# DHBD : 23ddhb_c + nad_c <=> 23dhb_c + h_c + nadh_c
# DHBS : 23dhb_c + atp_c + h_c --> 23dhba_c + ppi_c
# DHBSH : 23dhbzs_c + h2o_c --> 23dhb_c + ser__L_c
# DHCIND : cenchddd_c + nad_c --> dhcinnm_c + h_c + nadh_c
# DHCINDO : dhcinnm_c + o2_c --> h_c + hkntd_c
# DHDPRy : 23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c
# DHDPS : aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c
# DHFR : dhf_c + h_c + nadph_c <=> nadp_c + thf_c
# DHFS : atp_c + dhpt_c + glu__L_c --> adp_c + dhf_c + h_c + pi_c
# DHNAOT4 : dhna_c + h_c + octdp_c --> 2dmmql8_c + co2_c + ppi_c
# DHNPA2r : dhnpt_c --> 6hmhpt_c + gcald_c
# DHORD2 : dhor__S_c + q8_c --> orot_c + q8h2_c
# DHORD5 : dhor__S_c + mqn8_c --> mql8_c + orot_c
# DHORTS : dhor__S_c + h2o_c <=> cbasp_c + h_c
# DHPPD : cechddd_c + nad_c --> dhpppn_c + h_c + nadh_c
# DHPPDA2 : 25drapp_c + h2o_c + h_c --> 5apru_c + nh4_c
# DHPS2 : 4abz_c + 6hmhptpp_c --> dhpt_c + ppi_c
# DHPTDCs : dhptd_c --> h2o_c + hmfurn_c
# DHPTPE : ahdt_c <=> dhmptp_c
# DHQS : 2dda7p_c --> 3dhq_c + pi_c
# DHQTi : 3dhq_c --> 3dhsk_c + h2o_c
# DIMPtex : dimp_e <=> dimp_p
# DINSt2pp : din_p + h_p --> din_c + h_c
# DINStex : din_e <=> din_p
# DKGLCNR1 : 25dkglcn_c + h_c + nadph_c --> 2dhguln_c + nadp_c
# DKGLCNR2x : 25dkglcn_c + h_c + nadh_c --> 5dglcn_c + nad_c
# DKGLCNR2y : 25dkglcn_c + h_c + nadph_c --> 5dglcn_c + nadp_c
# DKMPPD : dkmpp_c + h2o_c + o2_c --> 2kmb_c + for_c + 2.0 h_c + pi_c
# DKMPPD3 : dkmpp_c + 3.0 h2o_c + 2.0 nad_c --> 2kmb_c + for_c + 4.0 h_c + 2.0 nadh_c + pi_c
# DMATT : dmpp_c + ipdp_c --> grdp_c + ppi_c
# DMPPS : h2mb4p_c + h_c + nadh_c --> dmpp_c + h2o_c + nad_c
# DMQMT : 2omhmbl_c + amet_c --> ahcys_c + h_c + q8h2_c
# DMSOR1 : dmso_c + mql8_c --> dms_c + h2o_c + mqn8_c
# DMSOR1pp : dmso_p + mql8_c --> dms_p + h2o_p + mqn8_c
# DMSOR2 : 2dmmql8_c + dmso_c --> 2dmmq8_c + dms_c + h2o_c
# DMSOR2pp : 2dmmql8_c + dmso_p --> 2dmmq8_c + dms_p + h2o_p
# DMSOtex : dmso_e <=> dmso_p
# DMStex : dms_e <=> dms_p
# DM_4hba_c : 4hba_c -->
# DM_5drib_c : 5drib_c -->
# DM_aacald_c : aacald_c -->
# DM_hmfurn_c : hmfurn_c -->
# DM_oxam_c : oxam_c -->
# DNMPPA : dhpmp_c + h2o_c --> dhnpt_c + pi_c
# DNTPPA : ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c
# DOGULNR : 23doguln_c + h_c + nadh_c --> 3dhguln_c + nad_c
# DOPAtex : dopa_e <=> dopa_p
# DPCOAK : atp_c + dpcoa_c --> adp_c + coa_c + h_c
# DPR : 2dhp_c + h_c + nadph_c --> nadp_c + pant__R_c
# DRPA : 2dr5p_c --> acald_c + g3p_c
# DSBAO1 : dsbard_p + q8_c --> dsbaox_p + q8h2_c
# DSBAO2 : dsbard_p + mqn8_c --> dsbaox_p + mql8_c
# DSBCGT : dsbcox_p + 2.0 gthrd_p --> dsbcrd_p + gthox_p
# DSBDR : dsbdox_c + trdrd_c --> dsbdrd_c + trdox_c
# DSBGGT : dsbgox_p + 2.0 gthrd_p --> dsbgrd_p + gthox_p
# DSERDHr : nadp_c + ser__D_c <=> 2amsa_c + h_c + nadph_c
# DSERt2pp : h_p + ser__D_p --> h_c + ser__D_c
# DSERtex : ser__D_e <=> ser__D_p
# DTMPK : atp_c + dtmp_c <=> adp_c + dtdp_c
# DTMPtex : dtmp_e <=> dtmp_p
# DUMPtex : dump_e <=> dump_p
# DURIK1 : atp_c + duri_c --> adp_c + dump_c + h_c
# DURIPP : duri_c + pi_c <=> 2dr1p_c + ura_c
# DURIt2pp : duri_p + h_p --> duri_c + h_c
# DURItex : duri_e <=> duri_p
# DUTPDP : dutp_c + h2o_c --> dump_c + h_c + ppi_c
# DXPRIi : dxyl5p_c + h_c + nadph_c --> 2me4p_c + nadp_c
# DXPS : g3p_c + h_c + pyr_c --> co2_c + dxyl5p_c
# DXYLK : atp_c + dxyl_c --> adp_c + dxyl5p_c + h_c
# D_LACt2pp : h_p + lac__D_p <=> h_c + lac__D_c
# D_LACtex : lac__D_e <=> lac__D_p
# E4PD : e4p_c + h2o_c + nad_c <=> 4per_c + 2.0 h_c + nadh_c
# EAR100x : h_c + nadh_c + tdec2eACP_c --> dcaACP_c + nad_c
# EAR100y : h_c + nadph_c + tdec2eACP_c --> dcaACP_c + nadp_c
# EAR120x : h_c + nadh_c + tddec2eACP_c --> ddcaACP_c + nad_c
# EAR120y : h_c + nadph_c + tddec2eACP_c --> ddcaACP_c + nadp_c
# EAR121x : h_c + nadh_c + t3c5ddeceACP_c --> cddec5eACP_c + nad_c
# EAR121y : h_c + nadph_c + t3c5ddeceACP_c --> cddec5eACP_c + nadp_c
# EAR140x : h_c + nadh_c + tmrs2eACP_c --> myrsACP_c + nad_c
# EAR140y : h_c + nadph_c + tmrs2eACP_c --> myrsACP_c + nadp_c
# EAR141x : h_c + nadh_c + t3c7mrseACP_c --> nad_c + tdeACP_c
# EAR141y : h_c + nadph_c + t3c7mrseACP_c --> nadp_c + tdeACP_c
# EAR160x : h_c + nadh_c + tpalm2eACP_c --> nad_c + palmACP_c
# EAR160y : h_c + nadph_c + tpalm2eACP_c --> nadp_c + palmACP_c
# EAR161x : h_c + nadh_c + t3c9palmeACP_c --> hdeACP_c + nad_c
# EAR161y : h_c + nadph_c + t3c9palmeACP_c --> hdeACP_c + nadp_c
# EAR180x : h_c + nadh_c + toctd2eACP_c --> nad_c + ocdcaACP_c
# EAR180y : h_c + nadph_c + toctd2eACP_c --> nadp_c + ocdcaACP_c
# EAR181x : h_c + nadh_c + t3c11vaceACP_c --> nad_c + octeACP_c
# EAR181y : h_c + nadph_c + t3c11vaceACP_c --> nadp_c + octeACP_c
# EAR40x : but2eACP_c + h_c + nadh_c --> butACP_c + nad_c
# EAR40y : but2eACP_c + h_c + nadph_c --> butACP_c + nadp_c
# EAR60x : h_c + nadh_c + thex2eACP_c --> hexACP_c + nad_c
# EAR60y : h_c + nadph_c + thex2eACP_c --> hexACP_c + nadp_c
# EAR80x : h_c + nadh_c + toct2eACP_c --> nad_c + ocACP_c
# EAR80y : h_c + nadph_c + toct2eACP_c --> nadp_c + ocACP_c
# ECA4COLIPAtex : eca4colipa_p --> eca4colipa_e
# ECA4OALpp : colipa_p + eca4und_p --> eca4colipa_p + h_p + udcpdp_p
# ECAP1pp : 2.0 unagamuf_p --> eca2und_p + h_p + udcpdp_p
# ECAP2pp : eca2und_p + unagamuf_p --> eca3und_p + h_p + udcpdp_p
# ECAP3pp : eca3und_p + unagamuf_p --> eca4und_p + h_p + udcpdp_p
# ECAtpp : unagamuf_c --> unagamuf_p
# ECOAH1 : 3hbcoa_c <=> b2coa_c + h2o_c
# ECOAH2 : 3hhcoa_c <=> h2o_c + hx2coa_c
# ECOAH3 : 3hocoa_c <=> h2o_c + oc2coa_c
# ECOAH4 : 3hdcoa_c <=> dc2coa_c + h2o_c
# ECOAH5 : 3hddcoa_c <=> dd2coa_c + h2o_c
# ECOAH6 : 3htdcoa_c <=> h2o_c + td2coa_c
# ECOAH7 : 3hhdcoa_c <=> h2o_c + hdd2coa_c
# ECOAH8 : 3hodcoa_c <=> h2o_c + od2coa_c
# EDA : 2ddg6p_c --> g3p_c + pyr_c
# EDD : 6pgc_c --> 2ddg6p_c + h2o_c
# EDTXS1 : ddcaACP_c + kdo2lipid4_c --> ACP_c + kdo2lipid4L_c
# EDTXS2 : kdo2lipid4L_c + myrsACP_c --> ACP_c + lipa_c
# EDTXS3 : hdeACP_c + kdo2lipid4_c --> ACP_c + kdo2lipid4p_c
# EDTXS4 : kdo2lipid4p_c + myrsACP_c --> ACP_c + lipa_cold_c
# ENLIPAtex : enlipa_p --> enlipa_e
# ENO : 2pg_c <=> h2o_c + pep_c
# ENTCS : 3.0 23dhba_c + 3.0 seramp_c --> 6.0 amp_c + enter_c + 9.0 h_c
# ENTERES : enter_c + 3.0 h2o_c --> 3.0 23dhbzs_c + 3.0 h_c
# ENTERES2 : feenter_c + 3.0 h2o_c --> 3.0 23dhbzs_c + fe3_c + 3.0 h_c
# ETHAAL : etha_c --> acald_c + nh4_c
# ETHAt2pp : etha_p + h_p --> etha_c + h_c
# ETHAtex : etha_e <=> etha_p
# ETHSO3abcpp : atp_c + ethso3_p + h2o_c --> adp_c + ethso3_c + h_c + pi_c
# ETHSO3tex : ethso3_e <=> ethso3_p
# ETOHt2rpp : etoh_p + h_p <=> etoh_c + h_c
# ETOHtex : etoh_e <=> etoh_p
# EX_12ppd__R_e : 12ppd__R_e -->
# EX_12ppd__S_e : 12ppd__S_e -->
# EX_14glucan_e : 14glucan_e -->
# EX_15dap_e : 15dap_e -->
# EX_23camp_e : 23camp_e -->
# EX_23ccmp_e : 23ccmp_e -->
# EX_23cgmp_e : 23cgmp_e -->
# EX_23cump_e : 23cump_e -->
# EX_23dappa_e : 23dappa_e -->
# EX_26dap__M_e : 26dap__M_e -->
# EX_2ddglcn_e : 2ddglcn_e -->
# EX_34dhpac_e : 34dhpac_e -->
# EX_3amp_e : 3amp_e -->
# EX_3cmp_e : 3cmp_e -->
# EX_3gmp_e : 3gmp_e -->
# EX_3hcinnm_e : 3hcinnm_e -->
# EX_3hpppn_e : 3hpppn_e -->
# EX_3ump_e : 3ump_e -->
# EX_4abut_e : 4abut_e -->
# EX_4hoxpacd_e : 4hoxpacd_e -->
# EX_5dglcn_e : 5dglcn_e -->
# EX_LalaDgluMdapDala_e : LalaDgluMdapDala_e -->
# EX_LalaDgluMdap_e : LalaDgluMdap_e -->
# EX_ac_e : ac_e -->
# EX_acac_e : acac_e -->
# EX_acald_e : acald_e -->
# EX_acgal1p_e : acgal1p_e -->
# EX_acgal_e : acgal_e -->
# EX_acgam1p_e : acgam1p_e -->
# EX_acgam_e : acgam_e -->
# EX_acmana_e : acmana_e -->
# EX_acmum_e : acmum_e -->
# EX_acnam_e : acnam_e -->
# EX_acolipa_e : acolipa_e -->
# EX_acser_e : acser_e -->
# EX_ade_e : ade_e -->
# EX_adn_e : adn_e -->
# EX_adocbl_e : adocbl_e -->
# EX_ag_e : ag_e -->
# EX_agm_e : agm_e -->
# EX_akg_e : akg_e -->
# EX_ala_B_e : ala_B_e -->
# EX_ala__D_e : ala__D_e -->
# EX_ala__L_e : ala__L_e -->
# EX_alaala_e : alaala_e -->
# EX_all__D_e : all__D_e -->
# EX_alltn_e : alltn_e -->
# EX_amp_e : amp_e -->
# EX_anhgm_e : anhgm_e -->
# EX_arab__L_e : arab__L_e -->
# EX_arbtn_e : arbtn_e -->
# EX_arbtn_fe3_e : arbtn_fe3_e -->
# EX_arg__L_e : arg__L_e -->
# EX_ascb__L_e : ascb__L_e -->
# EX_asn__L_e : asn__L_e -->
# EX_aso3_e : aso3_e -->
# EX_asp__L_e : asp__L_e -->
# EX_but_e : but_e -->
# EX_butso3_e : butso3_e -->
# EX_ca2_e : ca2_e <=>
# EX_cbi_e : cbi_e -->
# EX_cbl1_e : cbl1_e <=>
# EX_cd2_e : cd2_e -->
# EX_cgly_e : cgly_e -->
# EX_chol_e : chol_e -->
# EX_cit_e : cit_e -->
# EX_cl_e : cl_e <=>
# EX_cmp_e : cmp_e -->
# EX_co2_e : co2_e <=>
# EX_cobalt2_e : cobalt2_e <=>
# EX_colipa_e : colipa_e -->
# EX_cpgn_e : cpgn_e -->
# EX_cpgn_un_e : cpgn_un_e -->
# EX_crn_e : crn_e -->
# EX_csn_e : csn_e -->
# EX_cu2_e : cu2_e <=>
# EX_cu_e : cu_e -->
# EX_cyan_e : cyan_e -->
# EX_cynt_e : cynt_e -->
# EX_cys__D_e : cys__D_e -->
# EX_cys__L_e : cys__L_e -->
# EX_cytd_e : cytd_e -->
# EX_dad_2_e : dad_2_e -->
# EX_damp_e : damp_e -->
# EX_dca_e : dca_e -->
# EX_dcmp_e : dcmp_e -->
# EX_dcyt_e : dcyt_e -->
# EX_ddca_e : ddca_e -->
# EX_dgmp_e : dgmp_e -->
# EX_dgsn_e : dgsn_e -->
# EX_dha_e : dha_e -->
# EX_dimp_e : dimp_e -->
# EX_din_e : din_e -->
# EX_dms_e : dms_e -->
# EX_dmso_e : dmso_e -->
# EX_dopa_e : dopa_e -->
# EX_dtmp_e : dtmp_e -->
# EX_dump_e : dump_e -->
# EX_duri_e : duri_e -->
# EX_eca4colipa_e : eca4colipa_e -->
# EX_enlipa_e : enlipa_e -->
# EX_enter_e : enter_e -->
# EX_etha_e : etha_e -->
# EX_ethso3_e : ethso3_e -->
# EX_etoh_e : etoh_e -->
# EX_f6p_e : f6p_e -->
# EX_fald_e : fald_e -->
# EX_fe2_e : fe2_e <=>
# EX_fe3_e : fe3_e <=>
# EX_fe3dcit_e : fe3dcit_e -->
# EX_fe3dhbzs_e : fe3dhbzs_e -->
# EX_fe3hox_e : fe3hox_e -->
# EX_fe3hox_un_e : fe3hox_un_e -->
# EX_fecrm_e : fecrm_e -->
# EX_fecrm_un_e : fecrm_un_e -->
# EX_feenter_e : feenter_e -->
# EX_feoxam_e : feoxam_e -->
# EX_feoxam_un_e : feoxam_un_e -->
# EX_for_e : for_e -->
# EX_fru_e : fru_e -->
# EX_frulys_e : frulys_e -->
# EX_fruur_e : fruur_e -->
# EX_fuc__L_e : fuc__L_e -->
# EX_fum_e : fum_e -->
# EX_g1p_e : g1p_e -->
# EX_g3pc_e : g3pc_e -->
# EX_g3pe_e : g3pe_e -->
# EX_g3pg_e : g3pg_e -->
# EX_g3pi_e : g3pi_e -->
# EX_g3ps_e : g3ps_e -->
# EX_g6p_e : g6p_e -->
# EX_gal1p_e : gal1p_e -->
# EX_gal_e : gal_e -->
# EX_gal_bD_e : gal_bD_e -->
# EX_galct__D_e : galct__D_e -->
# EX_galctn__D_e : galctn__D_e -->
# EX_galctn__L_e : galctn__L_e -->
# EX_galt_e : galt_e -->
# EX_galur_e : galur_e -->
# EX_gam6p_e : gam6p_e -->
# EX_gam_e : gam_e -->
# EX_gbbtn_e : gbbtn_e -->
# EX_gdp_e : gdp_e -->
# EX_glc__D_e : glc__D_e <=>
# EX_glcn_e : glcn_e -->
# EX_glcr_e : glcr_e -->
# EX_glcur1p_e : glcur1p_e -->
# EX_glcur_e : glcur_e -->
# EX_gln__L_e : gln__L_e -->
# EX_glu__L_e : glu__L_e -->
# EX_gly_e : gly_e -->
# EX_glyald_e : glyald_e -->
# EX_glyb_e : glyb_e -->
# EX_glyc2p_e : glyc2p_e -->
# EX_glyc3p_e : glyc3p_e -->
# EX_glyc_e : glyc_e -->
# EX_glyc__R_e : glyc__R_e -->
# EX_glyclt_e : glyclt_e -->
# EX_gmp_e : gmp_e -->
# EX_gsn_e : gsn_e -->
# EX_gthox_e : gthox_e -->
# EX_gthrd_e : gthrd_e -->
# EX_gtp_e : gtp_e -->
# EX_gua_e : gua_e -->
# EX_h2_e : h2_e -->
# EX_h2o2_e : h2o2_e -->
# EX_h2o_e : h2o_e <=>
# EX_h2s_e : h2s_e -->
# EX_h_e : h_e <=>
# EX_hacolipa_e : hacolipa_e -->
# EX_halipa_e : halipa_e -->
# EX_hdca_e : hdca_e -->
# EX_hdcea_e : hdcea_e -->
# EX_hg2_e : hg2_e -->
# EX_his__L_e : his__L_e -->
# EX_hom__L_e : hom__L_e -->
# EX_hxa_e : hxa_e -->
# EX_hxan_e : hxan_e -->
# EX_idon__L_e : idon__L_e -->
# EX_ile__L_e : ile__L_e -->
# EX_imp_e : imp_e -->
# EX_indole_e : indole_e -->
# EX_inost_e : inost_e -->
# EX_ins_e : ins_e -->
# EX_isetac_e : isetac_e -->
# EX_k_e : k_e <=>
# EX_kdo2lipid4_e : kdo2lipid4_e -->
# EX_lac__D_e : lac__D_e -->
# EX_lac__L_e : lac__L_e -->
# EX_lcts_e : lcts_e -->
# EX_leu__L_e : leu__L_e -->
# EX_lipa_e : lipa_e -->
# EX_lipa_cold_e : lipa_cold_e -->
# EX_lys__L_e : lys__L_e -->
# EX_lyx__L_e : lyx__L_e -->
# EX_mal__D_e : mal__D_e -->
# EX_mal__L_e : mal__L_e -->
# EX_malt_e : malt_e -->
# EX_malthx_e : malthx_e -->
# EX_maltpt_e : maltpt_e -->
# EX_malttr_e : malttr_e -->
# EX_maltttr_e : maltttr_e -->
# EX_man6p_e : man6p_e -->
# EX_man_e : man_e -->
# EX_manglyc_e : manglyc_e -->
# EX_melib_e : melib_e -->
# EX_met__D_e : met__D_e -->
# EX_met__L_e : met__L_e -->
# EX_metsox_R__L_e : metsox_R__L_e -->
# EX_metsox_S__L_e : metsox_S__L_e -->
# EX_mg2_e : mg2_e <=>
# EX_minohp_e : minohp_e -->
# EX_mmet_e : mmet_e -->
# EX_mn2_e : mn2_e <=>
# EX_mnl_e : mnl_e -->
# EX_mobd_e : mobd_e <=>
# EX_mso3_e : mso3_e -->
# EX_n2o_e : n2o_e -->
# EX_na1_e : na1_e <=>
# EX_nac_e : nac_e -->
# EX_nh4_e : nh4_e <=>
# EX_ni2_e : ni2_e -->
# EX_nmn_e : nmn_e -->
# EX_no2_e : no2_e -->
# EX_no3_e : no3_e -->
# EX_no_e : no_e -->
# EX_o16a4colipa_e : o16a4colipa_e -->
# EX_o2_e : o2_e <=>
# EX_o2s_e : o2s_e -->
# EX_ocdca_e : ocdca_e -->
# EX_ocdcea_e : ocdcea_e -->
# EX_octa_e : octa_e -->
# EX_orn_e : orn_e -->
# EX_orot_e : orot_e -->
# EX_pacald_e : pacald_e -->
# EX_peamn_e : peamn_e -->
# EX_phe__L_e : phe__L_e -->
# EX_pheme_e : pheme_e -->
# EX_pi_e : pi_e <=>
# EX_pnto__R_e : pnto__R_e -->
# EX_ppa_e : ppa_e -->
# EX_ppal_e : ppal_e -->
# EX_pppn_e : pppn_e -->
# EX_ppt_e : ppt_e -->
# EX_pro__L_e : pro__L_e -->
# EX_progly_e : progly_e -->
# EX_psclys_e : psclys_e -->
# EX_pser__L_e : pser__L_e -->
# EX_ptrc_e : ptrc_e -->
# EX_pyr_e : pyr_e -->
# EX_r5p_e : r5p_e -->
# EX_rib__D_e : rib__D_e -->
# EX_rmn_e : rmn_e -->
# EX_sbt__D_e : sbt__D_e -->
# EX_ser__D_e : ser__D_e -->
# EX_ser__L_e : ser__L_e -->
# EX_skm_e : skm_e -->
# EX_so2_e : so2_e -->
# EX_so3_e : so3_e -->
# EX_so4_e : so4_e <=>
# EX_spmd_e : spmd_e -->
# EX_succ_e : succ_e -->
# EX_sucr_e : sucr_e -->
# EX_sulfac_e : sulfac_e -->
# EX_tartr__L_e : tartr__L_e -->
# EX_taur_e : taur_e -->
# EX_tcynt_e : tcynt_e -->
# EX_thm_e : thm_e -->
# EX_thr__L_e : thr__L_e -->
# EX_thrp_e : thrp_e -->
# EX_thym_e : thym_e -->
# EX_thymd_e : thymd_e -->
# EX_tma_e : tma_e -->
# EX_tmao_e : tmao_e -->
# EX_tre_e : tre_e -->
# EX_trp__L_e : trp__L_e -->
# EX_tsul_e : tsul_e -->
# EX_ttdca_e : ttdca_e -->
# EX_ttdcea_e : ttdcea_e -->
# EX_tungs_e : tungs_e <=>
# EX_tym_e : tym_e -->
# EX_tyr__L_e : tyr__L_e -->
# EX_tyrp_e : tyrp_e -->
# EX_uacgam_e : uacgam_e -->
# EX_udpacgal_e : udpacgal_e -->
# EX_udpg_e : udpg_e -->
# EX_udpgal_e : udpgal_e -->
# EX_udpglcur_e : udpglcur_e -->
# EX_ump_e : ump_e -->
# EX_ura_e : ura_e -->
# EX_urea_e : urea_e -->
# EX_uri_e : uri_e -->
# EX_val__L_e : val__L_e -->
# EX_xan_e : xan_e -->
# EX_xmp_e : xmp_e -->
# EX_xtsn_e : xtsn_e -->
# EX_xyl__D_e : xyl__D_e -->
# EX_xylu__L_e : xylu__L_e -->
# EX_zn2_e : zn2_e <=>
# BIOMASS_Ec_iAF1260_core_59p81M : 0.000223 10fthf_c + 0.000223 2ohph_c + 0.5137 ala__L_c + 0.000223 amet_c + 0.2958 arg__L_c + 0.2411 asn__L_c + 0.2411 asp__L_c + 59.984 atp_c + 0.004737 ca2_c + 0.004737 cl_c + 0.000576 coa_c + 0.003158 cobalt2_c + 0.1335 ctp_c + 0.003158 cu2_c + 0.09158 cys__L_c + 0.02617 datp_c + 0.02702 dctp_c + 0.02702 dgtp_c + 0.02617 dttp_c + 0.000223 fad_c + 0.007106 fe2_c + 0.007106 fe3_c + 0.2632 gln__L_c + 0.2632 glu__L_c + 0.6126 gly_c + 0.2151 gtp_c + 54.462 h2o_c + 0.09474 his__L_c + 0.2905 ile__L_c + 0.1776 k_c + 0.01945 kdo2lipid4_e + 0.4505 leu__L_c + 0.3432 lys__L_c + 0.1537 met__L_c + 0.007895 mg2_c + 0.000223 mlthf_c + 0.003158 mn2_c + 0.003158 mobd_c + 0.01389 murein5px4p_p + 0.001831 nad_c + 0.000447 nadp_c + 0.011843 nh4_c + 0.02233 pe160_c + 0.04148 pe160_p + 0.02632 pe161_c + 0.04889 pe161_p + 0.1759 phe__L_c + 0.000223 pheme_c + 0.2211 pro__L_c + 0.000223 pydx5p_c + 0.000223 ribflv_c + 0.2158 ser__L_c + 0.000223 sheme_c + 0.003948 so4_c + 0.000223 thf_c + 0.000223 thmpp_c + 0.2537 thr__L_c + 0.05684 trp__L_c + 0.1379 tyr__L_c + 5.5e-05 udcpdp_c + 0.1441 utp_c + 0.4232 val__L_c + 0.003158 zn2_c --> 59.81 adp_c + 59.81 h_c + 59.806 pi_c + 0.7739 ppi_c
# F6PA : f6p_c <=> dha_c + g3p_c
# F6PP : f6p_c + h2o_c --> fru_c + pi_c
# F6Pt6_2pp : f6p_p + 2.0 pi_c --> f6p_c + 2.0 pi_p
# F6Ptex : f6p_e <=> f6p_p
# FA100ACPHi : dcaACP_c + h2o_c --> ACP_c + dca_c + h_c
# FA120ACPHi : ddcaACP_c + h2o_c --> ACP_c + ddca_c + h_c
# FA140ACPHi : h2o_c + myrsACP_c --> ACP_c + h_c + ttdca_c
# FA141ACPHi : h2o_c + tdeACP_c --> ACP_c + h_c + ttdcea_c
# FA160ACPHi : h2o_c + palmACP_c --> ACP_c + h_c + hdca_c
# FA161ACPHi : h2o_c + hdeACP_c --> ACP_c + h_c + hdcea_c
# FA80ACPHi : h2o_c + ocACP_c --> ACP_c + h_c + octa_c
# FACOAE100 : dcacoa_c + h2o_c --> coa_c + dca_c + h_c
# FACOAE120 : ddcacoa_c + h2o_c --> coa_c + ddca_c + h_c
# FACOAE140 : h2o_c + tdcoa_c --> coa_c + h_c + ttdca_c
# FACOAE141 : h2o_c + tdecoa_c --> coa_c + h_c + ttdcea_c
# FACOAE160 : h2o_c + pmtcoa_c --> coa_c + h_c + hdca_c
# FACOAE161 : h2o_c + hdcoa_c --> coa_c + h_c + hdcea_c
# FACOAE180 : h2o_c + stcoa_c --> coa_c + h_c + ocdca_c
# FACOAE181 : h2o_c + odecoa_c --> coa_c + h_c + ocdcea_c
# FACOAE60 : h2o_c + hxcoa_c --> coa_c + h_c + hxa_c
# FACOAE80 : h2o_c + occoa_c --> coa_c + h_c + octa_c
# FACOAL100t2pp : atp_c + coa_c + dca_p + h_p --> amp_c + dcacoa_c + h_c + ppi_c
# FACOAL120t2pp : atp_c + coa_c + ddca_p + h_p --> amp_c + ddcacoa_c + h_c + ppi_c
# FACOAL140t2pp : atp_c + coa_c + h_p + ttdca_p --> amp_c + h_c + ppi_c + tdcoa_c
# FACOAL141t2pp : atp_c + coa_c + h_p + ttdcea_p --> amp_c + h_c + ppi_c + tdecoa_c
# FACOAL160t2pp : atp_c + coa_c + h_p + hdca_p --> amp_c + h_c + pmtcoa_c + ppi_c
# FACOAL161t2pp : atp_c + coa_c + h_p + hdcea_p --> amp_c + h_c + hdcoa_c + ppi_c
# FACOAL180t2pp : atp_c + coa_c + h_p + ocdca_p --> amp_c + h_c + ppi_c + stcoa_c
# FACOAL181t2pp : atp_c + coa_c + h_p + ocdcea_p --> amp_c + h_c + odecoa_c + ppi_c
# FACOAL60t2pp : atp_c + coa_c + h_p + hxa_p --> amp_c + h_c + hxcoa_c + ppi_c
# FACOAL80t2pp : atp_c + coa_c + h_p + octa_p --> amp_c + h_c + occoa_c + ppi_c
# FADRx : fad_c + h_c + nadh_c --> fadh2_c + nad_c
# FADRx2 : fad_c + h_c + nadph_c --> fadh2_c + nadp_c
# FALDH2 : hmgth_c + nad_c <=> Sfglutth_c + h_c + nadh_c
# FALDtex : fald_e <=> fald_p
# FALDtpp : fald_p <=> fald_c
# FALGTHLs : fald_c + gthrd_c <=> hmgth_c
# FBA : fdp_c <=> dhap_c + g3p_c
# FBP : fdp_c + h2o_c --> f6p_c + pi_c
# FCI : fuc__L_c <=> fcl__L_c
# FCLK : atp_c + fcl__L_c --> adp_c + fc1p_c + h_c
# FCLPA : fc1p_c <=> dhap_c + lald__L_c
# FCLT : fe2_c + ppp9_c --> 2.0 h_c + pheme_c
# FDH4pp_1 : for_p + 2.0 h_c + q8_c --> co2_c + h_p + q8h2_c
# FDH5pp_1 : for_p + 2.0 h_c + mqn8_c --> co2_c + h_p + mql8_c
# FDMO : fmnh2_c + isetac_c + o2_c --> fmn_c + gcald_c + h2o_c + h_c + so3_c
# FDMO2 : fmnh2_c + mso3_c + o2_c --> fald_c + fmn_c + h2o_c + h_c + so3_c
# FDMO3 : ethso3_c + fmnh2_c + o2_c --> acald_c + fmn_c + h2o_c + h_c + so3_c
# FDMO4 : butso3_c + fmnh2_c + o2_c --> btal_c + fmn_c + h2o_c + h_c + so3_c
# FDMO6 : fmnh2_c + o2_c + sulfac_c --> fmn_c + glx_c + h2o_c + h_c + so3_c
# FE2abcpp : atp_c + fe2_p + h2o_c --> adp_c + fe2_c + h_c + pi_c
# FE2t2pp : fe2_p + h_p --> fe2_c + h_c
# FE2t3pp : fe2_c + h_p --> fe2_p + h_c
# FE2tex : fe2_e <=> fe2_p
# FE2tpp : fe2_p --> fe2_c
# FE3DCITabcpp : atp_c + fe3dcit_p + h2o_c --> adp_c + 2.0 cit_c + fe3_c + h_c + pi_c
# FE3DCITtonex : fe3dcit_e + h_p --> fe3dcit_p + h_c
# FE3DHBZR : fe3dhbzs_c --> 23dhbzs_c + fe3_c
# FE3DHBZSabcpp : atp_c + fe3dhbzs_p + h2o_c --> adp_c + fe3dhbzs_c + h_c + pi_c
# FE3DHBZStonex : fe3dhbzs_e + h_p --> fe3dhbzs_p + h_c
# FE3HOXR1 : fadh2_c + 2.0 fe3hox_c --> fad_c + 2.0 fe2_c + 2.0 fe3hox_un_c + 2.0 h_c
# FE3HOXR2 : 2.0 fe3hox_c + fmnh2_c --> 2.0 fe2_c + 2.0 fe3hox_un_c + fmn_c + 2.0 h_c
# FE3HOXR3 : 2.0 fe3hox_c + rbflvrd_c --> 2.0 fe2_c + 2.0 fe3hox_un_c + 2.0 h_c + ribflv_c
# FE3HOXUtex : fe3hox_un_c + h_p --> fe3hox_un_p + h_c
# FE3HOXUtpp : fe3hox_un_p + h_p --> fe3hox_un_e + h_c
# FE3HOXabcpp : atp_c + fe3hox_p + h2o_c --> adp_c + fe3hox_c + h_c + pi_c
# FE3HOXexs : fe3_e + fe3hox_un_e --> fe3hox_e
# FE3HOXtonex : fe3hox_e + h_p --> fe3hox_p + h_c
# FE3Ri : fadh2_c + 2.0 fe3_c --> fad_c + 2.0 fe2_c + 2.0 h_c
# FE3abcpp : atp_c + fe3_p + h2o_c --> adp_c + fe3_c + h_c + pi_c
# FE3tex : fe3_e <=> fe3_p
# FECRMR1 : fadh2_c + 2.0 fecrm_c --> fad_c + 2.0 fe2_c + 2.0 fecrm_un_c + 2.0 h_c
# FECRMR2 : 2.0 fecrm_c + fmnh2_c --> 2.0 fe2_c + 2.0 fecrm_un_c + fmn_c + 2.0 h_c
# ...
# PRATPP : h2o_c + prbatp_c --> h_c + ppi_c + prbamp_c
# PRFGS : atp_c + fgam_c + gln__L_c + h2o_c --> adp_c + fpram_c + glu__L_c + h_c + pi_c
# PRMICI : prfp_c <=> prlp_c
# PROD2 : fad_c + pro__L_c --> 1pyr5c_c + fadh2_c + h_c
# PROGLYabcpp : atp_c + h2o_c + progly_p --> adp_c + h_c + pi_c + progly_c
# PROGLYtex : progly_e <=> progly_p
# PROTRS : atp_c + pro__L_c + trnapro_c --> amp_c + ppi_c + protrna_c
# PROabcpp : atp_c + h2o_c + pro__L_p --> adp_c + h_c + pi_c + pro__L_c
# PROt2rpp : h_p + pro__L_p <=> h_c + pro__L_c
# PROt4pp : na1_p + pro__L_p --> na1_c + pro__L_c
# PROtex : pro__L_e <=> pro__L_p
# PRPPS : atp_c + r5p_c <=> amp_c + h_c + prpp_c
# PSCLYSt2pp : h_p + psclys_p --> h_c + psclys_c
# PSCLYStex : psclys_e <=> psclys_p
# PSCVT : pep_c + skm5p_c <=> 3psme_c + pi_c
# PSD120 : h_c + ps120_c --> co2_c + pe120_c
# PSD140 : h_c + ps140_c --> co2_c + pe140_c
# PSD141 : h_c + ps141_c --> co2_c + pe141_c
# PSD160 : h_c + ps160_c --> co2_c + pe160_c
# PSD161 : h_c + ps161_c --> co2_c + pe161_c
# PSD180 : h_c + ps180_c --> co2_c + pe180_c
# PSD181 : h_c + ps181_c --> co2_c + pe181_c
# PSERT : 3php_c + glu__L_c --> akg_c + pser__L_c
# PSERtex : pser__L_e <=> pser__L_p
# PSP_L : h2o_c + pser__L_c --> pi_c + ser__L_c
# PSP_Lpp : h2o_p + pser__L_p --> pi_p + ser__L_p
# PSSA120 : cdpdddecg_c + ser__L_c --> cmp_c + h_c + ps120_c
# PSSA140 : cdpdtdecg_c + ser__L_c --> cmp_c + h_c + ps140_c
# PSSA141 : cdpdtdec7eg_c + ser__L_c --> cmp_c + h_c + ps141_c
# PSSA160 : cdpdhdecg_c + ser__L_c --> cmp_c + h_c + ps160_c
# PSSA161 : cdpdhdec9eg_c + ser__L_c --> cmp_c + h_c + ps161_c
# PSSA180 : cdpdodecg_c + ser__L_c --> cmp_c + h_c + ps180_c
# PSSA181 : cdpdodec11eg_c + ser__L_c --> cmp_c + h_c + ps181_c
# PTA2 : pi_c + ppcoa_c --> coa_c + ppap_c
# PTAr : accoa_c + pi_c <=> actp_c + coa_c
# PTHRpp : h2o_p + thrp_p --> pi_p + thr__L_p
# PTPATi : atp_c + h_c + pan4p_c --> dpcoa_c + ppi_c
# PTRCORNt7pp : orn_c + ptrc_p <=> orn_p + ptrc_c
# PTRCTA : akg_c + ptrc_c --> 4abutn_c + glu__L_c
# PTRCabcpp : atp_c + h2o_c + ptrc_p --> adp_c + h_c + pi_c + ptrc_c
# PTRCt2pp : h_p + ptrc_p --> h_c + ptrc_c
# PTRCtex : ptrc_e <=> ptrc_p
# PUNP1 : adn_c + pi_c <=> ade_c + r1p_c
# PUNP2 : dad_2_c + pi_c <=> 2dr1p_c + ade_c
# PUNP3 : gsn_c + pi_c <=> gua_c + r1p_c
# PUNP4 : dgsn_c + pi_c <=> 2dr1p_c + gua_c
# PUNP5 : ins_c + pi_c <=> hxan_c + r1p_c
# PUNP6 : din_c + pi_c <=> 2dr1p_c + hxan_c
# PUNP7 : pi_c + xtsn_c <=> r1p_c + xan_c
# PYAM5PO : h2o_c + o2_c + pyam5p_c --> h2o2_c + nh4_c + pydx5p_c
# PYDAMK : atp_c + pydam_c --> adp_c + h_c + pyam5p_c
# PYDXK : atp_c + pydx_c --> adp_c + h_c + pydx5p_c
# PYDXNK : atp_c + pydxn_c --> adp_c + h_c + pdx5p_c
# PYDXPP : h2o_c + pydx5p_c --> pi_c + pydx_c
# PYK : adp_c + h_c + pep_c --> atp_c + pyr_c
# PYNP2r : pi_c + uri_c <=> r1p_c + ura_c
# PYRt2rpp : h_p + pyr_p <=> h_c + pyr_c
# PYRtex : pyr_e <=> pyr_p
# QMO2 : 2.0 o2_c + q8h2_c --> 2.0 h_c + 2.0 o2s_c + q8_c
# QMO3 : mql8_c + 2.0 o2_c --> 2.0 h_c + mqn8_c + 2.0 o2s_c
# QULNS : dhap_c + iasp_c --> 2.0 h2o_c + pi_c + quln_c
# R15BPK : atp_c + r15bp_c --> adp_c + prpp_c
# R1PK : atp_c + r1p_c --> adp_c + h_c + r15bp_c
# R5PP : h2o_c + r5p_c --> pi_c + rib__D_c
# R5PPpp : h2o_p + r5p_p --> pi_p + rib__D_p
# R5Ptex : r5p_e <=> r5p_p
# RBFK : atp_c + ribflv_c --> adp_c + fmn_c + h_c
# RBFSa : 4r5au_c + db4p_c --> dmlz_c + 2.0 h2o_c + pi_c
# RBFSb : 2.0 dmlz_c --> 4r5au_c + ribflv_c
# RBK : atp_c + rib__D_c --> adp_c + h_c + r5p_c
# RBK_L1 : atp_c + rbl__L_c --> adp_c + h_c + ru5p__L_c
# RBP4E : ru5p__L_c <=> xu5p__D_c
# RHAT1 : dtdprmn_c + kphphhlipa_c --> dtdp_c + h_c + icolipa_c
# RHCCE : rhcys_c --> dhptd_c + hcys__L_c
# RIBabcpp : atp_c + h2o_c + rib__D_p --> adp_c + h_c + pi_c + rib__D_c
# RIBtex : rib__D_e <=> rib__D_p
# RMI : rmn_c <=> rml_c
# RMK : atp_c + rml_c --> adp_c + h_c + rml1p_c
# RMNtex : rmn_e <=> rmn_p
# RMNtpp : h_p + rmn_p --> h_c + rmn_c
# RMPA : rml1p_c <=> dhap_c + lald__L_c
# RNDR1 : adp_c + trdrd_c --> dadp_c + h2o_c + trdox_c
# RNDR1b : adp_c + grxrd_c --> dadp_c + grxox_c + h2o_c
# RNDR2 : gdp_c + trdrd_c --> dgdp_c + h2o_c + trdox_c
# RNDR2b : gdp_c + grxrd_c --> dgdp_c + grxox_c + h2o_c
# RNDR3 : cdp_c + trdrd_c --> dcdp_c + h2o_c + trdox_c
# RNDR3b : cdp_c + grxrd_c --> dcdp_c + grxox_c + h2o_c
# RNDR4 : trdrd_c + udp_c --> dudp_c + h2o_c + trdox_c
# RNDR4b : grxrd_c + udp_c --> dudp_c + grxox_c + h2o_c
# RNTR1c : atp_c + fldrd_c --> datp_c + fldox_c + h2o_c
# RNTR2c : fldrd_c + gtp_c --> dgtp_c + fldox_c + h2o_c
# RNTR3c : ctp_c + fldrd_c --> dctp_c + fldox_c + h2o_c
# RNTR4c : fldrd_c + utp_c --> dutp_c + fldox_c + h2o_c
# RPE : ru5p__D_c <=> xu5p__D_c
# RPI : r5p_c <=> ru5p__D_c
# RZ5PP : 5prdmbz_c + h2o_c --> pi_c + rdmbzi_c
# S7PI : s7p_c --> gmhep7p_c
# SADH : 2.0 h2o_c + 2.0 h_c + sucarg_c --> co2_c + 2.0 nh4_c + sucorn_c
# SADT2 : atp_c + gtp_c + h2o_c + so4_c --> aps_c + gdp_c + pi_c + ppi_c
# SARCOX : h2o_c + o2_c + sarcs_c --> fald_c + gly_c + h2o2_c
# SBTPD : nad_c + sbt6p_c <=> f6p_c + h_c + nadh_c
# SBTptspp : pep_c + sbt__D_p --> pyr_c + sbt6p_c
# SBTtex : sbt__D_e <=> sbt__D_p
# SDPDS : h2o_c + sl26da_c --> 26dap_LL_c + succ_c
# SDPTA : akg_c + sl26da_c <=> glu__L_c + sl2a6o_c
# SELCYSS : selnp_c + sertrna_sec_c --> h_c + pi_c + sectrna_c
# SELNPS : atp_c + h2o_c + seln_c --> amp_c + pi_c + selnp_c
# SERASr : atp_c + h_c + ser__L_c <=> ppi_c + seramp_c
# SERAT : accoa_c + ser__L_c <=> acser_c + coa_c
# SERD_D : ser__D_c --> nh4_c + pyr_c
# SERD_L : ser__L_c --> nh4_c + pyr_c
# SERTRS : atp_c + ser__L_c + trnaser_c --> amp_c + ppi_c + sertrna_c
# SERTRS2 : atp_c + ser__L_c + trnasecys_c --> amp_c + ppi_c + sertrna_sec_c
# SERt2rpp : h_p + ser__L_p <=> h_c + ser__L_c
# SERt4pp : na1_p + ser__L_p --> na1_c + ser__L_c
# SERtex : ser__L_e <=> ser__L_p
# SFGTHi : Sfglutth_c + h2o_c --> for_c + gthrd_c + h_c
# SGDS : h2o_c + sucglu_c --> glu__L_c + succ_c
# SGSAD : h2o_c + nad_c + sucgsa_c --> 2.0 h_c + nadh_c + sucglu_c
# SHCHCS2 : ichor_c + ssaltpp_c --> 2shchc_c + pyr_c + thmpp_c
# SHCHD2 : dscl_c + nad_c --> h_c + nadh_c + scl_c
# SHCHF : fe2_c + scl_c --> 3.0 h_c + sheme_c
# SHK3Dr : 3dhsk_c + h_c + nadph_c <=> nadp_c + skm_c
# SHKK : atp_c + skm_c --> adp_c + h_c + skm5p_c
# SHSL1 : cys__L_c + suchms_c --> cyst__L_c + h_c + succ_c
# SKMt2pp : h_p + skm_p --> h_c + skm_c
# SKMtex : skm_e <=> skm_p
# SO2tex : so2_e <=> so2_p
# SO2tpp : so2_p <=> so2_c
# SO3tex : so3_e <=> so3_p
# SO4tex : so4_e <=> so4_p
# SOTA : akg_c + sucorn_c --> glu__L_c + sucgsa_c
# SPMDAT1 : accoa_c + spmd_c --> N1aspmd_c + coa_c + h_c
# SPMDAT2 : accoa_c + spmd_c --> coa_c + h_c + n8aspmd_c
# SPMDabcpp : atp_c + h2o_c + spmd_p --> adp_c + h_c + pi_c + spmd_c
# SPMDtex : spmd_e <=> spmd_p
# SPMS : ametam_c + ptrc_c --> 5mta_c + h_c + spmd_c
# SPODM : 2.0 h_c + 2.0 o2s_c --> h2o2_c + o2_c
# SPODMpp : 2.0 h_p + 2.0 o2s_p --> h2o2_p + o2_p
# SSALx : h2o_c + nad_c + sucsal_c --> 2.0 h_c + nadh_c + succ_c
# SSALy : h2o_c + nadp_c + sucsal_c --> 2.0 h_c + nadph_c + succ_c
# SUCBZL : atp_c + coa_c + sucbz_c --> amp_c + ppi_c + sbzcoa_c
# SUCBZS : 2shchc_c --> h2o_c + sucbz_c
# SUCCt2_2pp : 2.0 h_p + succ_p --> 2.0 h_c + succ_c
# SUCCt2_3pp : 3.0 h_p + succ_p --> 3.0 h_c + succ_c
# SUCCt3pp : h_p + succ_c --> h_c + succ_p
# SUCCtex : succ_e <=> succ_p
# SUCDi : q8_c + succ_c --> fum_c + q8h2_c
# SUCFUMtpp : fum_p + succ_c <=> fum_c + succ_p
# SUCOAS : atp_c + coa_c + succ_c <=> adp_c + pi_c + succoa_c
# SUCRtex : sucr_e <=> sucr_p
# SUCptspp : pep_c + sucr_p --> pyr_c + suc6p_c
# SULFACabcpp : atp_c + h2o_c + sulfac_p --> adp_c + h_c + pi_c + sulfac_c
# SULFACtex : sulfac_e <=> sulfac_p
# SULRi : 5.0 h_c + 3.0 nadph_c + so3_c --> 3.0 h2o_c + h2s_c + 3.0 nadp_c
# SULabcpp : atp_c + h2o_c + so4_p --> adp_c + h_c + pi_c + so4_c
# T2DECAI : tdec2eACP_c <=> cdec3eACP_c
# TAGURr : altrn_c + nad_c <=> h_c + nadh_c + tagur_c
# TALA : g3p_c + s7p_c <=> e4p_c + f6p_c
# TARTD : tartr__L_c --> h2o_c + oaa_c
# TARTRt7pp : succ_c + tartr__L_p <=> succ_p + tartr__L_c
# TARTRtex : tartr__L_e <=> tartr__L_p
# TAUDO : akg_c + o2_c + taur_c --> aacald_c + co2_c + h_c + so3_c + succ_c
# TAURabcpp : atp_c + h2o_c + taur_p --> adp_c + h_c + pi_c + taur_c
# TAURtex : taur_e <=> taur_p
# TCYNTtex : tcynt_e <=> tcynt_p
# CTECOAI6 : tdecoa_c --> td2coa_c
# TDP : h2o_c + thmpp_c --> h_c + pi_c + thmmp_c
# TDPADGAT : accoa_c + dtdp4addg_c --> coa_c + dtdp4aaddg_c + h_c
# TDPAGTA : dtdp4d6dg_c + glu__L_c --> akg_c + dtdp4addg_c
# TDPDRE : dtdp4d6dg_c --> dtdp4d6dm_c
# TDPDRR : dtdp4d6dm_c + h_c + nadph_c --> dtdprmn_c + nadp_c
# TDPGDH : dtdpglu_c --> dtdp4d6dg_c + h2o_c
# TDSK : atp_c + lipidAds_c --> adp_c + h_c + lipidA_c
# TDSR1 : dsbcox_p + dsbdrd_c --> dsbcrd_p + dsbdox_c
# TDSR2 : dsbdrd_c + dsbgox_p --> dsbdox_c + dsbgrd_p
# TGBPA : tagdp__D_c <=> dhap_c + g3p_c
# THD2pp : 2.0 h_p + nadh_c + nadp_c --> 2.0 h_c + nad_c + nadph_c
# THDPS : h2o_c + succoa_c + thdp_c --> coa_c + sl2a6o_c
# THIORDXi : h2o2_c + trdrd_c --> 2.0 h2o_c + trdox_c
# THMDt2pp_copy1 : h_p + thymd_p --> h_c + thymd_c
# THMDt2pp_copy2 : h_p + thymd_p <=> h_c + thymd_c
# THMDtex : thymd_e <=> thymd_p
# THMabcpp : atp_c + h2o_c + thm_p --> adp_c + h_c + pi_c + thm_c
# THMtex : thm_e <=> thm_p
# THRA2i : athr__L_c --> acald_c + gly_c
# THRAi : thr__L_c --> acald_c + gly_c
# THRD : nad_c + thr__L_c --> 2aobut_c + h_c + nadh_c
# THRD_L : thr__L_c --> 2obut_c + nh4_c
# THRPtex : thrp_e <=> thrp_p
# THRS : h2o_c + phom_c --> pi_c + thr__L_c
# THRTRS : atp_c + thr__L_c + trnathr_c --> amp_c + ppi_c + thrtrna_c
# THRabcpp : atp_c + h2o_c + thr__L_p --> adp_c + h_c + pi_c + thr__L_c
# THRt2pp : h_p + thr__L_c --> h_c + thr__L_p
# THRt2rpp : h_p + thr__L_p <=> h_c + thr__L_c
# THRt4pp : na1_p + thr__L_p --> na1_c + thr__L_c
# THRtex : thr__L_e <=> thr__L_p
# THYMt3pp : h_p + thym_c --> h_c + thym_p
# THYMtex : thym_e <=> thym_p
# THZPSN : atp_c + cys__L_c + dxyl5p_c + tyr__L_c --> 4hba_c + 4mpetz_c + ala__L_c + amp_c + co2_c + h2o_c + h_c + ppi_c
# TKT1 : r5p_c + xu5p__D_c <=> g3p_c + s7p_c
# TKT2 : e4p_c + xu5p__D_c <=> f6p_c + g3p_c
# TMAOR1 : h_c + mql8_c + tmao_c --> h2o_c + mqn8_c + tma_c
# TMAOR1pp : h_p + mql8_c + tmao_p --> h2o_p + mqn8_c + tma_p
# TMAOR2 : 2dmmql8_c + h_c + tmao_c --> 2dmmq8_c + h2o_c + tma_c
# TMAOR2pp : 2dmmql8_c + h_p + tmao_p --> 2dmmq8_c + h2o_p + tma_p
# TMAOtex : tmao_e <=> tmao_p
# TMAtex : tma_e <=> tma_p
# TMDK1 : atp_c + thymd_c --> adp_c + dtmp_c + h_c
# TMDPP : pi_c + thymd_c <=> 2dr1p_c + thym_c
# TMDS : dump_c + mlthf_c --> dhf_c + dtmp_c
# TMK : atp_c + thm_c --> adp_c + h_c + thmmp_c
# TMPK : atp_c + thmmp_c --> adp_c + thmpp_c
# TMPPP : 2mahmp_c + 4mpetz_c + h_c --> ppi_c + thmmp_c
# TPI : dhap_c <=> g3p_c
# TPRDCOAS : atp_c + dpcoa_c --> 2tpr3dpcoa_c + ade_c
# TRDR : h_c + nadph_c + trdox_c --> nadp_c + trdrd_c
# TRE6PH : h2o_c + tre6p_c --> g6p_c + glc__D_c
# TRE6PP : h2o_c + tre6p_c --> pi_c + tre_c
# TRE6PS : g6p_c + udpg_c --> h_c + tre6p_c + udp_c
# TREH : h2o_c + tre_c --> 2.0 glc__D_c
# TREHpp : h2o_p + tre_p --> 2.0 glc__D_p
# TREptspp : pep_c + tre_p --> pyr_c + tre6p_c
# TREtex : tre_e <=> tre_p
# TRPAS2 : h2o_c + trp__L_c <=> indole_c + nh4_c + pyr_c
# TRPS1 : 3ig3p_c + ser__L_c --> g3p_c + h2o_c + trp__L_c
# TRPS2 : indole_c + ser__L_c --> h2o_c + trp__L_c
# TRPS3 : 3ig3p_c --> g3p_c + indole_c
# TRPTRS : atp_c + trnatrp_c + trp__L_c --> amp_c + ppi_c + trptrna_c
# TRPt2rpp : h_p + trp__L_p <=> h_c + trp__L_c
# TRPtex : trp__L_e <=> trp__L_p
# TRSARr : 2h3oppan_c + h_c + nadh_c <=> glyc__R_c + nad_c
# TSULabcpp : atp_c + h2o_c + tsul_p --> adp_c + h_c + pi_c + tsul_c
# TSULtex : tsul_e <=> tsul_p
# TTDCAtexi : ttdca_e --> ttdca_p
# TTDCEAtexi : ttdcea_e --> ttdcea_p
# TUNGSabcpp : atp_c + h2o_c + tungs_p --> adp_c + h_c + pi_c + tungs_c
# TUNGStex : tungs_e <=> tungs_p
# TYMtex : tym_e <=> tym_p
# TYROXDApp : h2o_p + o2_p + tym_p --> 4hoxpacd_p + h2o2_p + nh4_p
# TYRPpp : h2o_p + tyrp_p --> pi_p + tyr__L_p
# TYRPtex : tyrp_e <=> tyrp_p
# TYRTA : akg_c + tyr__L_c <=> 34hpp_c + glu__L_c
# TYRTRS : atp_c + trnatyr_c + tyr__L_c --> amp_c + ppi_c + tyrtrna_c
# TYRt2rpp : h_p + tyr__L_p <=> h_c + tyr__L_c
# TYRtex : tyr__L_e <=> tyr__L_p
# U23GAAT : 3hmrsACP_c + u3hga_c --> ACP_c + h_c + u23ga_c
# UAAGDS : 26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c
# UACGALPpp : h2o_p + udpacgal_p --> acgal1p_p + 2.0 h_p + ump_p
# UACGAMPpp : h2o_p + uacgam_p --> acgam1p_p + 2.0 h_p + ump_p
# UACGAMtex : uacgam_e <=> uacgam_p
# UACMAMO : h2o_c + 2.0 nad_c + uacmam_c --> 3.0 h_c + 2.0 nadh_c + uacmamu_c
# UAG2E : uacgam_c <=> uacmam_c
# UAGAAT : 3hmrsACP_c + uacgam_c <=> ACP_c + u3aga_c
# UAGCVT : pep_c + uacgam_c --> pi_c + uaccg_c
# UAGDP : acgam1p_c + h_c + utp_c --> ppi_c + uacgam_c
# UAGPT3 : uacgam_c + uagmda_c --> h_c + uaagmda_c + udp_c
# UAMAGS : atp_c + glu__D_c + uama_c --> adp_c + h_c + pi_c + uamag_c
# UAMAS : ala__L_c + atp_c + uamr_c --> adp_c + h_c + pi_c + uama_c
# UAPGR : h_c + nadph_c + uaccg_c --> nadp_c + uamr_c
# UDCPDP : h2o_c + udcpdp_c --> h_c + pi_c + udcpp_c
# UDCPDPS : frdp_c + 8.0 ipdp_c --> 8.0 ppi_c + udcpdp_c
# UDCPDPpp : h2o_p + udcpdp_p --> h_p + pi_p + udcpp_p
# UDCPPtppi : udcpp_p --> udcpp_c
# UDPACGALtex : udpacgal_e <=> udpacgal_p
# UDPG4E : udpg_c <=> udpgal_c
# UDPGALM : udpgal_c --> udpgalfur_c
# UDPGALPpp : h2o_p + udpgal_p --> gal1p_p + 2.0 h_p + ump_p
# UDPGALtex : udpgal_e <=> udpgal_p
# UDPGD : h2o_c + 2.0 nad_c + udpg_c --> 3.0 h_c + 2.0 nadh_c + udpglcur_c
# UDPGDC : nad_c + udpglcur_c --> co2_c + nadh_c + udpLa4o_c
# UDPGLCURtex : udpglcur_e <=> udpglcur_p
# UDPGPpp : h2o_p + udpg_p --> g1p_p + 2.0 h_p + ump_p
# UDPGtex : udpg_e <=> udpg_p
# UDPKAAT : glu__L_c + udpLa4o_c <=> akg_c + udpLa4n_c
# UGLCURPpp : h2o_p + udpglcur_p --> glcur1p_p + 2.0 h_p + ump_p
# UGLT : gal1p_c + udpg_c <=> g1p_c + udpgal_c
# UGLYCH : h2o_c + 2.0 h_c + urdglyc_c --> co2_c + glx_c + 2.0 nh4_c
# UGMDDS : alaala_c + atp_c + ugmd_c --> adp_c + h_c + pi_c + ugmda_c
# UHGADA : h2o_c + u3aga_c --> ac_c + u3hga_c
# ULA4NFT : 10fthf_c + udpLa4n_c --> h_c + thf_c + udpLa4fn_c
# ULA4Ntppi : uLa4n_c --> uLa4n_p
# UM3PL : LalaDgluMdap_c + atp_c + uamr_c --> adp_c + h_c + pi_c + ugmd_c
# UM4PCP : h2o_c + um4p_c --> ala__D_c + ugmd_c
# UM4PL : LalaDgluMdapDala_c + atp_c + uamr_c --> adp_c + h_c + pi_c + um4p_c
# UMPK : atp_c + ump_c <=> adp_c + udp_c
# UMPtex : ump_e <=> ump_p
# UNK3 : 2kmb_c + glu__L_c --> akg_c + met__L_c
# UPLA4FNF : h2o_c + uLa4fn_c --> for_c + uLa4n_c
# UPLA4FNT : udcpp_c + udpLa4fn_c --> uLa4fn_c + udp_c
# UPP3MT : 2.0 amet_c + uppg3_c --> 2.0 ahcys_c + dscl_c + h_c
# UPP3S : hmbil_c --> h2o_c + uppg3_c
# UPPDC1 : 4.0 h_c + uppg3_c --> 4.0 co2_c + cpppg3_c
# UPPRT : prpp_c + ura_c --> ppi_c + ump_c
# URAt2pp_copy1 : h_p + ura_p --> h_c + ura_c
# URAt2pp_copy2 : h_p + ura_p <=> h_c + ura_c
# URAtex : ura_e <=> ura_p
# URDGLYCD : nad_c + urdglyc_c --> h_c + nadh_c + oxur_c
# UREAtex : urea_e <=> urea_p
# UREAtpp : urea_p <=> urea_c
# URIC : 2.0 h2o_c + o2_c + urate_c --> alltn_c + co2_c + h2o2_c
# URIDK2r : atp_c + dump_c <=> adp_c + dudp_c
# URIH : h2o_c + uri_c --> rib__D_c + ura_c
# URIK2 : gtp_c + uri_c --> gdp_c + h_c + ump_c
# URIt2pp_copy1 : h_p + uri_p --> h_c + uri_c
# URIt2pp_copy2 : h_p + uri_p <=> h_c + uri_c
# URItex : uri_e <=> uri_p
# USHD : h2o_c + u23ga_c --> 2.0 h_c + lipidX_c + ump_c
# VALTA : akg_c + val__L_c <=> 3mob_c + glu__L_c
# VALTRS : atp_c + trnaval_c + val__L_c --> amp_c + ppi_c + valtrna_c
# VALabcpp : atp_c + h2o_c + val__L_p --> adp_c + h_c + pi_c + val__L_c
# VALt2rpp : h_p + val__L_p <=> h_c + val__L_c
# VALtex : val__L_e <=> val__L_p
# VPAMTr : 3mob_c + ala__L_c --> pyr_c + val__L_c
# X5PL3E : xu5p__L_c --> ru5p__L_c
# XAND : h2o_c + nad_c + xan_c --> h_c + nadh_c + urate_c
# XANt2pp : h_p + xan_p --> h_c + xan_c
# XANtex : xan_e <=> xan_p
# XANtpp : xan_p <=> xan_c
# XMPtex : xmp_e <=> xmp_p
# XPPT : prpp_c + xan_c --> ppi_c + xmp_c
# XTSNH : h2o_c + xtsn_c --> rib__D_c + xan_c
# XTSNt2rpp : h_p + xtsn_p <=> h_c + xtsn_c
# XTSNtex : xtsn_e <=> xtsn_p
# XYLI1 : xyl__D_c <=> xylu__D_c
# XYLI2 : glc__D_c <=> fru_c
# XYLK : atp_c + xylu__D_c --> adp_c + h_c + xu5p__D_c
# XYLK2 : atp_c + xylu__L_c --> adp_c + h_c + xu5p__L_c
# XYLUt2pp : h_p + xylu__L_p --> h_c + xylu__L_c
# XYLUtex : xylu__L_e <=> xylu__L_p
# XYLabcpp : atp_c + h2o_c + xyl__D_p --> adp_c + h_c + pi_c + xyl__D_c
# XYLt2pp : h_p + xyl__D_p --> h_c + xyl__D_c
# XYLtex : xyl__D_e <=> xyl__D_p
# ZN2abcpp : atp_c + h2o_c + zn2_c --> adp_c + h_c + pi_c + zn2_p
# ZN2t3pp : h_p + zn2_c --> h_c + zn2_p
# ZN2tpp : zn2_p --> zn2_c
# ZNabcpp : atp_c + h2o_c + zn2_p --> adp_c + h_c + pi_c + zn2_c
# Zn2tex : zn2_e <=> zn2_p

# %%
model.reactions.HEX1.reaction
# Out:
# 'atp_c + glc__D_c --> adp_c + g6p_c + h_c'

# %% [markdown]
# ## If we extended this creation of metabolites and reactions we end up with the following S matrix for Glycolysis as a system

# %% [markdown]
# ![glycolysisSmatrix.png](attachment:glycolysisSmatrix.png)

# %% [markdown]
# ## Utilizing escher to visualize pathways in models

# %%
import escher
from escher import Builder

# %%
import escher.urls
from IPython.display import HTML
path = 'Glycolysis.json'
escher_map = escher.Builder(map_json=path)
escher_map.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="hwifagiool"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"hwifagiool"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": null, "enable_editing": false, "gene_data": null, "metabolite_data": null, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name":"new_map","map_id":"9WnUpPkulrL4","map_description":"","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"0":{"name":"Hexokinase (D-glucose:ATP)","bigg_id":"HEX1","reversibility":false,"label_x":-18,"label_y":4,"gene_reaction_rule":"b2388","genes":[{"notes":{"original_bigg_ids":["b2388"]},"name":"glk","bigg_id":"b2388"}],"metabolites":[{"bigg_id":"glc__D_c","coefficient":-1},{"bigg_id":"g6p_c","coefficient":1},{"bigg_id":"h_c","coefficient":1},{"bigg_id":"atp_c","coefficient":-1},{"bigg_id":"adp_c","coefficient":1}],"segments":{"0":{"from_node_id":"1","to_node_id":"2","b1":null,"b2":null},"1":{"from_node_id":"3","to_node_id":"2","b1":null,"b2":null},"2":{"from_node_id":"1","to_node_id":"0","b1":{"x":-33,"y":-68},"b2":{"x":-32.99999999999999,"y":-122.25}},"3":{"from_node_id":"3","to_node_id":"4","b1":{"x":-33,"y":56},"b2":{"x":-33,"y":110.25}},"4":{"from_node_id":"3","to_node_id":"5","b1":{"x":-33,"y":60},"b2":{"x":-15,"y":65.25}},"5":{"from_node_id":"1","to_node_id":"6","b1":{"x":-33,"y":-72},"b2":{"x":-51,"y":-77.25}},"6":{"from_node_id":"3","to_node_id":"7","b1":{"x":-33,"y":60},"b2":{"x":-51,"y":65.25}}}},"1":{"name":"Glucose-6-phosphate isomerase","bigg_id":"PGI","reversibility":true,"label_x":-18,"label_y":354,"gene_reaction_rule":"b4025","genes":[{"notes":{"original_bigg_ids":["b4025"]},"name":"pgi","bigg_id":"b4025"}],"metabolites":[{"bigg_id":"g6p_c","coefficient":-1},{"bigg_id":"f6p_c","coefficient":1}],"segments":{"7":{"from_node_id":"8","to_node_id":"9","b1":null,"b2":null},"8":{"from_node_id":"10","to_node_id":"9","b1":null,"b2":null},"9":{"from_node_id":"8","to_node_id":"4","b1":{"x":-33,"y":282},"b2":{"x":-32.99999999999999,"y":227.75}},"10":{"from_node_id":"10","to_node_id":"11","b1":{"x":-33,"y":406},"b2":{"x":-33,"y":460.25}}}},"2":{"name":"Phosphofructokinase","bigg_id":"PFK","reversibility":false,"label_x":-18,"label_y":704,"gene_reaction_rule":"b3916 or b1723","genes":[{"notes":{"original_bigg_ids":["b3916"]},"name":"pfkA","bigg_id":"b3916"},{"notes":{"original_bigg_ids":["b1723"]},"name":"pfkB","bigg_id":"b1723"}],"metabolites":[{"bigg_id":"f6p_c","coefficient":-1},{"bigg_id":"atp_c","coefficient":-1},{"bigg_id":"h_c","coefficient":1},{"bigg_id":"adp_c","coefficient":1},{"bigg_id":"fdp_c","coefficient":1}],"segments":{"11":{"from_node_id":"12","to_node_id":"13","b1":null,"b2":null},"12":{"from_node_id":"14","to_node_id":"13","b1":null,"b2":null},"13":{"from_node_id":"12","to_node_id":"11","b1":{"x":-33,"y":632},"b2":{"x":-32.99999999999999,"y":577.75}},"14":{"from_node_id":"12","to_node_id":"15","b1":{"x":-33,"y":628},"b2":{"x":-51,"y":622.75}},"15":{"from_node_id":"14","to_node_id":"16","b1":{"x":-33,"y":760},"b2":{"x":-15,"y":765.25}},"16":{"from_node_id":"14","to_node_id":"17","b1":{"x":-33,"y":760},"b2":{"x":-51,"y":765.25}},"17":{"from_node_id":"14","to_node_id":"18","b1":{"x":-33,"y":756},"b2":{"x":-33,"y":810.25}}}},"3":{"name":"Fructose-bisphosphate aldolase","bigg_id":"FBA","reversibility":true,"label_x":-18,"label_y":1054,"gene_reaction_rule":"b2097 or b1773 or b2925","genes":[{"notes":{"original_bigg_ids":["b2097"]},"name":"fbaB","bigg_id":"b2097"},{"notes":{"original_bigg_ids":["b1773"]},"name":"ydjI","bigg_id":"b1773"},{"notes":{"original_bigg_ids":["b2925"]},"name":"fbaA","bigg_id":"b2925"}],"metabolites":[{"bigg_id":"dhap_c","coefficient":1},{"bigg_id":"g3p_c","coefficient":1},{"bigg_id":"fdp_c","coefficient":-1}],"segments":{"18":{"from_node_id":"19","to_node_id":"20","b1":null,"b2":null},"19":{"from_node_id":"21","to_node_id":"20","b1":null,"b2":null},"20":{"from_node_id":"21","to_node_id":"22","b1":{"x":-33,"y":1106},"b2":{"x":-99.66671752929688,"y":1113.5833740234375}},"21":{"from_node_id":"21","to_node_id":"23","b1":{"x":-33,"y":1110},"b2":{"x":-31.000030517578125,"y":1123.2501220703125}},"22":{"from_node_id":"19","to_node_id":"18","b1":{"x":-33,"y":982},"b2":{"x":-32.999999 ...
