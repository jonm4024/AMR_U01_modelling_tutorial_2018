# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-data" data-toc-modified-id="Load-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load data</a></span><ul class="toc-item"><li><span><a href="#Load-expression-data-and-metadata" data-toc-modified-id="Load-expression-data-and-metadata-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load expression data and metadata</a></span></li><li><span><a href="#Load-S-and-A-matrices" data-toc-modified-id="Load-S-and-A-matrices-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Load S and A matrices</a></span></li></ul></li><li><span><a href="#Exploring-the-S-matrix" data-toc-modified-id="Exploring-the-S-matrix-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploring the S matrix</a></span><ul class="toc-item"><li><span><a href="#Example:-Component-#36" data-toc-modified-id="Example:-Component-#36-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Example: Component #36</a></span></li><li><span><a href="#I-modulon-thresholds" data-toc-modified-id="I-modulon-thresholds-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>I-modulon thresholds</a></span></li><li><span><a href="#Load-gene-annotation" data-toc-modified-id="Load-gene-annotation-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Load gene annotation</a></span></li><li><span><a href="#Load-TRN" data-toc-modified-id="Load-TRN-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Load TRN</a></span></li><li><span><a href="#Regulator-enrichments" data-toc-modified-id="Regulator-enrichments-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Regulator enrichments</a></span></li></ul></li><li><span><a href="#Naming-I-modulons" data-toc-modified-id="Naming-I-modulons-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Naming I-modulons</a></span></li><li><span><a href="#Exploring-the-A-matrix" data-toc-modified-id="Exploring-the-A-matrix-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exploring the A matrix</a></span><ul class="toc-item"><li><span><a href="#Fear-greed-trade-off" data-toc-modified-id="Fear-greed-trade-off-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Fear-greed trade-off</a></span></li><li><span><a href="#The-Fur-i-modulons" data-toc-modified-id="The-Fur-i-modulons-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>The Fur i-modulons</a></span></li><li><span><a href="#Expanding-to-additional-strains" data-toc-modified-id="Expanding-to-additional-strains-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Expanding to additional strains</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from os.path import join
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
from statsmodels.stats.multitest import fdrcorrection

# %%
sns.set_style('ticks')

# %% [markdown]
# # Load data

# %% [markdown]
# ## Load expression data and metadata

# %%
log_tpm = pd.read_csv(join('data','log_tpm.csv'),index_col=0)
metadata = pd.read_csv(join('data','metadata.csv'),index_col=0)

# %% [markdown]
# ## Load S and A matrices

# %% [markdown]
# $$ \textbf{X} = \textbf{SA} $$

# %%
S = pd.read_csv(join('data','S.csv'),index_col=0)
A = pd.read_csv(join('data','A.csv'),index_col=0)

# For now, remove i-modulon names
S.columns = range(len(S.columns))
A.index = range(len(A.index))

# %% [markdown]
# **The S matrix**: Gene coefficients/weightings
# * Similar to a Principal Component
# * PRECISE: ~4000 genes x 92 components
# * Most numbers are near zero
# * Nonzero values are most interesting

# %%
S.shape
# Out:
# (3923, 92)

# %%
sns.heatmap(S,center=0,cmap='RdBu_r')

# %%
S.head()
# Out:
#              0         1         2         3         4         5         6   \
# b0002 -0.010888 -0.007717 -0.008502 -0.012186 -0.061489 -0.005599 -0.007377
# b0003 -0.011467  0.003042  0.011448 -0.003685 -0.006106  0.006680 -0.043512
# b0004 -0.008693  0.003944  0.012347 -0.008104  0.000585  0.003245 -0.041283
# b0005  0.006565 -0.001099  0.009415 -0.008507  0.005399  0.014748 -0.009249
# b0006 -0.006011  0.009889 -0.005555 -0.000152 -0.002454  0.009678 -0.003456
#
#              7         8         9     ...           82        83        84  \
# b0002 -0.000795  0.004331  0.001845    ...     0.479209  0.035685  0.024778
# b0003  0.005107  0.000474  0.007650    ...     0.011420  0.040811  0.003324
# b0004  0.006390  0.004260  0.007109    ...     0.011339  0.036244  0.003710
# b0005 -0.003058 -0.012649 -0.002370    ...    -0.015324  0.028972  0.023969
# b0006  0.002160 -0.001924 -0.000628    ...    -0.005661  0.000700 -0.002538
#
#              85        86        87        88        89        90        91
# b0002 -0.010660 -0.002123 -0.004416 -0.005428 -0.009219 -0.004345 -0.007838
# b0003 -0.008424 -0.004415 -0.016126 -0.016476 -0.003497 -0.003583  0.003381
# b0004 -0.005212  0.000700 -0.011096 -0.006140 -0.003155 -0.008418  0.000129
# b0005  0.000150  0.018497  0.009428  0.001255 -0.006890 -0.028069  0.021534
# b0006 -0.006103 -0.002506 -0.005077 -0.004616 -0.003585  0.001607  0.001285
#
# [5 rows x 92 columns]

# %% [markdown]
# **The A matrix**: I-modulon activities
# * Similar to PC Loadings
# * 92 i-modulons x 278 samples
# * Contains i-modulon activities
# * Value of zero is reference condition (M9 glucose)

# %%
A.shape
# Out:
# (92, 278)

# %%
sns.heatmap(A,center=0,cmap='RdBu_r')

# %%
A.head()
# Out:
#    control__wt_glc__1  control__wt_glc__2  fur__wt_dpd__1  fur__wt_dpd__2  \
# 0            0.378690           -0.378690        2.457678        2.248678
# 1           -0.440210            0.440210       -5.367360       -5.684301
# 2            0.762258           -0.762258        2.619623        2.900696
# 3           -0.289630            0.289630      -10.085719      -13.187916
# 4            0.250770           -0.250770        1.844767        2.055052
#
#    fur__wt_fe__1  fur__wt_fe__2  fur__delfur_dpd__1  fur__delfur_dpd__2  \
# 0      -0.327344      -0.259164            1.777251            2.690655
# 1       0.131174       0.348843           -4.436389           -4.770469
# 2       3.120724       2.743634            1.989803            1.555835
# 3       2.371129       1.861918           -8.708701           -7.881588
# 4       0.299345       0.425502            1.801217            1.790987
#
#    fur__delfur_fe2__1  fur__delfur_fe2__2             ...               \
# 0            0.656937            0.319583             ...
# 1           -1.799113           -1.474222             ...
# 2            1.782500            1.530811             ...
# 3           -1.237027           -1.235604             ...
# 4            0.921254            1.410026             ...
#
#    efeU__menFentC_ale29__1  efeU__menFentC_ale29__2  efeU__menFentC_ale30__1  \
# 0                 1.041336                 2.203940                 3.698292
# 1                -6.471714                -6.549861                -3.109145
# 2                 2.789653                 3.959650                 1.585147
# 3               -11.263744               -10.366813                -0.289217
# 4                 3.821909                 3.306573                 2.652394
#
#    efeU__menFentC_ale30__2  efeU__menFentCubiC_ale36__1  \
# 0                 0.856998                     1.557323
# 1                -2.716183                    -2.531192
# 2                 0.811182                     0.300414
# 3                 0.389228                    -5.142768
# 4                 1.910173                     0.927772
#
#    efeU__menFentCubiC_ale36__2  efeU__menFentCubiC_ale37__1  \
# 0                     0.337806                     0.943742
# 1                    -1.461022                    -0.408849
# 2                     2.537535                     1.061408
# 3                    -5.014526                    -3.648777
# 4                     1.327549                     1.846321
#
#    efeU__menFentCubiC_ale37__2  efeU__menFentCubiC_ale38__1  \
# 0                     1.736640                     0.499461
# 1                    -0.210397                    -5.700321
# 2                     2.634524                     0.125513
# 3                    -4.125952                    -4.286326
# 4                     0.909667                     2.064662
#
#    efeU__menFentCubiC_ale38__2
# 0                     1.581476
# 1                    -6.237836
# 2                     1.178747
# 3                    -5.475940
# 4                     2.371405
#
# [5 rows x 278 columns]

# %% [markdown]
# # Exploring the S matrix

# %% [markdown]
# ## Example: Component #36

# %%
# One column of S is a component
S[36].head()
# Out:
# b0002   -0.004708
# b0003    0.007967
# b0004    0.004028
# b0005    0.006701
# b0006   -0.003870
# Name: 36, dtype: float64

# %%
fig,ax = plt.subplots(3,1,figsize=(4,9))

# Linear y-scale shows that most coefficients are near 0
ax[0].set_title('Linear y-scale',fontsize=16)
ax[0].hist(S[36].values)
ax[0].set_xlabel('I-modulon Gene Coefficient',fontsize=14)
ax[0].set_ylabel('Number of Genes',fontsize=14)


# Log y-scale highlights outliers
ax[1].set_title('Log y-scale',fontsize=16)
ax[1].hist(S[36].values)
ax[1].set_yscale('log')
ax[1].set_xlabel('I-modulon Gene Coefficient',fontsize=14)
ax[1].set_ylabel('Number of Genes',fontsize=14)

# Where to draw thresholds?
ax[2].set_title('Example Thresholds',fontsize=16)
ax[2].hist(S[36].values)
ax[2].set_yscale('log')
ax[2].set_xlabel('I-modulon Gene Coefficient',fontsize=14)
ax[2].set_ylabel('Number of Genes',fontsize=14)
ax[2].vlines([-0.08,.08],0,3000)

plt.tight_layout()

# %% [markdown]
# ## I-modulon thresholds

# %%
def compute_threshold(S,k,cutoff=550):
    """Computes kurtosis-based threshold for a component of an S matrix
        S: Component matrix with gene weights
        k: Component name
        cutoff: Minimum test statistic value to determine threshold (550 is default from sensitivity analysis)
    """
    i = 0 
    # Sort genes based on absolute value
    ordered_genes = abs(S[k]).sort_values()
    K,p = stats.normaltest(S.loc[:,k])
    while K > cutoff:
        i -= 1
        # Check if K statistic is below cutoff
        K,p = stats.normaltest(S.loc[ordered_genes.index[:i],k])
    comp_genes = ordered_genes.iloc[i:]
    if len(comp_genes) == len(S.index):
        return max(comp_genes)+.05
    else:
        return np.mean([ordered_genes.iloc[i],ordered_genes.iloc[i-1]])
    
def get_imodulon(S,k,annotation=None,trn=None):
    """
    Returns pandas dataframe containing i-modulon genes and coefficients.
    
    Parameters:
        S: Component matrix with gene weights
        k: I-modulon name
        show_info: Show extended information about each gene
        show_regs: Show known regulators for each gene (separated by commas)
    """
    
    if k not in S.columns:
        raise ValueError('{} is not a valid i-modulon name. See S.index'.format(name))
    
    comp = S[k]
    thresh = compute_threshold(S,k)
    genes = comp[abs(comp) > thresh].sort_values(ascending=False)
    
    if annotation is None: 
        df = pd.DataFrame(genes)
    else:
        df = gene_info.loc[genes.index]
        df['coefficient'] = genes.values
    
    if trn is not None:
        for gene in genes.index:
            df.loc[gene,'regulators'] = ','.join(trn[trn.gene_id==gene].regulator.tolist())
    return df

# %%
get_imodulon(S,36)
# Out:
#              36
# b3941  0.288795
# b4013  0.272038
# b3828  0.229074
# b0260  0.216009
# b3829  0.210910
# b0600  0.206409
# b0599  0.176938
# b0199  0.176367
# b3939  0.165735
# b2942  0.159666
# b0198  0.140481
# b0261  0.136112
# b3008  0.135951
# b3940  0.130638
# b0197  0.122575
# b3937  0.098325
# b3938  0.095358

# %% [markdown]
# ## Load gene annotation

# %%
gene_info = pd.read_csv(join('data','gene_info.csv'),index_col=0)

# %%
gene_info.head()
# Out:
#        start  stop strand gene_name  length   operon  \
# b0001    189   255      +      thrL      66  thrLABC
# b0002    336  2799      +      thrA    2463  thrLABC
# b0003   2800  3733      +      thrB     933  thrLABC
# b0004   3733  5020      +      thrC    1287  thrLABC
# b0005   5233  5530      +      yaaX     297     yaaX
#
#                                        cog  \
# b0001                    No COG Annotation
# b0002  Amino acid transport and metabolism
# b0003  Amino acid transport and metabolism
# b0004  Amino acid transport and metabolism
# b0005                     Function unknown
#
#                                                  Product
# b0001                   <i>thr</i> operon leader peptide
# b0002  fused aspartate kinase/homoserine dehydrogenase 1
# b0003                                  homoserine kinase
# b0004                                    THRESYN-MONOMER
# b0005             DUF2502 domain-containing protein YaaX

# %% [markdown]
# ## Load TRN

# %%
trn = pd.read_csv(join('data','TRN.csv'),index_col=0)

# %%
trn.tail()
# Out:
#      regulator gene_id
# 8320      csqR   b3882
# 8321      csqR   b3881
# 8322      csqR   b3880
# 8323      csqR   b3883
# 8324      csqR   b3884

# %%
# Also includes riboswitches 
# TPP = thiamine, FMN = flavin mononucleotide
trn.head()
# Out:
#       regulator gene_id
# 0           FMN   b3041
# 1  L-tryptophan   b3708
# 2  L-tryptophan   b3709
# 3           TPP   b0066
# 4           TPP   b0067

# %%
get_imodulon(S,36,annotation=gene_info,trn=trn)
# Out:
#          start     stop strand gene_name  length  operon  \
# b3941  4132615  4133506      +      metF     891    metF
# b4013  4214279  4215209      +      metA     930    metA
# b3828  4011862  4012816      -      metR     954    metR
# b0260   275324   276728      +      mmuP    1404   mmuPM
# b3829  4013052  4015314      +      metE    2262    metE
# b0600   633585   634746      +      ybdL    1161    ybdL
# b0599   632388   633477      -      ybdH    1089    hcxA
# b0199   221613   222645      -      metN    1032  metNIQ
# b3939  4128671  4129832      +      metB    1161   metBL
# b2942  3086705  3087860      +      metK    1155    metK
# b0198   220967   221621      -      metI     654  metNIQ
# b0261   276714   277647      +      mmuM     933   mmuPM
# b3008  3152235  3153423      +      metC    1188    metC
# b3940  4129834  4132267      +      metL    2433   metBL
# b0197   220112   220928      -      metQ     816  metNIQ
# b3937  4127285  4127894      -      yiiX     609    yiiX
# b3938  4128077  4128395      -      metJ     318    metJ
#
#                                           cog  \
# b3941     Amino acid transport and metabolism
# b4013     Amino acid transport and metabolism
# b3828                           Transcription
# b0260     Amino acid transport and metabolism
# b3829     Amino acid transport and metabolism
# b0600     Amino acid transport and metabolism
# b0599        Energy production and conversion
# b0199  Inorganic ion transport and metabolism
# b3939     Amino acid transport and metabolism
# b2942       Coenzyme transport and metabolism
# b0198  Inorganic ion transport and metabolism
# b0261     Amino acid transport and metabolism
# b3008     Amino acid transport and metabolism
# b3940     Amino acid transport and metabolism
# b0197  Inorganic ion transport and metabolism
# b3937                        Function unknown
# b3938                           Transcription
#
#                                                  Product  coefficient  \
# b3941           5,10-methylenetetrahydrofolate reductase     0.288795
# b4013            homoserine <i>O</i>-succinyltransferase     0.272038
# b3828    DNA-binding transcriptional dual regulator MetR     0.229074
# b0260                                      B0260-MONOMER     0.216009
# b3829                                 HOMOCYSMET-MONOMER     0.210910
# b0600    methionine-oxo-acid transaminase, PLP-dependent     0.206409
# b0599                 hydroxycarboxylate dehydrogenase A     0.176938
# b0199  L-methionine/D-methionine ABC transporter ATP ...     0.176367
# b3939  <i>O</i>-succinylhomoserine(thiol)-lyase / <i>...     0.165735
# b2942                     methionine adenosyltransferase     0.159666
# b0198  L-methionine/D-methionine ABC transporter memb...     0.140481
# b0261                                       MMUM-MONOMER     0.136112
# b3008  cystathionine &beta;-lyase / L-cysteine desulf...     0.135951
# b3940  fused aspartate kinase/homoserine dehydrogenase 2     0.130638
# b0197  L-methionine/D-methionine ABC transporter memb...     0.122575
# b3937                   putative lipid binding hydrolase     0.098325
# b3938         DNA-binding transcriptional repressor MetJ     0.095358
#
#                        regulators
# b3941                   metJ,rpoD
# b4013              metJ,rpoD,rpoH
# b3828          metJ,metR,nac,oxyR
# b0260
# b3829      cra,metJ,metR,nac,oxyR
# b0600
# b0599
# b0199          fnr,hypT,metJ,rpoD
# b3939         hypT,metJ,phoP,rpoD
# b2942  crp,fnr,gadX,lrp,metJ,rpoD
# b0198          fnr,hypT,metJ,rpoD
# b0261
# b3008                   metJ,rpoD
# b3940         hypT,metJ,phoP,rpoD
# b0197          fnr,hypT,metJ,rpoD
# b3937
# b3938                    fur,rpoD

# %% [markdown]
# ## Regulator enrichments

# %%
def get_regulon(regulator,trn):
    """
    Parses regulators (for / and + operators) and returns the genes in the regulon.
    
    "/" indicates an OR relation (i.e. union of regulons)
    "+" indicates an AND relation (i.e. intersection of regulons)
    
    Parameters:
        regulator: Name of regulator (see imodulons.regulator)
        trn: TRN dataframe
    """
    
    if '/' in regulator:
        regs = regulator.split('/')
        genes = set()
        for reg in regs:
            genes = genes.union(trn[trn.regulator == reg].gene_id.tolist())
        return sorted(genes)
        
    elif '+' in regulator:
        regs = regulator.split('+')
        genes = trn[trn.regulator.isin(regs)].gene_id.tolist()
        return sorted(genes)
    else:
        return trn[trn.regulator == regulator].gene_id.tolist()

def compute_enrichment(S,k,regulator,trn):
    
    """
    Calculates the enrichment of a regulator (see get_regulon) in an i-modulon
    
    Parameters:
        S: Component matrix with gene weights
        k: I-modulon name
        regulator:
        trn: TRN dataframe
    """
        
    regulon = set(get_regulon(regulator,trn))
    imodulon = set(get_imodulon(S,k).index)
    all_genes = set(S.index)
    
    # Compute contingency
    ((tp,fp),(fn,tn)) = contingency(regulon,imodulon,all_genes)
    
    # Handle edge cases
    if tp == 0:
        res = [1,0,0,0]
    elif fp == 0 and fn == 0:
        res = [0,1,1,len(imodulon)]
    else:
        odds,pval = stats.fisher_exact([[tp,fp],[fn,tn]],alternative='greater')
        recall = np.true_divide(tp,tp+fn)
        precision = np.true_divide(tp,tp+fp)
        res = [pval,recall,precision,tp]
    return pd.Series(res,index=['pvalue','recall','precision','TP'],
                     name=regulator)

def contingency(set1,set2,all_genes):
    """Creates contingency table for gene enrichment
        set1: Set of genes (e.g. regulon)
        set2: Set of genes (e.g. i-modulon)
        all_genes: Set of all genes
    """
        
    tp = len(set1 & set2)
    fp = len(set2 - set1)
    tn = len(all_genes - set1 - set2)
    fn = len(set1 - set2)
    return [[tp,fp],[fn,tn]]

def fdr(enrich,alpha=1e-5):
    return enrich[fdrcorrection(enrich.pvalue,alpha=1e-5)[0]].sort_values('pvalue')

# %%
compute_enrichment(S,36,'metJ',trn)
# Out:
# pvalue       2.007782e-25
# recall       7.333333e-01
# precision    6.470588e-01
# TP           1.100000e+01
# Name: metJ, dtype: float64

# %%
venn = venn2((set(get_regulon('metJ',trn)),set(get_imodulon(S,36).index)),
             set_labels=('Regulon','I-modulon'))
for text in venn.set_labels:
    text.set_fontsize(20)
for text in venn.subset_labels:
    text.set_fontsize(20)

# %%
list2struct = []
for tf in trn.regulator.unique():
    list2struct.append(compute_enrichment(S,36,tf,trn))
enrichments = pd.DataFrame(list2struct)

# %%
fdr(enrichments,alpha=1e-5)
# Out:
#             pvalue    recall  precision    TP
# metJ  2.007782e-25  0.733333   0.647059  11.0
# hypT  1.010282e-09  0.384615   0.294118   5.0

# %% [markdown]
# # Naming I-modulons

# %%
S = pd.read_csv(join('data','S.csv'),index_col=0)
A = pd.read_csv(join('data','A.csv'),index_col=0)

DF_imodulons = pd.read_csv(join('data','curated_enrichments.csv'),index_col=0)

# %%
DF_imodulons.head()
# Out:
#                      regulator   f1score        pvalue  precision    recall  \
# name
# AllR/AraC/FucR  allR/araC/fucR  0.750000  1.190000e-41   1.000000  0.600000
# ArcA-1                    arcA  0.130952  6.420000e-20   0.660000  0.072687
# ArcA-2                    arcA  0.087683  1.150000e-16   0.840000  0.046256
# ArgR                      argR  0.177778  6.030000e-18   0.923077  0.098361
# AtoC                      atoC  0.800000  1.520000e-12   0.666667  1.000000
#
#                   TP  n_genes  n_tf                                Category  \
# name
# AllR/AraC/FucR  18.0       18     3               Carbon Source Utilization
# ArcA-1          33.0       50     1                       Energy Metabolism
# ArcA-2          21.0       25     1                       Energy Metabolism
# ArgR            12.0       13     1  Amino Acid and Nucleotide Biosynthesis
# AtoC             4.0        6     1                Miscellaneous Metabolism
#
#                 threshold
# name
# AllR/AraC/FucR   0.086996
# ArcA-1           0.058051
# ArcA-2           0.081113
# ArgR             0.080441
# AtoC             0.105756

# %%
A.head()
# Out:
#                 control__wt_glc__1  control__wt_glc__2  fur__wt_dpd__1  \
# AllR/AraC/FucR            0.378690           -0.378690        2.457678
# ArcA-1                   -0.440210            0.440210       -5.367360
# ArcA-2                    0.762258           -0.762258        2.619623
# ArgR                     -0.289630            0.289630      -10.085719
# AtoC                      0.250770           -0.250770        1.844767
#
#                 fur__wt_dpd__2  fur__wt_fe__1  fur__wt_fe__2  \
# AllR/AraC/FucR        2.248678      -0.327344      -0.259164
# ArcA-1               -5.684301       0.131174       0.348843
# ArcA-2                2.900696       3.120724       2.743634
# ArgR                -13.187916       2.371129       1.861918
# AtoC                  2.055052       0.299345       0.425502
#
#                 fur__delfur_dpd__1  fur__delfur_dpd__2  fur__delfur_fe2__1  \
# AllR/AraC/FucR            1.777251            2.690655            0.656937
# ArcA-1                   -4.436389           -4.770469           -1.799113
# ArcA-2                    1.989803            1.555835            1.782500
# ArgR                     -8.708701           -7.881588           -1.237027
# AtoC                      1.801217            1.790987            0.921254
#
#                 fur__delfur_fe2__2             ...               \
# AllR/AraC/FucR            0.319583             ...
# ArcA-1                   -1.474222             ...
# ArcA-2                    1.530811             ...
# ArgR                     -1.235604             ...
# AtoC                      1.410026             ...
#
#                 efeU__menFentC_ale29__1  efeU__menFentC_ale29__2  \
# AllR/AraC/FucR                 1.041336                 2.203940
# ArcA-1                        -6.471714                -6.549861
# ArcA-2                         2.789653                 3.959650
# ArgR                         -11.263744               -10.366813
# AtoC                           3.821909                 3.306573
#
#                 efeU__menFentC_ale30__1  efeU__menFentC_ale30__2  \
# AllR/AraC/FucR                 3.698292                 0.856998
# ArcA-1                        -3.109145                -2.716183
# ArcA-2                         1.585147                 0.811182
# ArgR                          -0.289217                 0.389228
# AtoC                           2.652394                 1.910173
#
#                 efeU__menFentCubiC_ale36__1  efeU__menFentCubiC_ale36__2  \
# AllR/AraC/FucR                     1.557323                     0.337806
# ArcA-1                            -2.531192                    -1.461022
# ArcA-2                             0.300414                     2.537535
# ArgR                              -5.142768                    -5.014526
# AtoC                               0.927772                     1.327549
#
#                 efeU__menFentCubiC_ale37__1  efeU__menFentCubiC_ale37__2  \
# AllR/AraC/FucR                     0.943742                     1.736640
# ArcA-1                            -0.408849                    -0.210397
# ArcA-2                             1.061408                     2.634524
# ArgR                              -3.648777                    -4.125952
# AtoC                               1.846321                     0.909667
#
#                 efeU__menFentCubiC_ale38__1  efeU__menFentCubiC_ale38__2
# AllR/AraC/FucR                     0.499461                     1.581476
# ArcA-1                            -5.700321                    -6.237836
# ArcA-2                             0.125513                     1.178747
# ArgR                              -4.286326                    -5.475940
# AtoC                               2.064662                     2.371405
#
# [5 rows x 278 columns]

# %% [markdown]
# # Exploring the A matrix

# %%
def fit_line(x,y,ax):
    a, b, r, p,_ = stats.linregress(x,y)
    ax.plot([min(x),max(x)],[min(x)*a+b,max(x)*a+b],label='R = {:.2f}'.format(r),color='k')

# %% [markdown]
# See the metadata table for detailed information about each experiment

# %%
A.loc['MetJ'].head()
# Out:
# control__wt_glc__1    -0.106342
# control__wt_glc__2     0.106342
# fur__wt_dpd__1        10.653125
# fur__wt_dpd__2         8.413443
# fur__wt_fe__1         -0.371773
# Name: MetJ, dtype: float64

# %%
fig,ax = plt.subplots(figsize=(50,3))
ax.bar(range(A.shape[1]),A.loc['MetJ'],width=1,linewidth=0)
ax.set_xlim([-0.5,A.shape[1]-0.5])
ax.set_xticks(range(A.shape[1]))
ax.set_xticklabels(A.columns,rotation=90,fontsize=12)
ax.set_ylabel('MetJ I-modulon Activity',fontsize=16)
# Out:
# Text(0, 0.5, 'MetJ I-modulon Activity')

# %% [markdown]
# ## Fear-greed trade-off

# %%
DF_imodulons.loc['RpoS']
# Out:
# regulator               rpoS
# f1score             0.195122
# pvalue               1.1e-18
# precision           0.373832
# recall              0.132013
# TP                        40
# n_genes                  107
# n_tf                       1
# Category     Stress Response
# threshold           0.040188
# Name: RpoS, dtype: object

# %%
fig,ax = plt.subplots(figsize=(5,5))
ax.scatter(log_tpm.loc['b2741'],A.loc['RpoS'])
ax.set_xlabel('RpoS Expression',fontsize=16)
ax.set_ylabel('RpoS I-modulon Activity',fontsize=16)
fit_line(log_tpm.loc['b2741'],A.loc['RpoS'],ax)

# %%
get_imodulon(S,'translation',annotation=gene_info,trn=trn)
# Out:
#          start     stop strand gene_name  length  \
# b3315  3449900  3450233      -      rplV     333
# b3316  3450247  3450526      -      rpsS     279
# b3317  3450542  3451364      -      rplB     822
# b3314  3449181  3449883      -      rpsC     702
# b3319  3451680  3452286      -      rplD     606
# b3311  3448313  3448568      -      rpsQ     255
# b3318  3451381  3451684      -      rplW     303
# b3313  3448758  3449169      -      rplP     411
# b0429   447716   448046      -      cyoD     330
# b3320  3452296  3452926      -      rplC     630
# b3321  3452958  3453270      -      rpsJ     312
# b0430   448045   448660      -      cyoC     615
# b3312  3448567  3448759      -      rpmC     192
# b2762  2887577  2888312      -      cysH     735
# b4202  4425838  4426066      +      rpsR     228
# b3304  3445243  3445597      -      rplR     354
# b3303  3444725  3445229      -      rpsE     504
# b3306  3446152  3446545      -      rpsH     393
# b3231  3378222  3378651      -      rplM     429
# b3984  4178878  4179583      +      rplA     705
# b3300  3442765  3444097      -      secY    1332
# b4203  4426107  4426557      +      rplI     450
# b4201  4425519  4425834      +      priB     315
# b4002  4201262  4201688      -      zraP     426
#
#                                             operon  \
# b3315   rpsJ-rplCDWB-rpsS-rplV-rpsC-rplP-rpmC-rpsQ
# b3316   rpsJ-rplCDWB-rpsS-rplV-rpsC-rplP-rpmC-rpsQ
# b3317   rpsJ-rplCDWB-rpsS-rplV-rpsC-rplP-rpmC-rpsQ
# b3314   rpsJ-rplCDWB-rpsS-rplV-rpsC-rplP-rpmC-rpsQ
# b3319   rpsJ-rplCDWB-rpsS-rplV-rpsC-rplP-rpmC-rpsQ
# b3311   rpsJ-rplCDWB-rpsS-rplV-rpsC-rplP-rpmC-rpsQ
# b3318   rpsJ-rplCDWB-rpsS-rplV-rpsC-rplP-rpmC-rpsQ
# b3313   rpsJ-rplCDWB-rpsS-rplV-rpsC-rplP-rpmC-rpsQ
# b0429                                     cyoABCDE
# b3320   rpsJ-rplCDWB-rpsS-rplV-rpsC-rplP-rpmC-rpsQ
# b3321   rpsJ-rplCDWB-rpsS-rplV-rpsC-rplP-rpmC-rpsQ
# b0430                                     cyoABCDE
# b3312   rpsJ-rplCDWB-rpsS-rplV-rpsC-rplP-rpmC-rpsQ
# b2762                                       cysJIH
# b4202                          rpsF-priB-rpsR-rplI
# b3304  rplNXE-rpsNH-rplFR-rpsE-rpmD-rplO-secY-rpmJ
# b3303  rplNXE-rpsNH-rplFR-rpsE-rpmD-rplO-secY-rpmJ
# b3306  rplNXE-rpsNH-rplFR-rpsE-rpmD-rplO-secY-rpmJ
# b3231                                    rplM-rpsI
# b3984                                rplKAJL-rpoBC
# b3300  rplNXE-rpsNH-rplFR-rpsE-rpmD-rplO-secY-rpmJ
# b4203                          rpsF-priB-rpsR-rplI
# b4201                          rpsF-priB-rpsR-rplI
# b4002                                         zraP
#
#                                                      cog  \
# b3315    Translation, ribosomal structure and biogenesis
# b3316    Translation, ribosomal structure and biogenesis
# b3317    Translation, ribosomal structure and biogenesis
# b3314    Translation, ribosomal structure and biogenesis
# b3319    Translation, ribosomal structure and biogenesis
# b3311    Translation, ribosomal structure and biogenesis
# b3318    Translation, ribosomal structure and biogenesis
# b3313    Translation, ribosomal structure and biogenesis
# b0429                   Energy production and conversion
# b3320    Translation, ribosomal structure and biogenesis
# b3321    Translation, ribosomal structure and biogenesis
# b0430                   Energy production and conversion
# b3312    Translation, ribosomal structure and biogenesis
# b2762             Inorganic ion transport and metabolism
# b4202    Translation, ribosomal structure and biogenesis
# b3304    Translation, ribosomal structure and biogenesis
# b3303    Translation, ribosomal structure and biogenesis
# b3306    Translation, ribosomal structure and biogenesis
# b3231    Translation, ribosomal structure and biogenesis
# b3984    Translation, ribosomal structure and biogenesis
# b3300  Intracellular trafficking, secretion, and vesi...
# b4203    Translation, ribosomal structure and biogenesis
# b4201              Replication, recombination and repair
# b4002                                      Cell motility
#
#                                                  Product  coefficient  \
# b3315                  50S ribosomal subunit protein L22     0.110544
# b3316                  30S ribosomal subunit protein S19     0.104094
# b3317                   50S ribosomal subunit protein L2     0.101821
# b3314                   30S ribosomal subunit protein S3     0.096774
# b3319                   50S ribosomal subunit protein L4     0.095053
# b3311                  30S ribosomal subunit protein S17     0.093796
# b3318                  50S ribosomal subunit protein L23     0.093268
# b3313                  50S ribosomal subunit protein L16     0.092656
# b0429  cytochrome <i>bo</i><sub>3</sub> ubiquinol oxi...     0.092124
# b3320                   50S ribosomal subunit protein L3     0.087126
# b3321                  30S ribosomal subunit protein S10     0.085273
# b0430  cytochrome <i>bo</i><sub>3</sub> ubiquinol oxi...     0.079671
# b3312                  50S ribosomal subunit protein L29     0.079171
# b2762          phosphoadenosine phosphosulfate reductase     0.078393
# b4202                  30S ribosomal subunit protein S18     0.077934
# b3304                  50S ribosomal subunit protein L18     0.076217
# b3303                   30S ribosomal subunit protein S5     0.076048
# b3306                   30S ribosomal subunit protein S8     0.072486
# b3231                  50S ribosomal subunit protein L13     0.071190
# b3984                   50S ribosomal subunit protein L1     0.071142
# b3300                        Sec translocon subunit SecY     0.070967
# b4203                   50S ribosomal subunit protein L9     0.070785
# b4201                   primosomal replication protein N     0.068960
# b4002                   signaling pathway modulator ZraP    -0.090406
#
#                                               regulators
# b3315                                      arcA,fnr,rpoD
# b3316                                      arcA,fnr,rpoD
# b3317                                      arcA,fnr,rpoD
# b3314                                      arcA,fnr,rpoD
# b3319                                      arcA,fnr,rpoD
# b3311                                      arcA,fnr,rpoD
# b3318                                      arcA,fnr,rpoD
# b3313                                      arcA,fnr,rpoD
# b0429  arcA,cra,crp,cusR,fis,fnr,fur,gadE,hprR,pdhR,rpoD
# b3320                                      arcA,fnr,rpoD
# b3321                                      arcA,fnr,rpoD
# b0430  arcA,cra,crp,cusR,fis,fnr,fur,gadE,hprR,pdhR,rpoD
# b3312                                      arcA,fnr,rpoD
# b2762                                 cysB,hypT,ihf,rpoD
# b4202                                           crp,rpoD
# b3304
# b3303
# b3306
# b3231                                   crp,fis,fnr,rpoD
# b3984
# b3300
# b4203                                           crp,rpoD
# b4201                                           crp,rpoD
# b4002                                          rpoN,zraR

# %%
fig,ax = plt.subplots(figsize=(5,5))
ax.scatter(A.loc['translation'],metadata['Growth Rate (1/hr)'])
ax.set_xlabel('Translation I-modulon Activity',fontsize=16)
ax.set_ylabel('Growth Rate (1/hr)',fontsize=16)
# Out:
# Text(0, 0.5, 'Growth Rate (1/hr)')

# %%
fig,ax = plt.subplots(figsize=(5,5))
ax.scatter(A.loc['RpoS'],A.loc['translation'])
ax.set_xlabel('RpoS I-modulon Activity',fontsize=16)
ax.set_ylabel('Translation I-modulon Activity',fontsize=16)
fit_line(A.loc['RpoS'],A.loc['translation'],ax)

# %% [markdown]
# ## The Fur i-modulons

# %%
# %matplotlib notebook

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs=A.loc['Fur-1'],ys=A.loc['Fur-2'],zs=A.loc['iron-related'])
ax.set_xlabel('Fur-1 I-modulon')
ax.set_ylabel('Fur-2 I-modulon')
ax.set_zlabel('ryhB I-modulon')
# Out:
# <img src="data:image/png;base64,..." width="500">
# Text(0.5, 0, 'ryhB I-modulon')

# %%
get_imodulon(S,'Fur-1',annotation=gene_info,trn=trn)
# Out:
#            start     stop strand gene_name  length              operon  \
# b2155    2244777  2246769      -      cirA    1992                cirA
# b0584     610253   612494      -      fepA    2241           fepA-entD
# b0805     839248   841531      -       fiu    2283                 fiu
# b0586     614156   618038      +      entF    3882  fes-ybdZ-entF-fepE
# b0585     612736   613939      +       fes    1203  fes-ybdZ-entF-fepE
# b0594     626069   627680      +      entE    1611            entCEBAH
# b0595     627693   628551      +      entB     858            entCEBAH
# b0804     838529   839207      -      ybiX     678                ybiX
# b0583     609458   610079      -      entD     621           fepA-entD
# b0593     624884   626060      +      entC    1176            entCEBAH
# b1102    1159361  1161551      -      fhuE    2190                fhuE
# b4511     613941   614160      +      ybdZ     219  fes-ybdZ-entF-fepE
# b0596     628550   629297      +      entA     747            entCEBAH
# b0597     629299   629713      +      entH     414            entCEBAH
# b2676    2803501  2804461      +      nrdF     960             nrdHIEF
# b4567    4605803  4606040      +      yjjZ     237                yjjZ
# b2675    2801347  2803492      +      nrdE    2145             nrdHIEF
# b2674    2800964  2801375      +      nrdI     411             nrdHIEF
# b0591     622299   623550      +      entS    1251                entS
# b1705    1789612  1789804      +      ydiE     192                ydiE
# b1452    1523306  1524368      +      yncE    1062                yncE
# b2673    2800722  2800968      +      nrdH     246             nrdHIEF
# b0588     619383   620199      -      fepC     816              fepDGC
# b0589     620195   621188      -      fepG     993              fepDGC
# b0590     621184   622189      -      fepD    1005              fepDGC
# b1681    1760519  1761791      -      sufD    1272           sufABCDSE
# b0592     623553   624510      -      fepB     957                fepB
# b1679    1758873  1759290      -      sufE     417           sufABCDSE
# b4292    4516763  4517717      -      fecR     954               fecIR
# b1684    1764017  1764386      -      sufA     369           sufABCDSE
# b1683    1762521  1764009      -      sufB    1488           sufABCDSE
# b1680    1759302  1760523      -      sufS    1221           sufABCDSE
# b1682    1761765  1762512      -      sufC     747           sufABCDSE
# b1495    1575246  1577619      -      yddB    2373               yddAB
# b1496    1577656  1579342      -      yddA    1686               yddAB
# b4293    4517713  4518235      -      fecI     522               fecIR
# b0587     618253   619387      +      fepE    1134  fes-ybdZ-entF-fepE
# b4582_1  2068634  2068940      +    yoeA_1     306              yoeA_1
# b1494    1572406  1575202      -      pqqL    2796                pqqL
# b4291    4514352  4516677      -      fecA    2325            fecABCDE
# b0803     838189   838456      -      ybiI     267                ybiI
# b0152     170574   171465      +      fhuD     891             fhuACDB
# b0151     169777   170575      +      fhuC     798             fhuACDB
# b0153     171461   173444      +      fhuB    1983             fhuACDB
# b3070    3215726  3216491      -      yqjH     765                yqjH
# b4640_1  2067457  2067892      -    yoeG_1     435              yoeG_1
# b3336    3466248  3466725      -       bfr     477             bfd-bfr
# b1656    1735377  1735959      +      sodB     582                sodB
#
#                                                        cog  \
# b2155               Inorganic ion transport and metabolism
# b0584               Inorganic ion transport and metabolism
# b0805               Inorganic ion transport and metabolism
# b0586    Secondary metabolites biosynthesis, transport ...
# b0585               Inorganic ion transport and metabolism
# b0594    Secondary metabolites biosynthesis, transport ...
# b0595    Secondary metabolites biosynthesis, transport ...
# b0804                                     Function unknown
# b0583    Secondary metabolites biosynthesis, transport ...
# b0593                    Coenzyme transport and metabolism
# b1102               Inorganic ion transport and metabolism
# b4511                                     Function unknown
# b0596                                     Function unknown
# b0597    Secondary metabolites biosynthesis, transport ...
# b2676                  Nucleotide transport and metabolism
# b4567                                     Function unknown
# b2675                  Nucleotide transport and metabolism
# b2674                  Nucleotide transport and metabolism
# b0591                Carbohydrate transport and metabolism
# b1705               Inorganic ion transport and metabolism
# b1452                                     Function unknown
# b2673    Posttranslational modification, protein turnov...
# b0588               Inorganic ion transport and metabolism
# b0589               Inorganic ion transport and metabolism
# b0590               Inorganic ion transport and metabolism
# b1681    Posttranslational modification, protein turnov...
# b0592               Inorganic ion transport and metabolism
# b1679                                     Function unknown
# b4292                       Signal transduction mechanisms
# b1684                                     Function unknown
# b1683    Posttranslational modification, protein turnov...
# b1680                  Amino acid transport and metabolism
# b1682    Posttranslational modification, protein turnov...
# b1495               Inorganic ion transport and metabolism
# b1496                                     Function unknown
# b4293                                        Transcription
# b0587               Cell wall/membrane/envelope biogenesis
# b4582_1                                  No COG Annotation
# b1494    Posttranslational modification, protein turnov...
# b4291               Inorganic ion transport and metabolism
# b0803                       Signal transduction mechanisms
# b0152               Inorganic ion transport and metabolism
# b0151               Inorganic ion transport and metabolism
# b0153               Inorganic ion transport and metabolism
# b3070               Inorganic ion transport and metabolism
# b4640_1                                  No COG Annotation
# b3336               Inorganic ion transport and metabolism
# b1656               Inorganic ion transport and metabolism
#
#                                                    Product  coefficient  \
# b2155                                      EG10155-MONOMER     0.247534
# b0584       ferric enterobactin outer membrane transporter     0.247471
# b0805    putative iron siderophore outer membrane trans...     0.245032
# b0586    seryl-[EntF peptidyl-carrier protein] // "<i>h...     0.206488
# b0585                         ferric enterobactin esterase     0.197510
# b0594                     2,3-dihydroxybenzoate-AMP ligase     0.173521
# b0595    <i>holo</i> EntB // "enterobactin synthase com...     0.172764
# b0804                           PKHD-type hydroxylase YbiX     0.169382
# b0583                 phosphopantetheinyl transferase EntD     0.169132
# b0593                          isochorismate synthase EntC     0.166299
# b1102    ferric coprogen/ferric rhodotorulic acid outer...     0.164438
# b4511               enterobactin biosynthesis protein YbdZ     0.161349
# b0596      2,3-dihydro-2,3-dihydroxybenzoate dehydrogenase     0.155965
# b0597    proofreading thioesterase in enterobactin bios...     0.149545
# b2676    ribonucleoside-diphosphate reductase 2 subunit...     0.124804
# b4567               DUF1435 domain-containing protein YjjZ     0.120401
# b2675    ribonucleoside-diphosphate reductase 2 subunit...     0.119478
# b2674    dimanganese-tyrosyl radical cofactor maintenan...     0.115032
# b0591                                         YBDA-MONOMER     0.107137
# b1705                          PF10636 family protein YdiE     0.106153
# b1452              PQQ-like domain-containing protein YncE     0.104935
# b2673                            glutaredoxin-like protein     0.104328
# b0588    ferric enterobactin ABC transporter ATP bindin...     0.103335
# b0589    ferric enterobactin ABC transporter membrane s...     0.096084
# b0590    ferric enterobactin ABC transporter membrane s...     0.089680
# b1681           Fe-S cluster scaffold complex subunit SufD     0.086080
# b0592    ferric enterobactin ABC transporter periplasmi...     0.085227
# b1679                          sulfur carrier protein SufE     0.084060
# b4292                regulator for fec operon, periplasmic     0.082680
# b1684           iron-sulfur cluster insertion protein SufA     0.082251
# b1683           Fe-S cluster scaffold complex subunit SufB     0.081173
# b1680                               L-cysteine desulfurase     0.080921
# b1682           Fe-S cluster scaffold complex subunit SufC     0.080519
# b1495                     putative TonB-dependent receptor     0.078045
# b1496                  ABC transporter family protein YddA     0.076586
# b4293                     RNA polymerase sigma factor FecI     0.076229
# b0587     polysaccharide co-polymerase family protein FepE     0.068176
# b4582_1                                                NaN     0.067789
# b1494                              putative zinc peptidase     0.067299
# b4291            ferric citrate outer membrane transporter     0.063764
# b0803           zinc finger domain-containing protein YbiI     0.063212
# b0152    iron(III) hydroxamate ABC transporter periplas...     0.061659
# b0151    iron(III) hydroxamate ABC transporter ATP bind...     0.058259
# b0153    iron(III) hydroxamate ABC transporter membrane...     0.057953
# b3070             NADPH-dependent ferric-chelate reductase     0.054751
# b4640_1                                                NaN    -0.058392
# b3336                                     bacterioferritin    -0.060257
# b1656                            superoxide dismutase (Fe)    -0.104642
#
#                           regulators
# b2155              arcA,crp,fur,rpoD
# b0584                   crp,fur,rpoD
# b0805              arcA,crp,fur,rpoD
# b0586              fnr,fur,h-NS,rpoD
# b0585              fnr,fur,h-NS,rpoD
# b0594                   crp,fur,rpoD
# b0595                   crp,fur,rpoD
# b0804                       fur,yieP
# b0583                   crp,fur,rpoD
# b0593                   crp,fur,rpoD
# b1102                            fur
# b4511              fnr,fur,h-NS,rpoD
# b0596                   crp,fur,rpoD
# b0597                   crp,fur,rpoD
# b2676         cra,fur,iscR,nrdR,rpoD
# b4567          fnr,fur,nac,oxyR,rpoD
# b2675         cra,fur,iscR,nrdR,rpoD
# b2674         cra,fur,iscR,nrdR,rpoD
# b0591                       fur,rpoD
# b1705                            fur
# b1452                  arcA,fur,marA
# b2673         cra,fur,iscR,nrdR,rpoD
# b0588                       fur,rpoD
# b0589                       fur,rpoD
# b0590                       fur,rpoD
# b1681    fur,ihf,iscR,nsrR,oxyR,rpoD
# b0592                  fur,rpoD,rutR
# b1679    fur,ihf,iscR,nsrR,oxyR,rpoD
# b4292                  fur,rpoD,slyA
# b1684    fur,ihf,iscR,nsrR,oxyR,rpoD
# b1683    fur,ihf,iscR,nsrR,oxyR,rpoD
# b1680    fur,ihf,iscR,nsrR,oxyR,rpoD
# b1682    fur,ihf,iscR,nsrR,oxyR,rpoD
# b1495                            fur
# b1496                            fur
# b4293                  fur,rpoD,slyA
# b0587              fnr,fur,h-NS,rpoD
# b4582_1                          fur
# b1494
# b4291         crp,fecI,fur,hypT,pdhR
# b0803                           rpoS
# b0152                  fur,rpoD,trpR
# b0151                  fur,rpoD,trpR
# b0153                  fur,rpoD,trpR
# b3070                  fur,rpoD,yqjI
# b4640_1
# b3336                            nac
# b1656              crp,ihf,nsrR,rpoD

# %%
get_imodulon(S,'Fur-2',annotation=gene_info,trn=trn)
# Out:
#            start     stop strand gene_name  length              operon  \
# b4367    4604874  4605663      -      fhuF     789                fhuF
# b0150     167483   169727      +      fhuA    2244             fhuACDB
# b0590     621184   622189      -      fepD    1005              fepDGC
# b3337    3466796  3466991      -       bfd     195             bfd-bfr
# b0591     622299   623550      +      entS    1251                entS
# b3006    3151249  3151984      -      exbB     735               exbBD
# b3408    3540162  3540390      +      feoA     228              feoABC
# b0588     619383   620199      -      fepC     816              fepDGC
# b1252    1311088  1311808      +      tonB     720                tonB
# b0589     620195   621188      -      fepG     993              fepDGC
# b2211    2306971  2308615      -      yojI    1644                yojI
# b0151     169777   170575      +      fhuC     798             fhuACDB
# b3409    3540406  3542728      +      feoB    2322              feoABC
# b3005    3150817  3151243      -      exbD     426               exbBD
# b0585     612736   613939      +       fes    1203  fes-ybdZ-entF-fepE
# b4293    4517713  4518235      -      fecI     522               fecIR
# b0152     170574   171465      +      fhuD     891             fhuACDB
# b0468     490881   491259      +      ybaN     378                ybaN
# b1452    1523306  1524368      +      yncE    1062                yncE
# b0592     623553   624510      -      fepB     957                fepB
# b2673    2800722  2800968      +      nrdH     246             nrdHIEF
# b3515    3663889  3664618      -      gadW     729              gadAXW
# b4490_2  1081459  1082185      +    efeU_2     726           efeU_1U_2
# b2146    2234032  2235271      +      preT    1239               preTA
# b1673    1751727  1753830      -      ydhV    2103           ydhYVWXUT
# b1674    1753850  1754477      -      ydhY     627           ydhYVWXUT
# b1905    1988715  1989213      +      ftnA     498                ftnA
#
#                                                        cog  \
# b4367                                     Function unknown
# b0150               Inorganic ion transport and metabolism
# b0590               Inorganic ion transport and metabolism
# b3337                                     Function unknown
# b0591                Carbohydrate transport and metabolism
# b3006    Intracellular trafficking, secretion, and vesi...
# b3408               Inorganic ion transport and metabolism
# b0588               Inorganic ion transport and metabolism
# b1252               Cell wall/membrane/envelope biogenesis
# b0589               Inorganic ion transport and metabolism
# b2211                                   Defense mechanisms
# b0151               Inorganic ion transport and metabolism
# b3409               Inorganic ion transport and metabolism
# b3005    Intracellular trafficking, secretion, and vesi...
# b0585               Inorganic ion transport and metabolism
# b4293                                        Transcription
# b0152               Inorganic ion transport and metabolism
# b0468                                     Function unknown
# b1452                                     Function unknown
# b0592               Inorganic ion transport and metabolism
# b2673    Posttranslational modification, protein turnov...
# b3515                                    No COG Annotation
# b4490_2                                  No COG Annotation
# b2146                  Amino acid transport and metabolism
# b1673                     Energy production and conversion
# b1674                     Energy production and conversion
# b1905               Inorganic ion transport and metabolism
#
#                                                    Product  coefficient  \
# b4367               hydroxamate siderophore iron reductase     0.240632
# b0150    ferrichrome outer membrane transporter/phage r...     0.190665
# b0590    ferric enterobactin ABC transporter membrane s...     0.147707
# b3337               bacterioferritin-associated ferredoxin     0.145296
# b0591                                         YBDA-MONOMER     0.130018
# b3006                             Ton complex subunit ExbB     0.126099
# b3408                     ferrous iron transport protein A     0.122971
# b0588    ferric enterobactin ABC transporter ATP bindin...     0.121926
# b1252                             Ton complex subunit TonB     0.121358
# b0589    ferric enterobactin ABC transporter membrane s...     0.120050
# b2211    ABC transporter family protein / microcin J25 ...     0.112919
# b0151    iron(III) hydroxamate ABC transporter ATP bind...     0.112336
# b3409                     Fe<sup>2+</sup> transporter FeoB     0.111661
# b3005                             Ton complex subunit ExbD     0.110470
# b0585                         ferric enterobactin esterase     0.106237
# b4293                     RNA polymerase sigma factor FecI     0.096470
# b0152    iron(III) hydroxamate ABC transporter periplas...     0.096039
# b0468    DUF454 domain-containing inner membrane protei...     0.093143
# b1452              PQQ-like domain-containing protein YncE     0.093082
# b0592    ferric enterobactin ABC transporter periplasmi...     0.091150
# b2673                            glutaredoxin-like protein     0.090619
# b3515      DNA-binding transcriptional dual regulator GadW     0.089828
# b4490_2                                                NaN     0.087785
# b2146    NAD-dependent dihydropyrimidine dehydrogenase ...    -0.089343
# b1673                         putative oxidoreductase YdhV    -0.098993
# b1674         putative 4Fe-4S ferredoxin-like protein YdhY    -0.123377
# b1905                        ferritin iron storage protein    -0.127220
#
#                                                 regulators
# b4367                                fnr,fur,nac,oxyR,rpoD
# b0150                                             fur,rpoD
# b0590                                             fur,rpoD
# b3337                                                  nac
# b0591                                             fur,rpoD
# b3006                                             fur,rpoD
# b3408                               arcA,fnr,fur,nagC,rpoD
# b0588                                             fur,rpoD
# b1252                                             fur,rpoD
# b0589                                             fur,rpoD
# b2211                                fur,lrp,nac,rpoD,ydcI
# b0151                                        fur,rpoD,trpR
# b3409                               arcA,fnr,fur,nagC,rpoD
# b3005                                             fur,rpoD
# b0585                                    fnr,fur,h-NS,rpoD
# b4293                                        fur,rpoD,slyA
# b0152                                        fur,rpoD,trpR
# b0468                                                  fur
# b1452                                        arcA,fur,marA
# b0592                                        fur,rpoD,rutR
# b2673                               cra,fur,iscR,nrdR,rpoD
# b3515    arcA,fnr,gadE,gadW,gadX,h-NS,phoB,phoP,rpoS,ru...
# b4490_2                                           fur,rpoD
# b2146                                             crp,rpoD
# b1673                                   fnr,narL,narP,rpoS
# b1674                                   fnr,narL,narP,rpoS
# b1905                                        fur,h-NS,rpoD

# %%
get_imodulon(S,'iron-related',annotation=gene_info,trn=trn)
# Out:
#            start     stop strand gene_name  length            operon  \
# b1656    1735377  1735959      +      sodB     582              sodB
# b4640_1  2067457  2067892      -    yoeG_1     435            yoeG_1
# b3540    3701863  3702868      -      dppF    1005          dppABCDF
# b3543    3704770  3705790      -      dppB    1020          dppABCDF
# b3542    3703858  3704761      -      dppC     903          dppABCDF
# b3541    3702864  3703848      -      dppD     984          dppABCDF
# b2524    2656535  2656736      -      iscX     201    hscBA-fdx-iscX
# b2530    2660316  2661531      -      iscS    1215           iscRSUA
# b2525    2656747  2657083      -       fdx     336    hscBA-fdx-iscX
# b2529    2659902  2660289      -      iscU     387           iscRSUA
# b2523    2655074  2656358      -      pepB    1284              pepB
# b2526    2657084  2658935      -      hscA    1851    hscBA-fdx-iscX
# b2522    2654156  2654933      -      sseB     777              sseB
# b2528    2659562  2659886      -      iscA     324           iscRSUA
# b2527    2658951  2659467      -      hscB     516    hscBA-fdx-iscX
# b4506     312373   312514      -      ykgO     141             ykgMO
# b1612    1686730  1688377      -      fumA    1647             fumAC
# b2282    2396464  2397442      -      nuoH     978  nuoABCEFGHIJKLMN
# b2392    2511467  2512706      -      mntH    1239              mntH
# b4567    4605803  4606040      +      yjjZ     237              yjjZ
#
#                                                        cog  \
# b1656               Inorganic ion transport and metabolism
# b4640_1                                  No COG Annotation
# b3540                  Amino acid transport and metabolism
# b3543               Inorganic ion transport and metabolism
# b3542               Inorganic ion transport and metabolism
# b3541                  Amino acid transport and metabolism
# b2524                                     Function unknown
# b2530                                    No COG Annotation
# b2525                     Energy production and conversion
# b2529                     Energy production and conversion
# b2523                  Amino acid transport and metabolism
# b2526    Posttranslational modification, protein turnov...
# b2522                                     Function unknown
# b2528                                     Function unknown
# b2527    Posttranslational modification, protein turnov...
# b4506      Translation, ribosomal structure and biogenesis
# b1612                     Energy production and conversion
# b2282                     Energy production and conversion
# b2392               Inorganic ion transport and metabolism
# b4567                                     Function unknown
#
#                                                    Product  coefficient  \
# b1656                            superoxide dismutase (Fe)     0.153763
# b4640_1                                                NaN     0.133781
# b3540    dipeptide ABC transporter ATP binding subunit ...     0.117895
# b3543      dipeptide ABC transporter membrane subunit DppB     0.115937
# b3542      dipeptide ABC transporter membrane subunit DppC     0.112305
# b3541    dipeptide ABC transporter ATP binding subunit ...     0.110516
# b2524    accessory iron-sulfur cluster assembly protein...     0.105962
# b2530                                 cysteine desulfurase     0.105049
# b2525          oxidized ferredoxin // "reduced ferredoxin"     0.094516
# b2529    scaffold protein for iron-sulfur cluster assembly     0.090061
# b2523                                     aminopeptidase B     0.085509
# b2526      iron-sulfur cluster biosynthesis chaperone HscA     0.084871
# b2522                                         protein SseB     0.082776
# b2528           iron-sulfur cluster insertion protein IscA     0.082598
# b2527        [Fe-S] cluster biosynthesis co-chaperone HscB     0.081705
# b4506                           putative ribosomal protein     0.079447
# b1612                                           fumarase A     0.071174
# b2282                NADH:quinone oxidoreductase subunit H     0.070648
# b2392    Mn<sup>2+</sup>/Fe<sup>2+</sup>: H<sup>+</sup>...    -0.106224
# b4567               DUF1435 domain-containing protein YjjZ    -0.209488
#
#                                  regulators
# b1656                     crp,ihf,nsrR,rpoD
# b4640_1
# b3540             arcA,fnr,ihf,lrp,nac,rpoD
# b3543             arcA,fnr,ihf,lrp,nac,rpoD
# b3542             arcA,fnr,ihf,lrp,nac,rpoD
# b3541             arcA,fnr,ihf,lrp,nac,rpoD
# b2524                                  rpoD
# b2530                             iscR,rpoD
# b2525                                  rpoD
# b2529                             iscR,rpoD
# b2523
# b2526                             rpoD,ybiH
# b2522
# b2528                             iscR,rpoD
# b2527                                  rpoD
# b4506                              rpoD,zur
# b1612                     arcA,crp,fnr,rpoD
# b2282    arcA,cra,crp,fis,fnr,ihf,narL,rpoD
# b2392       arcA,crp,fur,mntR,nac,oxyR,rpoD
# b4567                 fnr,fur,nac,oxyR,rpoD

# %% [markdown]
# ## Expanding to additional strains

# %% [markdown]
# $$ \mathbf{X} = \mathbf{SA} $$
# $$ \mathbf{S}^{-1}\mathbf{X} = \mathbf{A} $$

# %%
DF_multi = pd.read_csv(join('data','multistrain_data.csv'),index_col=0)

# %%
DF_multi.head()
# Out:
#           BL21.1     BL21.2       HS.1       HS.2   CFT073.1   CFT073.2  \
# b0002   9.956475   9.882488   9.758191   9.722243   8.778787   8.778098
# b0003   9.660295   9.646450   9.340883   9.353096   8.273014   8.205768
# b0004   9.565739   9.480324   9.458359   9.439455   8.682122   8.595821
# b0014  10.431665  10.407715  10.562682  10.473558  10.232508  10.230903
# b0015   8.181207   8.140446   8.160990   8.237028   8.645375   8.600162
#
#          W3110.1    W3110.2     O157.1     O157.2   Crooks.1   Crooks.2  \
# b0002  11.051267  11.063098   9.806763   9.917789   9.567604   9.595503
# b0003  10.459465  10.475906   9.338716   9.528700   9.255841   9.292759
# b0004  10.390698  10.381146   9.800511   9.853385   9.313167   9.308077
# b0014  10.618153  10.677474  10.649165  10.579652  10.344358  10.369465
# b0015   8.486238   8.442598   8.666090   8.845480   8.267175   8.368835
#
#        control__wt_glc__1  control__wt_glc__2  BW25113.1  BW25113.2
# b0002           11.006653           11.130196  10.208587  10.218351
# b0003           10.415654           10.523138   9.609637   9.677931
# b0004           10.594871           10.725062   9.883558   9.870356
# b0014           10.307866           10.381348  10.569602  10.557703
# b0015            7.874248            8.184380   8.072288   8.149469

# %%
DF_multi.shape
# Out:
# (915, 16)

# %%
# Only keep genes in core genome
S_multi = S.reindex(DF_multi.index)

# %%
# Center to reference condition
X_multi = DF_multi.sub(DF_multi[['control__wt_glc__1','control__wt_glc__2']].mean(axis=1),axis=0)

# %%
# Compute A matrix
from scipy.linalg import pinv

A_multi = np.dot(pinv(S_multi),X_multi)

A_multi = pd.DataFrame(A_multi,columns = X_multi.columns,index=S.columns)

# %%
# %matplotlib inline

# %%
A_multi.loc['RpoS'].sort_values()
# Out:
# O157.1               -35.515805
# O157.2               -34.905797
# CFT073.1             -33.585962
# CFT073.2             -32.608324
# W3110.1              -30.932889
# W3110.2              -30.807190
# HS.1                 -22.903550
# Crooks.1             -22.410543
# HS.2                 -22.337756
# Crooks.2             -21.832001
# BL21.2               -13.946497
# BL21.1               -13.872377
# BW25113.1             -5.517325
# BW25113.2             -5.341697
# control__wt_glc__1    -0.105009
# control__wt_glc__2     0.105009
# Name: RpoS, dtype: float64
